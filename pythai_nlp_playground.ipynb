# %%
import pythainlp as pythai
from pythainlp.tokenize import subword_tokenize,word_tokenize, syllable_tokenize
from pythainlp.util import sound_syllable
from pythainlp.util import remove_tonemark
from pythainlp.util import sound_syllable
from pythainlp.util import isthai
from pythainlp.transliterate import pronunciate
from pythainlp.spell import correct
from pythainlp.khavee import KhaveeVerifier
kv = KhaveeVerifier()

# %%
print(kv.check_sara("พาล"))
print(kv.check_marttra("พาล"))
print(kv.check_marttra("พาน"))
print(kv.is_sumpus("บ้าน", "พาล"))
# Out:
# อา
# กน
# กน
# True

# %%
print(kv.is_sumpus("ทำ", "จำ"))
# Out:
# True

# %%
print(kv.check_sara("ธรรม"))
print(kv.check_sara("สัม"))
print(kv.is_sumpus("ธรรม", "สัม"))
print(kv.is_sumpus("ธรรม", "จำ"))
print(kv.is_sumpus("กัย", "ไกล"))
print(kv.is_sumpus("ใคร", "ไกล"))
# Out:
# อำ
# อะ
# True
# True
# True
# True

# %%
print(kv.check_marttra("กัย"))
print(kv.is_sumpus("กัย", "ไก"))
# Out:
# เกย
# True

# %%
print(kv.check_sara("กรม"))
print(kv.check_sara("ขอ"))
print(kv.check_sara("งอ"))
# Out:
# โอะ
# ออ
# ออ

# %%
# สระลดรูป/เปลี่ยนรูป
problem_words = ["เลย", "พวก", "จวก", "เจ็ด", "แข็ง", "เดิน"]
for word in problem_words:
    print(f"Word: {word}, Sara: {kv.check_sara(word)}, Marttra: {kv.check_marttra(word)}")

print(kv.is_sumpus("เลย", "เกย"))
print(kv.is_sumpus("พวก", "จวก"))
# Out:
# Word: เลย, Sara: เออ, Marttra: เกย
# Word: พวก, Sara: อัว, Marttra: กก
# Word: จวก, Sara: อัว, Marttra: กก
# Word: เจ็ด, Sara: เอะ, Marttra: กด
# Word: แข็ง, Sara: แอะ, Marttra: กง
# Word: เดิน, Sara: เออ, Marttra: กน
# True
# True

# %%
print(kv.is_sumpus("ได้","ด้าย"))
print(kv.check_marttra("ได้"))
print(kv.check_sara("ได้"))
print(kv.check_sara("ด้าย"))
karun_words = ["อินทรีย์", "กษัตริย์", "ไปรษณีย์", "ฤทธิ์", "การ์ตูน", "กอล์ฟ", "สัปดาห์", "จันทร์", "เฮิรตซ์", "ฟิล์ม", "สตาร์ตอัป", "พระลักษมณ์", "วิศวกรรมศาสตร์", "กบินทร์", "บดินทร์", "นราธิเบนทร์", "ทอร์นาโด", "พรหมจรรย์", "อินทรีย์", "กรณีย์", "รังสิมันตุ์", "รามเกียรติ์", "ทรลักษณ์", "ลิขสิทธิ์", "ธำมรงค์", "ศัพท์", "ฉันท์", "เจ้าเล่ห์", "สงเคราะห์", "โอห์ม", "ราชทัณฑ์", "สวาสดิ์", "สุปรีดิ์", "เปรมปรีดิ์", "กอล์ฟ", "ภูมินทร์", "ภาพยนตร์", "บาร์เลย์", "ชนินทร์", "กาสาวพัสตร์"]
for i in karun_words:
    print(f"{i} -> {kv.handle_karun_sound_silence(i)}")
# Out:
# False
# กา
# ไอ
# อา
# อินทรีย์ -> อินทรี
# กษัตริย์ -> กษัต
# ไปรษณีย์ -> ไปรษณี
# ฤทธิ์ -> ฤท
# การ์ตูน -> การ์ตูน
# กอล์ฟ -> กอล์ฟ
# สัปดาห์ -> สัปดา
# จันทร์ -> จัน
# เฮิรตซ์ -> เฮิรต
# ฟิล์ม -> ฟิล์ม
# สตาร์ตอัป -> สตาร์ตอัป
# พระลักษมณ์ -> พระลัก
# วิศวกรรมศาสตร์ -> วิศวกรรมศาส
# กบินทร์ -> กบิน
# บดินทร์ -> บดิน
# นราธิเบนทร์ -> นราธิเบน
# ทอร์นาโด -> ทอร์นาโด
# พรหมจรรย์ -> พรหมจรร
# อินทรีย์ -> อินทรี
# กรณีย์ -> กรณี
# รังสิมันตุ์ -> รังสิมัน
# รามเกียรติ์ -> รามเกียร
# ทรลักษณ์ -> ทรลัก
# ลิขสิทธิ์ -> ลิขสิท
# ธำมรงค์ -> ธำมรง
# ศัพท์ -> ศัพ
# ฉันท์ -> ฉัน
# เจ้าเล่ห์ -> เจ้าเล่
# สงเคราะห์ -> สงเคราะ
# โอห์ม -> โอห์ม
# ราชทัณฑ์ -> ราชทัณ
# สวาสดิ์ -> สวาส
# สุปรีดิ์ -> สุปรี
# เปรมปรีดิ์ -> เปรมปรี
# กอล์ฟ -> กอล์ฟ
# ภูมินทร์ -> ภูมิน
# ภาพยนตร์ -> ภาพยน
# บาร์เลย์ -> บาร์เล
# ชนินทร์ -> ชนิน
# กาสาวพัสตร์ -> กาสาวพัส

# %%
import timeit
from pythainlp.transliterate import romanize

# Sample words representing the different behaviors of 'ฤ'
test_words = ["ฤทธิ์", "ฤกษ์", "พฤษภาคม", "ทฤษฎี", "กฤษณ์", "กฤษณะ", "ฤดู"]

def check_sara_hardcoded(word: str) -> str:
    """Optimized Substring / Rule-based approach (Microseconds)"""
    if "ฤา" in word or "ฦา" in word:
        return "อือ"
    
    if "ฤกษ" in word:
        return "เออ"
    elif any(ex in word for ex in ("กฤษ", "ตฤณ", "ทฤษ", "ฤทธ", "ปฤษ", "ศฤง", "สฤต")):
        return "อิ"
    else:
        return "อึ"

def check_sara_romanized(word: str) -> str:
    """Heavy NLP Romanization approach (Milliseconds)"""
    if "ฤา" in word or "ฦา" in word:
        return "อือ"
        
    rom = romanize(word, engine="royin").lower()
    if "oek" in rom or "oe" in rom:
        return "เออ"
    elif "ri" in rom or "it" in rom:
        return "อิ"
    else:
        return "อึ"

# Wrapper functions for the benchmark loop
def run_hardcoded():
    for word in test_words:
        check_sara_hardcoded(word)

def run_romanized():
    for word in test_words:
        check_sara_romanized(word)

print("⚡ Starting Benchmark (Running 1,000 iterations per approach)...")
    
# Warm up pythainlp engine so initialization time isn't counted
print(romanize("พฤษภาคม", engine="royin"))

# Run the tests 1,000 times
iterations = 1000
time_hardcoded = timeit.timeit(run_hardcoded, number=iterations)

print("\n=== BENCHMARK RESULTS ===")
print(f"Hardcoded Rules: {time_hardcoded:.5f} seconds")
# Out:
# ⚡ Starting Benchmark (Running 1,000 iterations per approach)...
# phruetphakm
#
# === BENCHMARK RESULTS ===
# Hardcoded Rules: 0.00442 seconds

# %%
print(kv.check_sara("อ็อก"))
print(kv.check_sara("อต"))
print(kv.check_sara("อวก"))
print(kv.check_sara("ยศ"))
print(kv.check_sara("บวร"))
print(kv.check_sara("วร"))
print(kv.check_sara("ทฤษฎี"))
print(kv.check_sara("ทฤษ"))
print(kv.check_sara("ฎี"))
print(kv.check_sara("ฤา"))
print(kv.check_sara("ฤๅ"))
print(kv.check_sara("กูณฑ์"))
print(kv.check_sara("สินธุ์"))
print(kv.check_sara("เสนีย์")) # need to split into เส-นีย์ to get correct result
print(kv.check_sara("ปรีดิ์"))
print(kv.check_sara("เกียรติ"))
print(kv.check_sara("พรรดิ"))
print(kv.check_marttra("เกียรติ"))
print(kv.check_marttra("พรรดิ"))
# Out:
# เอาะ
# โอะ
# อัว
# โอะ
# ออ
# ออ
# อิ
# อิ
# อี
# อือ
# อือ
# อู
# อิ
# เอีย
# อี
# เอีย
# อะ
# กด
# กด

# %%
test_words = ["พัฒนาการ","มารถ"]
for word in test_words:
    print(f"Word: {word}, Sara: {kv.check_sara(word)}, Marttra: {kv.check_marttra(word)}")
# Out:
# Word: พัฒนาการ, Sara: อะ, Marttra: กน
# Word: มารถ, Sara: อา, Marttra: กด

# %%
# problematic_word = ["ฤทธิ์", "ฤกษ์", "พฤษภาคม", "ทฤษฎี", "กฤษณ์", "กฤษณะ"]
problematic_word = ["คุณวุฒิ", "เกียรติ", "ชาติ", "จักรวรรดิ", "สมมุติ", "พฤติกรรม", "พยัญ", "ชนะ", "สระ", "เกษม", "พัฒนาการ"]
for word in problematic_word:
    result = pronunciate(word, engine="w2p")
    result = result.replace("ฺ", "")
    # split the wordat "-"
    print(f"{word} -> {result}")
# Out:
# คุณวุฒิ -> คุน-นะ-วุด
# เกียรติ -> เกียด
# ชาติ -> ชาด
# จักรวรรดิ -> จัก-กระ-หวัด
# สมมุติ -> สม-มุด
# พฤติกรรม -> พรึด-ติ-กำ
# พยัญ -> พะ-ยัน
# ชนะ -> ชะ-นะ
# สระ -> สะ
# เกษม -> กะ-เสม
# พัฒนาการ -> พัด-ทะ-นา-กาน

# %%
# sentence = ["แม่รักลูกลูกก็รู้อยู่ว่ารัก","คนอื่นสักหมื่นแสนไม่แม้นเหมือน", "ถึงโรงเหล้าเตากลั่นควันโขมง", "มีคันโพงผูกสายไว้ปลายเสา", "โอ้บาปกรรมน้ำนรกเจียวอกเรา", "ให้มัวเมาเหมือนหนึ่งบ้าเป็นน่าอาย", "ทำบุญบวชกรวดน้ำขอสำเร็จ", "สรรเพชญโพธิญาณประมาณหมาย", "ถึงสุราพารอดไม่วอดวาย", "ไม่ใกล้กรายแกล้งเมินก็เกินไป"]
# sentence = ["ไม่เมาเหล้าแล้วแต่เรายังเมารัก", "สุดจะหักห้ามจิตคิดไฉน", "ถึงเมาเหล้าเช้าสายก็หายไป", "แต่เมาใจนี้ประจำทุกค่ำคืน", "ํอ","พฤติกรรม"]
sentence = [
    "แม่รักลูกลูกก็รู้อยู่ว่ารัก",
    "คนอื่นสักหมื่นแสนไม่แม้นเหมือน", 
    "ถึงโรงเหล้าเตากลั่นควันโขมง",
    "มีคันโพงผูกสายไว้ปลายเสา", 
    "โอ้บาปกรรมน้ำนรกเจียวอกเรา",
    "ให้มัวเมาเหมือนหนึ่งบ้าเป็นน่าอาย", 
    "ทำบุญบวชกรวดน้ำขอสำเร็จ",
    "สรรเพชญโพธิญาณประมาณหมาย", 
    "ถึงสุราพารอดไม่วอดวาย",
    "ไม่ใกล้กรายแกล้งเมินก็เกินไป",
    "ความแปลกแยกและพัฒนาการ",
    "อันประกอบด้วยสระและพยัญชนะหลายตัว",
    "เกษมสำราญระรื่นชื่นใจ",
    "โอ้มนุษย์ผู้มีจิตใจอันสูงส่งและมีความสามารถในการสร้างสรรค์สิ่งใหม่"
]

# word tokenize the sentence
for sent in sentence:
    pronunce_sent = []
    word_tok = word_tokenize(sent, engine="newmm") # newmm engine groups the words together, so we need to use subword_tokenize instead
    # word_tok = subword_tokenize(sent, engine="dict", keep_whitespace=False)
    # word_tok = syllable_tokenize(sent, engine="dict", keep_whitespace=False)
    print(f"Sentence: {sent}, Tokens: {word_tok}")
    for word in word_tok:
        # if word length is <= 3, don't pronunciate it kust append it to the pronunce_sent list
        if len(word) <= 3:
            pronunce_sent.append(word)
            print(f"**Word: {word}, len: {len(word)}, Pronunciation: {word}")
        else:
            result = pronunciate(word, engine="w2p").replace("ฺ", "").replace("-", "")
            pronunce_sent.append(result)
            print(f"Word: {word}, len: {len(word)}, Pronunciation: {result}")
    print(f"Pronunciation: {pronunce_sent}")
    # ['กะเสม', 'สำ', 'ราญ', 'ระ', 'รื่น', 'ชื่น', 'ใจ'] -> ['กะ', 'เสม', 'สำ', 'ราญ', 'ระ', 'รื่น', 'ชื่น', 'ใจ'] (only split if there is ะ and ะ is not at the end and split at the first ะ)
    final_syllable = []
    for syllable in pronunce_sent:
        if "ะ" in syllable and not syllable.endswith("ะ"):
            split_index = syllable.index("ะ") + 1
            final_syllable.append(syllable[:split_index])
            final_syllable.append(syllable[split_index:])
        else:
            final_syllable.append(syllable)
    print(f"Final Syllable: {final_syllable}\n")
# Out:
# Sentence: แม่รักลูกลูกก็รู้อยู่ว่ารัก, Tokens: ['แม่', 'รัก', 'ลูก', 'ลูก', 'ก็', 'รู้อยู่', 'ว่า', 'รัก']
# **Word: แม่, len: 3, Pronunciation: แม่
# **Word: รัก, len: 3, Pronunciation: รัก
# **Word: ลูก, len: 3, Pronunciation: ลูก
# **Word: ลูก, len: 3, Pronunciation: ลูก
# **Word: ก็, len: 2, Pronunciation: ก็
# Word: รู้อยู่, len: 7, Pronunciation: รู้หยู่
# **Word: ว่า, len: 3, Pronunciation: ว่า
# **Word: รัก, len: 3, Pronunciation: รัก
# Pronunciation: ['แม่', 'รัก', 'ลูก', 'ลูก', 'ก็', 'รู้หยู่', 'ว่า', 'รัก']
# Final Syllable: ['แม่', 'รัก', 'ลูก', 'ลูก', 'ก็', 'รู้หยู่', 'ว่า', 'รัก']
#
# Sentence: คนอื่นสักหมื่นแสนไม่แม้นเหมือน, Tokens: ['คนอื่น', 'สัก', 'หมื่น', 'แสน', 'ไม่', 'แม้น', 'เหมือน']
# Word: คนอื่น, len: 6, Pronunciation: คนอื่น
# **Word: สัก, len: 3, Pronunciation: สัก
# Word: หมื่น, len: 5, Pronunciation: หมื่น
# **Word: แสน, len: 3, Pronunciation: แสน
# **Word: ไม่, len: 3, Pronunciation: ไม่
# Word: แม้น, len: 4, Pronunciation: แม้น
# Word: เหมือน, len: 6, Pronunciation: เหมือน
# Pronunciation: ['คนอื่น', 'สัก', 'หมื่น', 'แสน', 'ไม่', 'แม้น', 'เหมือน']
# Final Syllable: ['คนอื่น', 'สัก', 'หมื่น', 'แสน', 'ไม่', 'แม้น', 'เหมือน']
#
# Sentence: ถึงโรงเหล้าเตากลั่นควันโขมง, Tokens: ['ถึง', 'โรงเหล้า', 'เตา', 'กลั่น', 'ควัน', 'โขมง']
# **Word: ถึง, len: 3, Pronunciation: ถึง
# Word: โรงเหล้า, len: 8, Pronunciation: โรงเหล้า
# **Word: เตา, len: 3, Pronunciation: เตา
# Word: กลั่น, len: 5, Pronunciation: กลั่น
# Word: ควัน, len: 4, Pronunciation: ควัน
# Word: โขมง, len: 4, Pronunciation: ขะโหมง
# Pronunciation: ['ถึง', 'โรงเหล้า', 'เตา', 'กลั่น', 'ควัน', 'ขะโหมง']
# Final Syllable: ['ถึง', 'โรงเหล้า', 'เตา', 'กลั่น', 'ควัน', 'ขะ', 'โหมง']
#
# Sentence: มีคันโพงผูกสายไว้ปลายเสา, Tokens: ['มี', 'คันโพง', 'ผูก', 'สาย', 'ไว้', 'ปลาย', 'เสา']
# **Word: มี, len: 2, Pronunciation: มี
# Word: คันโพง, len: 6, Pronunciation: คันโพง
# **Word: ผูก, len: 3, Pronunciation: ผูก
# **Word: สาย, len: 3, Pronunciation: สาย
# **Word: ไว้, len: 3, Pronunciation: ไว้
# Word: ปลาย, len: 4, Pronunciation: ปลาย
# **Word: เสา, len: 3, Pronunciation: เสา
# Pronunciation: ['มี', 'คันโพง', 'ผูก', 'สาย', 'ไว้', 'ปลาย', 'เสา']
# Final Syllable: ['มี', 'คันโพง', 'ผูก', 'สาย', 'ไว้', 'ปลาย', 'เสา']
#
# Sentence: โอ้บาปกรรมน้ำนรกเจียวอกเรา, Tokens: ['โอ้', 'บาปกรรม', 'น้ำ', 'นรก', 'เจีย', 'วอก', 'เรา']
# **Word: โอ้, len: 3, Pronunciation: โอ้
# Word: บาปกรรม, len: 7, Pronunciation: บาบกะรม
# **Word: น้ำ, len: 3, Pronunciation: น้ำ
# **Word: นรก, len: 3, Pronunciation: นรก
# Word: เจีย, len: 4, Pronunciation: เจีย
# **Word: วอก, len: 3, Pronunciation: วอก
# **Word: เรา, len: 3, Pronunciation: เรา
# Pronunciation: ['โอ้', 'บาบกะรม', 'น้ำ', 'นรก', 'เจีย', 'วอก', 'เรา']
# Final Syllable: ['โอ้', 'บาบกะ', 'รม', 'น้ำ', 'นรก', 'เจีย', 'วอก', 'เรา']
#
# Sentence: ให้มัวเมาเหมือนหนึ่งบ้าเป็นน่าอาย, Tokens: ['ให้', 'มัวเมา', 'เหมือน', 'หนึ่ง', 'บ้า', 'เป็น', 'น่าอาย']
# **Word: ให้, len: 3, Pronunciation: ให้
# Word: มัวเมา, len: 6, Pronunciation: มัวเมา
# Word: เหมือน, len: 6, Pronunciation: เหมือน
# Word: หนึ่ง, len: 5, Pronunciation: หนึ่ง
# **Word: บ้า, len: 3, Pronunciation: บ้า
# Word: เป็น, len: 4, Pronunciation: เป็น
# Word: น่าอาย, len: 6, Pronunciation: น่าอาย
# Pronunciation: ['ให้', 'มัวเมา', 'เหมือน', 'หนึ่ง', 'บ้า', 'เป็น', 'น่าอาย']
# Final Syllable: ['ให้', 'มัวเมา', 'เหมือน', 'หนึ่ง', 'บ้า', 'เป็น', 'น่าอาย']
#
# Sentence: ทำบุญบวชกรวดน้ำขอสำเร็จ, Tokens: ['ทำบุญ', 'บวช', 'กรวดน้ำ', 'ขอ', 'สำเร็จ']
# Word: ทำบุญ, len: 5, Pronunciation: ทำบุน
# **Word: บวช, len: 3, Pronunciation: บวช
# Word: กรวดน้ำ, len: 7, Pronunciation: กรวดน้าม
# **Word: ขอ, len: 2, Pronunciation: ขอ
# Word: สำเร็จ, len: 6, Pronunciation: สำเหร็ด
# Pronunciation: ['ทำบุน', 'บวช', 'กรวดน้าม', 'ขอ', 'สำเหร็ด']
# Final Syllable: ['ทำบุน', 'บวช', 'กรวดน้าม', 'ขอ', 'สำเหร็ด']
#
# Sentence: สรรเพชญโพธิญาณประมาณหมาย, Tokens: ['สรรเพชญ', 'โพธิญาณ', 'ประมาณ', 'หมาย']
# Word: สรรเพชญ, len: 7, Pronunciation: สันเพ็ด
# Word: โพธิญาณ, len: 7, Pronunciation: โพทิยาน
# Word: ประมาณ, len: 6, Pronunciation: ประมาน
# Word: หมาย, len: 4, Pronunciation: หมาย
# Pronunciation: ['สันเพ็ด', 'โพทิยาน', 'ประมาน', 'หมาย']
# Final Syllable: ['สันเพ็ด', 'โพทิยาน', 'ประ', 'มาน', 'หมาย']
#
# Sentence: ถึงสุราพารอดไม่วอดวาย, Tokens: ['ถึง', 'สุรา', 'พา', 'รอด', 'ไม่', 'วอดวาย']
# **Word: ถึง, len: 3, Pronunciation: ถึง
# Word: สุรา, len: 4, Pronunciation: สุรา
# **Word: พา, len: 2, Pronunciation: พา
# **Word: รอด, len: 3, Pronunciation: รอด
# **Word: ไม่, len: 3, Pronunciation: ไม่
# Word: วอดวาย, len: 6, Pronunciation: วอดวาย
# Pronunciation: ['ถึง', 'สุรา', 'พา', 'รอด', 'ไม่', 'วอดวาย']
# Final Syllable: ['ถึง', 'สุรา', 'พา', 'รอด', 'ไม่', 'วอดวาย']
#
# Sentence: ไม่ใกล้กรายแกล้งเมินก็เกินไป, Tokens: ['ไม่', 'ใกล้', 'กราย', 'แกล้ง', 'เมิน', 'ก็', 'เกินไป']
# **Word: ไม่, len: 3, Pronunciation: ไม่
# Word: ใกล้, len: 4, Pronunciation: ไกล้
# Word: กราย, len: 4, Pronunciation: กราย
# Word: แกล้ง, len: 5, Pronunciation: แกล้ง
# Word: เมิน, len: 4, Pronunciation: เมิน
# **Word: ก็, len: 2, Pronunciation: ก็
# Word: เกินไป, len: 6, Pronunciation: เกินไป
# Pronunciation: ['ไม่', 'ไกล้', 'กราย', 'แกล้ง', 'เมิน', 'ก็', 'เกินไป']
# Final Syllable: ['ไม่', 'ไกล้', 'กราย', 'แกล้ง', 'เมิน', 'ก็', 'เกินไป']
#
# Sentence: ความแปลกแยกและพัฒนาการ, Tokens: ['ความ', 'แปลกแยก', 'และ', 'พัฒนาการ']
# Word: ความ, len: 4, Pronunciation: ความ
# Word: แปลกแยก, len: 7, Pronunciation: แปลกแยก
# **Word: และ, len: 3, Pronunciation: และ
# Word: พัฒนาการ, len: 8, Pronunciation: พัดทะนากาน
# Pronunciation: ['ความ', 'แปลกแยก', 'และ', 'พัดทะนากาน']
# Final Syllable: ['ความ', 'แปลกแยก', 'และ', 'พัดทะ', 'นากาน']
#
# Sentence: อันประกอบด้วยสระและพยัญชนะหลายตัว, Tokens: ['อัน', 'ประกอบด้วย', 'สระ', 'และ', 'พยัญชนะ', 'หลาย', 'ตัว']
# **Word: อัน, len: 3, Pronunciation: อัน
# Word: ประกอบด้วย, len: 10, Pronunciation: ประกอบด้วย
# **Word: สระ, len: 3, Pronunciation: สระ
# **Word: และ, len: 3, Pronunciation: และ
# Word: พยัญชนะ, len: 7, Pronunciation: พะยันชะนะ
# Word: หลาย, len: 4, Pronunciation: หลาย
# **Word: ตัว, len: 3, Pronunciation: ตัว
# Pronunciation: ['อัน', 'ประกอบด้วย', 'สระ', 'และ', 'พะยันชะนะ', 'หลาย', 'ตัว']
# Final Syllable: ['อัน', 'ประ', 'กอบด้วย', 'สระ', 'และ', 'พะยันชะนะ', 'หลาย', 'ตัว']
#
# Sentence: เกษมสำราญระรื่นชื่นใจ, Tokens: ['เกษม', 'สำราญ', 'ระรื่น', 'ชื่นใจ']
# Word: เกษม, len: 4, Pronunciation: กะเสม
# Word: สำราญ, len: 5, Pronunciation: สำราน
# Word: ระรื่น, len: 6, Pronunciation: ระรื่น
# Word: ชื่นใจ, len: 6, Pronunciation: ชื่นใจ
# Pronunciation: ['กะเสม', 'สำราน', 'ระรื่น', 'ชื่นใจ']
# Final Syllable: ['กะ', 'เสม', 'สำราน', 'ระ', 'รื่น', 'ชื่นใจ']
#
# Sentence: โอ้มนุษย์ผู้มีจิตใจอันสูงส่งและมีความสามารถในการสร้างสรรค์สิ่งใหม่, Tokens: ['โอ้', 'มนุษย์', 'ผู้', 'มี', 'จิตใจ', 'อัน', 'สูงส่ง', 'และ', 'มี', 'ความสามารถ', 'ใน', 'การ', 'สร้างสรรค์', 'สิ่งใหม่']
# **Word: โอ้, len: 3, Pronunciation: โอ้
# Word: มนุษย์, len: 6, Pronunciation: มะนุด
# **Word: ผู้, len: 3, Pronunciation: ผู้
# **Word: มี, len: 2, Pronunciation: มี
# Word: จิตใจ, len: 5, Pronunciation: จิดใจ
# **Word: อัน, len: 3, Pronunciation: อัน
# Word: สูงส่ง, len: 6, Pronunciation: สูงส่ง
# **Word: และ, len: 3, Pronunciation: และ
# **Word: มี, len: 2, Pronunciation: มี
# Word: ความสามารถ, len: 10, Pronunciation: ความสามาด
# **Word: ใน, len: 2, Pronunciation: ใน
# **Word: การ, len: 3, Pronunciation: การ
# Word: สร้างสรรค์, len: 10, Pronunciation: ส้างสัน
# Word: สิ่งใหม่, len: 8, Pronunciation: สิ่งไหม่
# Pronunciation: ['โอ้', 'มะนุด', 'ผู้', 'มี', 'จิดใจ', 'อัน', 'สูงส่ง', 'และ', 'มี', 'ความสามาด', 'ใน', 'การ', 'ส้างสัน', 'สิ่งไหม่']
# Final Syllable: ['โอ้', 'มะ', 'นุด', 'ผู้', 'มี', 'จิดใจ', 'อัน', 'สูงส่ง', 'และ', 'มี', 'ความสามาด', 'ใน', 'การ', 'ส้างสัน', 'สิ่งไหม่']

# %%
print(kv.check_marttra("กัย"))
print(kv.is_sumpus("ชัย", "ไช"))
print(kv.is_sumpus("ต", "ทะ"))
print(kv.check_marttra("ต"))
print(kv.check_sara("ข"))
# Out:
# เกย
# True
# False
# กา
# Can't find Sara in this word

# %%
# sentence = ["แม่รักลูกลูกก็รู้อยู่ว่ารัก","คนอื่นสักหมื่นแสนไม่แม้นเหมือน", "ถึงโรงเหล้าเตากลั่นควันโขมง", "มีคันโพงผูกสายไว้ปลายเสา", "โอ้บาปกรรมน้ำนรกเจียวอกเรา", "ให้มัวเมาเหมือนหนึ่งบ้าเป็นน่าอาย", "ทำบุญบวชกรวดน้ำขอสำเร็จ", "สรรเพชญโพธิญาณประมาณหมาย", "ถึงสุราพารอดไม่วอดวาย", "ไม่ใกล้กรายแกล้งเมินก็เกินไป"]
# sentence = ["ไม่เมาเหล้าแล้วแต่เรายังเมารัก", "สุดจะหักห้ามจิตคิดไฉน", "ถึงเมาเหล้าเช้าสายก็หายไป", "แต่เมาใจนี้ประจำทุกค่ำคืน", "ํอ","พฤติกรรม"]
sentence = [
    "เรียกว่าบ้านจันตคามพราหมณ์พฤฒา",
    "แม่รักลูกลูกก็รู้อยู่ว่ารัก",
    "คนอื่นสักหมื่นแสนไม่แม้นเหมือน", 
    "ถึงโรงเหล้าเตากลั่นควันโขมง",
    "สรรเพชญโพธิญาณประมาณหมาย", 
    "ความแปลกแยกและพัฒนาการ",
    "อันประกอบด้วยสระและพยัญชนะหลายตัว",
    "เกษมสำราญระรื่นชื่นใจ",
    "บ่มีผู้ใดจะเข้าใจความรู้สึกของข้าได้",
    "ไหนใครใคร่ใช้ได้ใจชัยไทย",
    "โอ้มนุษย์ผู้มีจิตใจและมีความสามารถในการสร้างสรรค์สิ่งใหม่"
]

# word tokenize the sentence
for sent in sentence:
    words = word_tokenize(sent, engine="newmm") # Be greedy and let the prononciation engine handle
    final_syllables = []
    for word in words:
        # Skip pronunciation for very short words
        if len(word) <= 2:
            # We still want to ensure it's broken into syllables if needed
            syls = syllable_tokenize(word, engine="ssg")
            final_syllables.extend(syls)
            print(f"**Word: {word}, len: {len(word)}, Pronunciation: {syls}")
            continue
            
        # 2. Get the phonetic pronunciation of the whole word
        phonetic_word = pronunciate(word, engine="w2p")
        
        if not phonetic_word:
            final_syllables.append(word)
            print(f"Warning: No phonetic pronunciation found for '{word}'")
            continue
            
        # Clean up unwanted characters like Phinthu (ฺ)
        phonetic_word = phonetic_word.replace("ฺ", "")
        
        # 3. Handle segmentation
        # Strip the w2p hyphens since you noted they can sometimes be inaccurate
        clean_phonetic_word = phonetic_word.replace("-", "")
        
        # Re-tokenize the clean phonetic string into syllables. 
        # Because it's now perfectly phonetic (e.g., พัดทะนากาน), syllable_tokenize will be highly accurate.
        phonetic_syllables = syllable_tokenize(clean_phonetic_word, engine="ssg")
        
        final_syllables.extend(phonetic_syllables)
        print(f">Word: {word}, len: {len(word)}, Pronunciation: {phonetic_syllables}")
        
    print(f"Sentence: {sent}")
    print(f"Final Syllable: {final_syllables}\n")
    
problematic_words = ["ก็", "บ่", "ธ", "ณ", "ฤ", "ฤๅษี", "ได้", "มนุษย์", "พฤติกรรม", "สระ"]
for pw in problematic_words:
    print(f"{pw} - p:{pronunciate(pw, engine='w2p')}, s:{syllable_tokenize(pw, engine="han_solo")}")
# Out:
# >Word: เรียก, len: 5, Pronunciation: ['เรียก']
# >Word: ว่า, len: 3, Pronunciation: ['ว่า']
# >Word: บ้าน, len: 4, Pronunciation: ['บ้าน']
# >Word: จัน, len: 3, Pronunciation: ['จัน']
# **Word: ต, len: 1, Pronunciation: ['ต']
# >Word: คาม, len: 3, Pronunciation: ['คาม']
# >Word: พราหมณ์, len: 7, Pronunciation: ['พราม']
# >Word: พฤฒา, len: 4, Pronunciation: ['พรึด', 'ทา']
# Sentence: เรียกว่าบ้านจันตคามพราหมณ์พฤฒา
# Final Syllable: ['เรียก', 'ว่า', 'บ้าน', 'จัน', 'ต', 'คาม', 'พราม', 'พรึด', 'ทา']
#
# >Word: แม่, len: 3, Pronunciation: ['แม่']
# >Word: รัก, len: 3, Pronunciation: ['รัก']
# >Word: ลูก, len: 3, Pronunciation: ['ลูก']
# >Word: ลูก, len: 3, Pronunciation: ['ลูก']
# **Word: ก็, len: 2, Pronunciation: ['ก็']
# >Word: รู้อยู่, len: 7, Pronunciation: ['รู้', 'หยู่']
# >Word: ว่า, len: 3, Pronunciation: ['ว่า']
# >Word: รัก, len: 3, Pronunciation: ['รัก']
# Sentence: แม่รักลูกลูกก็รู้อยู่ว่ารัก
# Final Syllable: ['แม่', 'รัก', 'ลูก', 'ลูก', 'ก็', 'รู้', 'หยู่', 'ว่า', 'รัก']
#
# >Word: คนอื่น, len: 6, Pronunciation: ['คน', 'อื่น']
# >Word: สัก, len: 3, Pronunciation: ['สัก']
# >Word: หมื่น, len: 5, Pronunciation: ['หมื่น']
# >Word: แสน, len: 3, Pronunciation: ['แสน']
# >Word: ไม่, len: 3, Pronunciation: ['ไม่']
# >Word: แม้น, len: 4, Pronunciation: ['แม้น']
# >Word: เหมือน, len: 6, Pronunciation: ['เหมือน']
# Sentence: คนอื่นสักหมื่นแสนไม่แม้นเหมือน
# Final Syllable: ['คน', 'อื่น', 'สัก', 'หมื่น', 'แสน', 'ไม่', 'แม้น', 'เหมือน']
#
# >Word: ถึง, len: 3, Pronunciation: ['ถึง']
# >Word: โรงเหล้า, len: 8, Pronunciation: ['โรง', 'เหล้า']
# >Word: เตา, len: 3, Pronunciation: ['เตา']
# >Word: กลั่น, len: 5, Pronunciation: ['กลั่น']
# >Word: ควัน, len: 4, Pronunciation: ['ควัน']
# >Word: โขมง, len: 4, Pronunciation: ['ขะ', 'โห', 'มง']
# Sentence: ถึงโรงเหล้าเตากลั่นควันโขมง
# Final Syllable: ['ถึง', 'โรง', 'เหล้า', 'เตา', 'กลั่น', 'ควัน', 'ขะ', 'โห', 'มง']
#
# >Word: สรรเพชญ, len: 7, Pronunciation: ['สัน', 'เพ็ด']
# >Word: โพธิญาณ, len: 7, Pronunciation: ['โพ', 'ทิ', 'ยาน']
# >Word: ประมาณ, len: 6, Pronunciation: ['ประ', 'มาน']
# >Word: หมาย, len: 4, Pronunciation: ['หมาย']
# Sentence: สรรเพชญโพธิญาณประมาณหมาย
# Final Syllable: ['สัน', 'เพ็ด', 'โพ', 'ทิ', 'ยาน', 'ประ', 'มาน', 'หมาย']
#
# >Word: ความ, len: 4, Pronunciation: ['ความ']
# >Word: แปลกแยก, len: 7, Pronunciation: ['แปลก', 'แยก']
# >Word: และ, len: 3, Pronunciation: ['และ']
# >Word: พัฒนาการ, len: 8, Pronunciation: ['พัด', 'ทะ', 'นา', 'กาน']
# Sentence: ความแปลกแยกและพัฒนาการ
# Final Syllable: ['ความ', 'แปลก', 'แยก', 'และ', 'พัด', 'ทะ', 'นา', 'กาน']
#
# >Word: อัน, len: 3, Pronunciation: ['อัน']
# >Word: ประกอบด้วย, len: 10, Pronunciation: ['ประ', 'กอบ', 'ด้วย']
# >Word: สระ, len: 3, Pronunciation: ['สะ']
# >Word: และ, len: 3, Pronunciation: ['และ']
# >Word: พยัญชนะ, len: 7, Pronunciation: ['พะ', 'ยัน', 'ชะ', 'นะ']
# >Word: หลาย, len: 4, Pronunciation: ['หลาย']
# >Word: ตัว, len: 3, Pronunciation: ['ตัว']
# Sentence: อันประกอบด้วยสระและพยัญชนะหลายตัว
# Final Syllable: ['อัน', 'ประ', 'กอบ', 'ด้วย', 'สะ', 'และ', 'พะ', 'ยัน', 'ชะ', 'นะ', 'หลาย', 'ตัว']
#
# >Word: เกษม, len: 4, Pronunciation: ['กะ', 'เสม']
# >Word: สำราญ, len: 5, Pronunciation: ['สำ', 'ราน']
# >Word: ระรื่น, len: 6, Pronunciation: ['ระ', 'รื่น']
# >Word: ชื่นใจ, len: 6, Pronunciation: ['ชื่น', 'ใจ']
# Sentence: เกษมสำราญระรื่นชื่นใจ
# Final Syllable: ['กะ', 'เสม', 'สำ', 'ราน', 'ระ', 'รื่น', 'ชื่น', 'ใจ']
#
# **Word: บ่, len: 2, Pronunciation: ['บ่']
# **Word: มี, len: 2, Pronunciation: ['มี']
# >Word: ผู้ใด, len: 5, Pronunciation: ['พู่', 'ได']
# **Word: จะ, len: 2, Pronunciation: ['จะ']
# >Word: เข้าใจ, len: 6, Pronunciation: ['เข้า', 'ไจ']
# >Word: ความรู้สึก, len: 10, Pronunciation: ['ความ', 'รู้', 'สึก']
# >Word: ของ, len: 3, Pronunciation: ['ของ']
# >Word: ข้า, len: 3, Pronunciation: ['ข้า']
# >Word: ได้, len: 3, Pronunciation: ['ด้าย']
# Sentence: บ่มีผู้ใดจะเข้าใจความรู้สึกของข้าได้
# Final Syllable: ['บ่', 'มี', 'พู่', 'ได', 'จะ', 'เข้า', 'ไจ', 'ความ', 'รู้', 'สึก', 'ของ', 'ข้า', 'ด้าย']
#
# >Word: ไหน, len: 3, Pronunciation: ['ใหน']
# >Word: ใคร, len: 3, Pronunciation: ['ไคร']
# >Word: ใคร่, len: 4, Pronunciation: ['ไค', 'ร่']
# >Word: ใช้, len: 3, Pronunciation: ['ไช้']
# >Word: ได้ใจ, len: 5, Pronunciation: ['ด้าย', 'ไจ']
# >Word: ชัย, len: 3, Pronunciation: ['ไช']
# >Word: ไทย, len: 3, Pronunciation: ['ไท']
# Sentence: ไหนใครใคร่ใช้ได้ใจชัยไทย
# Final Syllable: ['ใหน', 'ไคร', 'ไค', 'ร่', 'ไช้', 'ด้าย', 'ไจ', 'ไช', 'ไท']
#
# >Word: โอ้, len: 3, Pronunciation: ['โอ้']
# >Word: มนุษย์, len: 6, Pronunciation: ['มะ', 'นุด']
# >Word: ผู้, len: 3, Pronunciation: ['พู่']
# **Word: มี, len: 2, Pronunciation: ['มี']
# >Word: จิตใจ, len: 5, Pronunciation: ['จิด', 'ใจ']
# >Word: และ, len: 3, Pronunciation: ['และ']
# **Word: มี, len: 2, Pronunciation: ['มี']
# >Word: ความสามารถ, len: 10, Pronunciation: ['ความ', 'สา', 'มาด']
# **Word: ใน, len: 2, Pronunciation: ['ใน']
# >Word: การ, len: 3, Pronunciation: ['กาน']
# >Word: สร้างสรรค์, len: 10, Pronunciation: ['ส้าง', 'สัน']
# >Word: สิ่งใหม่, len: 8, Pronunciation: ['สิ่ง', 'ไหม่']
# Sentence: โอ้มนุษย์ผู้มีจิตใจและมีความสามารถในการสร้างสรรค์สิ่งใหม่
# Final Syllable: ['โอ้', 'มะ', 'นุด', 'พู่', 'มี', 'จิด', 'ใจ', 'และ', 'มี', 'ความ', 'สา', 'มาด', 'ใน', 'กาน', 'ส้าง', 'สัน', 'สิ่ง', 'ไหม่']
#
# ก็ - p:ก็อย, s:['ก็']
# บ่ - p:บ่อ, s:['บ่']
# ธ - p:ทอน, s:['ธ']
# ณ - p:นะ, s:['ณ']
# ฤ - p:รึ-เริฟ, s:['ฤ']
# ฤๅษี - p:รือ-สี, s:['ฤๅ', 'ษี']
# ได้ - p:ด้าย, s:['ได้']
# มนุษย์ - p:มะ-นุด, s:['มนุษย์']
# พฤติกรรม - p:พฺรึด-ติ-กำ, s:['พฤ', 'ติ', 'กรรม']
# สระ - p:สะ, s:['สระ']

# %%
from pythainlp.tokenize import subword_tokenize, syllable_tokenize

sentences = [
    "แม่รักลูกลูกก็รู้อยู่ว่ารัก",
    "คนอื่นสักหมื่นแสนไม่แม้นเหมือน", 
    "ถึงโรงเหล้าเตากลั่นควันโขมง",
    "มีคันโพงผูกสายไว้ปลายเสา", 
    "โอ้บาปกรรมน้ำนรกเจียวอกเรา",
    "ให้มัวเมาเหมือนหนึ่งบ้าเป็นน่าอาย", 
    "ทำบุญบวชกรวดน้ำขอสำเร็จ",
    "สรรเพชญโพธิญาณประมาณหมาย", 
    "ถึงสุราพารอดไม่วอดวาย",
    "ไม่ใกล้กรายแกล้งเมินก็เกินไป",
    "ความแปลกแยกและพัฒนาการ",
    "อันประกอบด้วยสระและพยัญชนะหลายตัว",
    "โอ้มนุษย์ผู้มีจิตใจอันสูงส่งและมีความสามารถในการสร้างสรรค์สิ่งใหม่"
]

print("=== Tokenization Comparison ===\n")

for sent in sentences:
    # subword_tokenize typically uses 'tcc' (Thai Character Cluster) or 'etcc'
    subword_tok = subword_tokenize(sent, engine="dict", keep_whitespace=False)
    
    # syllable_tokenize can use 'dict', 'han_solo', or 'ssg' as seen in the docs
    syllable_tok = syllable_tokenize(sent, engine="han_solo", keep_whitespace=False)
    
    print(f"Original Sentence : {sent}")
    print(f"Subword Tokens    : {subword_tok}")
    print(f"Syllable Tokens   : {syllable_tok}")
    print(f"Count             : Subword ({len(subword_tok)}) vs Syllable ({len(syllable_tok)})")
    print("-" * 60)
# Out:
# === Tokenization Comparison ===
#
# Original Sentence : แม่รักลูกลูกก็รู้อยู่ว่ารัก
# Subword Tokens    : ['แม่', 'รัก', 'ลูก', 'ลูก', 'ก็', 'รู้', 'อยู่', 'ว่า', 'รัก']
# Syllable Tokens   : ['แม่', 'รัก', 'ลูก', 'ลูก', 'ก็', 'รู้', 'อยู่', 'ว่า', 'รัก']
# Count             : Subword (9) vs Syllable (9)
# ------------------------------------------------------------
# Original Sentence : คนอื่นสักหมื่นแสนไม่แม้นเหมือน
# Subword Tokens    : ['คน', 'อื่น', 'สัก', 'หมื่น', 'แสน', 'ไม่', 'แม้น', 'เหมือน']
# Syllable Tokens   : ['คน', 'อื่น', 'สัก', 'หมื่น', 'แสน', 'ไม่', 'แม้น', 'เหมือน']
# Count             : Subword (8) vs Syllable (8)
# ------------------------------------------------------------
# Original Sentence : ถึงโรงเหล้าเตากลั่นควันโขมง
# Subword Tokens    : ['ถึง', 'โรง', 'เหล้า', 'เตา', 'กลั่น', 'ควัน', 'โขมง']
# Syllable Tokens   : ['ถึง', 'โรง', 'เหล้า', 'เตา', 'กลั่น', 'ควัน', 'โขมง']
# Count             : Subword (7) vs Syllable (7)
# ------------------------------------------------------------
# Original Sentence : มีคันโพงผูกสายไว้ปลายเสา
# Subword Tokens    : ['มี', 'คัน', 'โพง', 'ผูก', 'สาย', 'ไว้', 'ปลาย', 'เสา']
# Syllable Tokens   : ['มี', 'คัน', 'โพง', 'ผูก', 'สาย', 'ไว้', 'ปลาย', 'เสา']
# Count             : Subword (8) vs Syllable (8)
# ------------------------------------------------------------
# Original Sentence : โอ้บาปกรรมน้ำนรกเจียวอกเรา
# Subword Tokens    : ['โอ้', 'บาป', 'กรรม', 'น้ำ', 'นรก', 'เจีย', 'วอก', 'เรา']
# Syllable Tokens   : ['โอ้', 'บาป', 'กรรม', 'น้ำ', 'นรก', 'เจีย', 'วอก', 'เรา']
# Count             : Subword (8) vs Syllable (8)
# ------------------------------------------------------------
# Original Sentence : ให้มัวเมาเหมือนหนึ่งบ้าเป็นน่าอาย
# Subword Tokens    : ['ให้', 'มัว', 'เมา', 'เหมือน', 'หนึ่ง', 'บ้า', 'เป็น', 'น่า', 'อาย']
# Syllable Tokens   : ['ให้', 'มัว', 'เมา', 'เหมือน', 'หนึ่ง', 'บ้า', 'เป็น', 'น่า', 'อาย']
# Count             : Subword (9) vs Syllable (9)
# ------------------------------------------------------------
# Original Sentence : ทำบุญบวชกรวดน้ำขอสำเร็จ
# Subword Tokens    : ['ทำ', 'บุญ', 'บวช', 'กรวด', 'น้ำ', 'ขอ', 'สำ', 'เร็จ']
# Syllable Tokens   : ['ทำ', 'บุญ', 'บวช', 'กรวด', 'น้ำ', 'ขอ', 'สำ', 'เร็จ']
# Count             : Subword (8) vs Syllable (8)
# ------------------------------------------------------------
# Original Sentence : สรรเพชญโพธิญาณประมาณหมาย
# Subword Tokens    : ['สรร', 'เพช', 'ญ', 'โพ', 'ธิ', 'ญาณ', 'ประ', 'มาณ', 'หมาย']
# Syllable Tokens   : ['สรร', 'เพชญ', 'โพธิ', 'ญาณ', 'ประ', 'มาณ', 'หมาย']
# Count             : Subword (9) vs Syllable (7)
# ------------------------------------------------------------
# Original Sentence : ถึงสุราพารอดไม่วอดวาย
# Subword Tokens    : ['ถึง', 'สุ', 'รา', 'พา', 'รอด', 'ไม่', 'วอด', 'วาย']
# Syllable Tokens   : ['ถึง', 'สุ', 'รา', 'พา', 'รอด', 'ไม่', 'วอด', 'วาย']
# Count             : Subword (8) vs Syllable (8)
# ------------------------------------------------------------
# Original Sentence : ไม่ใกล้กรายแกล้งเมินก็เกินไป
# Subword Tokens    : ['ไม่', 'ใกล้', 'กราย', 'แกล้ง', 'เมิน', 'ก็', 'เกิน', 'ไป']
# Syllable Tokens   : ['ไม่', 'ใกล้ก', 'ราย', 'แกล้ง', 'เมิน', 'ก็', 'เกิน', 'ไป']
# Count             : Subword (8) vs Syllable (8)
# ------------------------------------------------------------
# Original Sentence : ความแปลกแยกและพัฒนาการ
# Subword Tokens    : ['ความ', 'แปลก', 'แยก', 'และ', 'พัฒ', 'นา', 'การ']
# Syllable Tokens   : ['ความ', 'แปลก', 'แยก', 'และ', 'พัฒ', 'นา', 'การ']
# Count             : Subword (7) vs Syllable (7)
# ------------------------------------------------------------
# Original Sentence : อันประกอบด้วยสระและพยัญชนะหลายตัว
# Subword Tokens    : ['อัน', 'ประ', 'กอบ', 'ด้วย', 'สระ', 'และ', 'พยัญ', 'ชนะ', 'หลาย', 'ตัว']
# Syllable Tokens   : ['อัน', 'ประ', 'กอบ', 'ด้วย', 'สระ', 'และ', 'พยัญ', 'ชนะ', 'หลาย', 'ตัว']
# Count             : Subword (10) vs Syllable (10)
# ------------------------------------------------------------
# Original Sentence : โอ้มนุษย์ผู้มีจิตใจอันสูงส่งและมีความสามารถในการสร้างสรรค์สิ่งใหม่
# Subword Tokens    : ['โอ้', 'มนุษย์', 'ผู้', 'มี', 'จิต', 'ใจ', 'อัน', 'สูง', 'ส่ง', 'และ', 'มี', 'ความ', 'สา', 'มารถ', 'ใน', 'การ', 'สร้าง', 'สรรค์', 'สิ่ง', 'ใหม่']
# Syllable Tokens   : ['โอ้', 'มนุษย์', 'ผู้', 'มี', 'จิต', 'ใจ', 'อัน', 'สูง', 'ส่ง', 'และ', 'มี', 'ความ', 'สา', 'มารถ', 'ใน', 'การ', 'สร้าง', 'สรรค์', 'สิ่ง', 'ใหม่']
# Count             : Subword (20) vs Syllable (20)
# ------------------------------------------------------------

# %%
from pythainlp.tokenize import word_tokenize, syllable_tokenize
from pythainlp.transliterate import pronunciate

POETRY_OVERRIDES = {
    "ก็": ["ก็"],
    "บ่": ["บ่"],
    "ได้": ["ได้"],
    "ธ": ["ทะ"],
    "ณ": ["นะ"],
    "ฤ": ["รึ"],
    "ฤๅ": ["รือ"],
    "ฤๅษี": ["รือ", "สี"],
    "มนุษย์": ["มะ", "นุด"],
    "พฤติกรรม": ["พฺรึด", "ติ", "กำ"],
    "สระ": ["สะ", "หระ"],
    "ความรู้สึก": ["ความ", "รู้", "สึก"],
    "เข้าใจ": ["เข้า", "ใจ"],
    "อยู่": ["อยู่"], # Fixes the "รู้อยู่" -> 'หยู่' hallucination
    "ผู้": ["ผู้"],   # Fixes the "ผู้ใด" -> 'พู่' hallucination
    "ใหม่": ["ใหม่"],
    "อย่า": ["อย่า"],
    "อยู่": ["อยู่"],
    "อย่าง": ["อย่าง"],
    "อยาก": ["อยาก"],
    "สุริยา": ["สุ", "ริ", "ยา"],
    "ก้ม": ["ก้ม"],
    "เดิน": ["เดิน"],
    "น้ำ": ["น้ำ"],
    "นำ": ["นำ"],
    "ทำ": ["ทำ"],
}

# %%
def process_w2p(word: str) -> list:
    """Helper function to cleanly process a string through the w2p model."""
    # pronunciate hallucination on very short words. Use syllable_tokenize instead.
    if len(word) <= 2:
        return syllable_tokenize(word, engine="ssg")
        
    phonetic_word = pronunciate(word, engine="w2p")
    
    if not phonetic_word:
        return syllable_tokenize(word, engine="ssg")
    
    # Clean up unwanted characters like Phinthu (-ฺ) and hyphens (-)
    clean_phonetic = phonetic_word.replace("ฺ", "").replace("-", "")
    
    # Using ssg (CRF segmenter) as it handles phonetic text better than dict
    phonetic_syllables = syllable_tokenize(clean_phonetic, engine="ssg")
    
    # Clean up stray 'ห' artifacts
    return [s for s in phonetic_syllables if s != "ห" or word == "ห"]

def extract_poetic_syllables(text: str) -> list:
    """Extracts phonetic syllables for Klon 8 verification."""
    # Tokenize text into words using the newmm (greedy) engine, allowing w2p to handle compound words
    words = word_tokenize(text, engine="newmm")
    final_syllables = []
    
    for word in words:
        # Direct Override if the tokenized word is in the POETRY_OVERRIDES list (O(1) Fast Lookup)
        if word in POETRY_OVERRIDES:
            final_syllables.extend(POETRY_OVERRIDES[word])
            continue

        # Use 'ssg' to check if newmm greedy engine merged words like "ได้ใจ" or "รู้อยู่"
        sub_syllables = syllable_tokenize(word, engine="ssg")
        
        # Check if ANY of the segmented syllables are in the POETRY_OVERRIDES list
        has_override = any(sub in POETRY_OVERRIDES for sub in sub_syllables)
        
        if len(sub_syllables) > 1 and has_override:
            # Found a hidden override word in the segmented syllables. Process each sub-syllable independently.
            for sub in sub_syllables:
                if sub in POETRY_OVERRIDES:
                    final_syllables.extend(POETRY_OVERRIDES[sub])
                else:
                    final_syllables.extend(process_w2p(sub))
            continue
        
        # If no overrides were found inside, treat it as a true compound word (e.g. พัฒนาการ)
        # Proceed to parse the word into w2p pronunciate engine.
        final_syllables.extend(process_w2p(word))
        
    return final_syllables

# %%
# Test sentences
sentence = [
    "ปรเมศวร์ ปรเมษฐ์",
    "ปรมาณู ปรมาตมัน ปรมาภิไธย",
    "สกวาทยาจารย์ สกวาที ปรวาที ปรวาทยาจารย์",
    "ปรปักษ์ ปรโลก จรลี ทรยศ ทรพี นรสิงห์ หรดี อรทัย",
    "สรรเพชญโพธิญาณประมาณหมาย", 
    "บ่มีผู้ใดจะเข้าใจความรู้สึกของข้าได้",
    "ไหนใครใคร่ใช้ได้ใจชัยไทย",
    "โอ้มนุษย์ผู้มีจิตใจและมีความสามารถในการสร้างสรรค์สิ่งใหม่",
    "ความแปลกแยกและพัฒนาการ",
    "อย่าอยู่อย่างอยากหมากหมิ่นหมายหมอง",
    "อันประกอบด้วยสระและพยัญชนะหลายตัว",
]

for sent in sentence:
    syllables = extract_poetic_syllables(sent)
    print(f"Sentence: {sent}")
    print(f"Final Syllable: {syllables}\n")
# Out:
# Sentence: ปรเมศวร์ ปรเมษฐ์
# Final Syllable: ['ปะ', 'ระ', 'เมด', ' ', 'ปอ', 'ระ', 'เมด']
#
# Sentence: ปรมาณู ปรมาตมัน ปรมาภิไธย
# Final Syllable: ['ปะ', 'ระ', 'มานู', ' ', 'ปะ', 'ระ', 'มาด', 'มัน', ' ', 'ปะ', 'ระ', 'พา', 'ไม', 'ทิ']
#
# Sentence: สกวาทยาจารย์ สกวาที ปรวาที ปรวาทยาจารย์
# Final Syllable: ['สก', 'วา', 'ทะ', 'ยา', 'จาน', ' ', 'สะ', 'กะ', 'วา', 'ที', ' ', 'ปอ', 'ระ', 'วา', 'ที', ' ', 'ปร', 'วา', 'ทะ', 'ยา', 'จาน']
#
# Sentence: ปรปักษ์ ปรโลก จรลี ทรยศ ทรพี นรสิงห์ หรดี อรทัย
# Final Syllable: ['ปอ', 'ระ', 'ปัก', ' ', 'ปะ', 'ระ', 'โลก', ' ', 'จะ', 'ระ', 'ลี', ' ', 'ทอ', 'ระ', 'ยด', ' ', 'ทอ', 'ระ', 'พี', ' ', 'นอง', 'สิง', ' ', 'หะ', 'ระ', 'ดี', ' ', 'ออ', 'ระ', 'ไท']
#
# Sentence: สรรเพชญโพธิญาณประมาณหมาย
# Final Syllable: ['สัน', 'เพ็ด', 'โพ', 'ทิ', 'ยาน', 'ประ', 'มาน', 'หมาย']
#
# Sentence: บ่มีผู้ใดจะเข้าใจความรู้สึกของข้าได้
# Final Syllable: ['บ่', 'มี', 'ผู้', 'ใด', 'จะ', 'เข้า', 'ใจ', 'ความ', 'รู้', 'สึก', 'ของ', 'ข้า', 'ได้']
#
# Sentence: ไหนใครใคร่ใช้ได้ใจชัยไทย
# Final Syllable: ['ใหน', 'ไคร', 'ไค', 'ร่', 'ไช้', 'ได้', 'ใจ', 'ไช', 'ไท']
#
# Sentence: โอ้มนุษย์ผู้มีจิตใจและมีความสามารถในการสร้างสรรค์สิ่งใหม่
# Final Syllable: ['โอ้', 'มะ', 'นุด', 'ผู้', 'มี', 'จิด', 'ใจ', 'และ', 'มี', 'ความ', 'สา', 'มาด', 'ใน', 'กาน', 'ส้าง', 'สัน', 'สิ่ง', 'ใหม่']
#
# Sentence: ความแปลกแยกและพัฒนาการ
# Final Syllable: ['ความ', 'แปลก', 'แยก', 'และ', 'พัด', 'ทะ', 'นา', 'กาน']
#
# Sentence: อย่าอยู่อย่างอยากหมากหมิ่นหมายหมอง
# Final Syllable: ['อย่า', 'อยู่', 'อย่าง', 'อยาก', 'หมาก', 'หมิ่น', 'หมาย', 'หมอง']
#
# Sentence: อันประกอบด้วยสระและพยัญชนะหลายตัว
# Final Syllable: ['อัน', 'ประ', 'กอบ', 'ด้วย', 'สะ', 'หระ', 'และ', 'พะ', 'ยัน', 'ชะ', 'นะ', 'หลาย', 'ตัว']

# %%
import csv
import io
from pythainlp.tokenize import word_tokenize, syllable_tokenize
from pythainlp.transliterate import pronunciate
from pythainlp.khavee import KhaveeVerifier

# Initialize Khavee for Rhyme Checking
kv = KhaveeVerifier()

def check_internal_klon8_rhymes(waks):
    """
    Goal 2: Automatically verify Klon 8 internal stanza rhymes using Khavee.
    Klon 8 Rule: 
    - Last syllable of Wak 1 rhymes with 3rd or 5th syllable of Wak 2
    - Last syllable of Wak 2 rhymes with Last syllable of Wak 3
    - Last syllable of Wak 3 rhymes with 3rd or 5th syllable of Wak 4
    """
    print("\n  [Rhyme Verification - Stanza 1 (Waks 1-4)]")
    
    # 1. Wak 1 End -> Wak 2 (3rd or 5th)
    w1_end = waks[1]["flat_syllables"][-1]
    w2_target_3 = waks[2]["flat_syllables"][2] if len(waks[2]["flat_syllables"]) > 2 else ""
    w2_target_5 = waks[2]["flat_syllables"][4] if len(waks[2]["flat_syllables"]) > 4 else ""
    
    match_w2 = kv.is_sumpus(w1_end, w2_target_3) or kv.is_sumpus(w1_end, w2_target_5)
    print(f"  - Wak 1->2 ({w1_end} -> {w2_target_3}/{w2_target_5}): {'✅ Pass' if match_w2 else '❌ Fail'}")

    # 2. Wak 2 End -> Wak 3 End
    w2_end = waks[2]["flat_syllables"][-1]
    w3_end = waks[3]["flat_syllables"][-1]
    match_w3 = kv.is_sumpus(w2_end, w3_end)
    print(f"  - Wak 2->3 ({w2_end} -> {w3_end}): {'✅ Pass' if match_w3 else '❌ Fail'}")

    # 3. Wak 3 End -> Wak 4 (3rd or 5th)
    w4_target_3 = waks[4]["flat_syllables"][2] if len(waks[4]["flat_syllables"]) > 2 else ""
    w4_target_5 = waks[4]["flat_syllables"][4] if len(waks[4]["flat_syllables"]) > 4 else ""
    match_w4 = kv.is_sumpus(w3_end, w4_target_3) or kv.is_sumpus(w3_end, w4_target_5)
    print(f"  - Wak 3->4 ({w3_end} -> {w4_target_3}/{w4_target_5}): {'✅ Pass' if match_w4 else '❌ Fail'}")


# ==========================================
# MAIN EXECUTION
# ==========================================

# csv_data = """w1_a,w1_b,w1_c,w2_a,w2_b,w2_c,w3_a,w3_b,w3_c,w4_a,w4_b,w4_c,w5_a,w5_b,w5_c,w6_a,w6_b,w6_c,w7_a,w7_b,w7_c,w8_a,w8_b,w8_c
# สมเด็จท้าว,บิตุรงค์,ดำรงราชย์,แสนสวาท,ลูกน้อย,เสน่หา,จะเสกสอง,ครองสมบัติ,ขัตติยา,แต่วิชา,สิ่งใด,ไม่ชำนาญ,จึงดำรัส,เรียกพระ,โอรสราช,มาริมอาสน์,แท่นสุวรรณ,แล้วบรรหาร,พ่อจะแจ้ง,เจ้าจงจำ,คำโบราณ,อันชายชาญ,เชื้อกษัตริย์,ขัตติยา
# แล้วก้มกราบ,บิตุราช,มาตุรงค์,ทั้งสององค์,ลูบหลัง,แล้วสั่งสอน,จะเดินทาง,กลางป่า,พนาดร,จงผันผ่อน,ตรึกจำ,คำโบราณ,จะพูดจา,สารพัด,บำหยัดยั้ง,จนลุกนั่ง,น้ำท่า,กระยาหาร,แม้นหลับนอน,ผ่อนพ้น,ที่ภัยพาล,อดบันดาล,โกรธขึ้ง,จึงสบาย"""
csv_path = "E:\\User\\Noto\\SIIT\\SIIT_Year_4\\LLM_WritePoem\\phraAphai_1_export.csv"

with open(csv_path, newline="", encoding="utf-8-sig") as f:
    reader = csv.DictReader(f)

    for row_idx, row in enumerate(reader):
        print(f"\n{'='*50}\nSTANZA {row_idx + 1}\n{'='*50}")
        
        # Dictionary to hold the structured waks for this row (1-indexed for clarity)
        waks_data = {}
        
        for i in range(1, 9):
            # Extract the 3 segments of the wak
            parts = [row[f'w{i}_a'], row[f'w{i}_b'], row[f'w{i}_c']]
            
            # Segment each part independently
            syllabled_parts = [extract_poetic_syllables(part) for part in parts]
            flat_syllables = [s for part_syls in syllabled_parts for s in part_syls]
            
            waks_data[i] = {
                "text_parts": parts,
                "syllabled_parts": syllabled_parts,
                "flat_syllables": flat_syllables
            }
            
            # Goal 1: Visualize the Segmentation
            text_display = " | ".join(parts)
            syl_display = " | ".join(["-".join(s) for s in syllabled_parts])
            
            print(f"Wak {i}: {text_display}")
            print(f"       [{syl_display}]")
            print("-" * 30)

        # Goal 2: Verify the rhymes
        check_internal_klon8_rhymes(waks_data)
# Out:
# ==================================================
# STANZA 1
# ==================================================
# Wak 1: สมเด็จท้าว | บิตุรงค์ | ดำรงราชย์
#        [สม-เด็ด-ท้าว | บิ-ตุ-รง | ดำ-รง-ราด]
# ------------------------------
# Wak 2: แสนสวาท | ลูกน้อย | เสน่หา
#        [แสน-สะ-หวาด | ลูก-น้อย | สะ-เหน่-หา]
# ------------------------------
# Wak 3: จะเสกสอง | ครองสมบัติ | ขัตติยา
#        [จะ-เสก-สอง | ครอง-สม-บัด | ขัด-ติ-ยา]
# ------------------------------
# Wak 4: แต่วิชา | สิ่งใด | ไม่ชำนาญ
#        [แต่-วิ-ชา | สิ่ง-ได | ไม่-ชำ-นาน]
# ------------------------------
# Wak 5: จึงดำรัส | เรียกพระ | โอรสราช
#        [จึง-ดำ-รัด | เรียก-พระ | โอ-รด-ราด]
# ------------------------------
# Wak 6: มาริมอาสน์ | แท่นสุวรรณ | แล้วบรรหาร
#        [มา-ริม-อาด | แท่น-สุ-วัน | แล้ว-บัน-หาร]
# ------------------------------
# Wak 7: พ่อจะแจ้ง | เจ้าจงจำ | คำโบราณ
#        [พ่อ-จะ-แจ้ง | เจ้า-จง-จำ | คำ-โบ-ราน]
# ------------------------------
# Wak 8: อันชายชาญ | เชื้อกษัตริย์ | ขัตติยา
#        [อัน-ชาย-ชาน | เชื้อ-กะ-สัด | ขัด-ติ-ยา]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (ราด -> หวาด/น้อย): ✅ Pass
#   - Wak 2->3 (หา -> ยา): ✅ Pass
#   - Wak 3->4 (ยา -> ชา/ได): ✅ Pass
#
# ==================================================
# STANZA 2
# ==================================================
# Wak 1: แล้วก้มกราบ | บิตุราช | มาตุรงค์
#        [แล้ว-ก้ม-กราบ | บิ-ตุ-ราด | มา-ตุ-รง]
# ------------------------------
# Wak 2: ทั้งสององค์ | ลูบหลัง | แล้วสั่งสอน
#        [ทั้ง-สอง-อง | ลูบ-หลัง | แล้ว-สั่ง-สอน]
# ------------------------------
# Wak 3: จะเดินทาง | กลางป่า | พนาดร
#        [จะ-เดิน-ทาง | กลาง-ป่า | พะ-นา-ดอน]
# ------------------------------
# Wak 4: จงผันผ่อน | ตรึกจำ | คำโบราณ
#        [จง-ผัน-ผ่อน | ตรึก-จำ | คำ-โบ-ราน]
# ------------------------------
# Wak 5: จะพูดจา | สารพัด | บำหยัดยั้ง
#        [จะ-พูด-จา | สา-ระ-พัด | บำ-หยัด-ยั้ง]
# ------------------------------
# Wak 6: จนลุกนั่ง | น้ำท่า | กระยาหาร
#        [จน-ลุก-นั่ง | น้ำ-ท่า | กระ-ยา-หาน]
# ------------------------------
# Wak 7: แม้นหลับนอน | ผ่อนพ้น | ที่ภัยพาล
#        [แม้น-หลับ-นอน | ผ่อน-พ้น | ที่-ไพ-พาน]
# ------------------------------
# Wak 8: อดบันดาล | โกรธขึ้ง | จึงสบาย
#        [อด-บัน-ดาน | โกรด-ขึ้ง | จึง-สะ-บาย]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (รง -> อง/หลัง): ✅ Pass
#   - Wak 2->3 (สอน -> ดอน): ✅ Pass
#   - Wak 3->4 (ดอน -> ผ่อน/จำ): ✅ Pass
#
# ==================================================
# STANZA 3
# ==================================================
# Wak 1: จะพูดจา | สารพัด | บำหยัดยั้ง
#        [จะ-พูด-จา | สา-ระ-พัด | บำ-หยัด-ยั้ง]
# ------------------------------
# Wak 2: จนลุกนั่ง | น้ำท่า | กระยาหาร
#        [จน-ลุก-นั่ง | น้ำ-ท่า | กระ-ยา-หาน]
# ------------------------------
# Wak 3: แม้นหลับนอน | ผ่อนพ้น | ที่ภัยพาล
#        [แม้น-หลับ-นอน | ผ่อน-พ้น | ที่-ไพ-พาน]
# ------------------------------
# Wak 4: อดบันดาล | โกรธขึ้ง | จึงสบาย
#        [อด-บัน-ดาน | โกรด-ขึ้ง | จึง-สะ-บาย]
# ------------------------------
# Wak 5: พระพี่น้อง | สององค์ | ทรงสดับ
#        [พระ-พี่-น้อง | สอง-อง | ทรง-สะ-ดับ]
# ------------------------------
# Wak 6: เคารพรับ | บังคมด้วย | สมหมาย
#        [เคา-รบ-รับ | บัง-คม-ด้วย | สม-มะ-หยา]
# ------------------------------
# Wak 7: พระเชษฐา | บัญชา | ชวนน้องชาย
#        [พระ-เชด-ถา | บัน-ชา | ชวน-น้อง-ชาย]
# ------------------------------
# Wak 8: มาสรงสาย | สาคเรศ | บนเตียงรอง
#        [มา-สง-สาย | สา-คะ-เรด | บน-เตียง-รอง]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (ยั้ง -> นั่ง/ท่า): ✅ Pass
#   - Wak 2->3 (หาน -> พาน): ✅ Pass
#   - Wak 3->4 (พาน -> ดาน/ขึ้ง): ✅ Pass
#
# ==================================================
# STANZA 4
# ==================================================
# Wak 1: พระพี่น้อง | สององค์ | ทรงสดับ
#        [พระ-พี่-น้อง | สอง-อง | ทรง-สะ-ดับ]
# ------------------------------
# Wak 2: เคารพรับ | บังคมด้วย | สมหมาย
#        [เคา-รบ-รับ | บัง-คม-ด้วย | สม-มะ-หยา]
# ------------------------------
# Wak 3: พระเชษฐา | บัญชา | ชวนน้องชาย
#        [พระ-เชด-ถา | บัน-ชา | ชวน-น้อง-ชาย]
# ------------------------------
# Wak 4: มาสรงสาย | สาคเรศ | บนเตียงรอง
#        [มา-สง-สาย | สา-คะ-เรด | บน-เตียง-รอง]
# ------------------------------
# Wak 5: แล้วแต่งองค์ | สอดทรง | เครื่องกษัตริย์
#        [แล้ว-แต่ง-อง | สอด-ทรง | เครื่อง-กะ-สัด]
# ------------------------------
# Wak 6: เนาวรัตน์ | เรืองศรี | ไม่มีสอง
#        [เนา-วะ-รัด | เรือง-สี | ไม่-มี-สอง]
# ------------------------------
# Wak 7: แล้วลีลา | มาสถิต | บนแท่นทอง
#        [แล้ว-ลี-ลา | มา-สะ-ถิด | บน-แท่น-ทอง]
# ------------------------------
# Wak 8: จนย่ำฆ้อง | สุริยน | สนธยา
#        [จน-ย่ำ-ค้อง | สุ-ริ-ยน | สน-ทะ-ยา]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (ดับ -> รับ/คม): ✅ Pass
#   - Wak 2->3 (หยา -> ชาย): ❌ Fail
#   - Wak 3->4 (ชาย -> สาย/คะ): ✅ Pass
#
# ==================================================
# STANZA 5
# ==================================================
# Wak 1: ล่วงตำบล | ชนบท | ไปหลายบ้าน
#        [ล่วง-ตำ-บน | ชน-นะ-บด | ไป-หลาย-บ้าน]
# ------------------------------
# Wak 2: เข้าดอนด่าน | แดนไพร | พอไก่ขัน
#        [เข้า-ดอน-ด่าน | แดน-ไพร | พอ-ไก่-ขัน]
# ------------------------------
# Wak 3: เสียงเสือกวาง | กลางเนิน | พนมวัน
#        [เสียง-เสือ-กวาง | กลาง-เนิน | พะ-นม-วัน]
# ------------------------------
# Wak 4: ให้หวั่นหวั่น | วังเวง | หวาดฤทัย
#        [ไห้-หวั่น-หวั่น | วัง-เวง | หวาด-รึ-ไท]
# ------------------------------
# Wak 5: จนแสงทอง | รองเรือง | อร่ามฟ้า
#        [จน-แสง-ทอง | รอง-เรือง | อะ-หร่าม-ฟ้า]
# ------------------------------
# Wak 6: พระสุริ | ยาเยื้องเยี่ยม | เหลี่ยมไศล
#        [พระ-สุ-ริ | ยา-เยื้อง-เยี่ยม | เหลี่ยม-สะ-ไหล]
# ------------------------------
# Wak 7: คณานก | เริงร้อง | คะนองไพร
#        [คะ-นา-กน | เริง-ร้อง | คะ-นอง-ไพร]
# ------------------------------
# Wak 8: เสียงเรไร | จักจั่น | สนั่นเนิน
#        [เสียง-เร-ไร | จัก-จั่น | สะ-หนั่น-เนิน]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (บ้าน -> ด่าน/ไพร): ✅ Pass
#   - Wak 2->3 (ขัน -> วัน): ✅ Pass
#   - Wak 3->4 (วัน -> หวั่น/เวง): ✅ Pass
#
# ==================================================
# STANZA 6
# ==================================================
# Wak 1: บ้างผลิดอก | ออกผล | พวงระย้า
#        [บ้าง-ผลิ-ดอก | ออก-ผน | พวง-ระ-ย้า]
# ------------------------------
# Wak 2: ปีบจำปา | สุกรม | นมสวรรค์
#        [ปีบ-จำ-ปา | สุ-กรม | นม-สะ-หวัน]
# ------------------------------
# Wak 3: พระอภัย | มณี | ศรีสุวรรณ
#        [พระ-อะ-ไพ | มะ-นี | สี-สุ-วัน]
# ------------------------------
# Wak 4: ต่างชิงกัน | เก็บพลาง | ตามทางมา
#        [ต่าง-ชิง-กัน | เก็บ-พลาง | ตาม-ทาง-มา]
# ------------------------------
# Wak 5: พระพี่เก็บ | กาหลง | ส่งให้น้อง
#        [พระ-พี่-เก็บ | กา-หลง | ส่ง-ไห้-น้อง]
# ------------------------------
# Wak 6: เดินประคอง | เคียงกัน | ด้วยหรรษา
#        [เดิน-ประ-คอง | เคียง-กัน | ด้วย-หัน-สา]
# ------------------------------
# Wak 7: พระน้องเก็บ | มะลุลี | ให้พี่ยา
#        [พระ-น้อง-เก็บ | มะ-ลุ-ลี | ไห้-พี่-ยา]
# ------------------------------
# Wak 8: ทั้งสองรา | เดินดม | แล้วชมเชย
#        [ทั้ง-สอง-รา | เดิน-ดม | แล้ว-ชม-เชย]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (ย้า -> ปา/กรม): ✅ Pass
#   - Wak 2->3 (หวัน -> วัน): ✅ Pass
#   - Wak 3->4 (วัน -> กัน/พลาง): ✅ Pass
#
# ==================================================
# STANZA 7
# ==================================================
# Wak 1: พระพี่เก็บ | กาหลง | ส่งให้น้อง
#        [พระ-พี่-เก็บ | กา-หลง | ส่ง-ไห้-น้อง]
# ------------------------------
# Wak 2: เดินประคอง | เคียงกัน | ด้วยหรรษา
#        [เดิน-ประ-คอง | เคียง-กัน | ด้วย-หัน-สา]
# ------------------------------
# Wak 3: พระน้องเก็บ | มะลุลี | ให้พี่ยา
#        [พระ-น้อง-เก็บ | มะ-ลุ-ลี | ไห้-พี่-ยา]
# ------------------------------
# Wak 4: ทั้งสองรา | เดินดม | แล้วชมเชย
#        [ทั้ง-สอง-รา | เดิน-ดม | แล้ว-ชม-เชย]
# ------------------------------
# Wak 5: เห็นมะม่วง | พวงผล | พึ่งสุกห่าม
#        [เห็น-มะ-ม่วง | พวง-ผล | พึ่ง-สุก-ห่าม]
# ------------------------------
# Wak 6: ทำไม้ง่าม | น้อยน้อย | สอยเสวย
#        [ทำ-ไม้-ง่าม | น้อย-น้อย | สอย-สะ-เหวย]
# ------------------------------
# Wak 7: อร่อยหวาน | ปานเปรียบ | รสนมเนย
#        [อะ-หร็่อย-หวาน | ปาน-เปรียบ | รส-นม-เนย]
# ------------------------------
# Wak 8: อิ่มแล้วเลย | ล่วงทาง | มากลางดง
#        [อิ่ม-แล้ว-เลย | ล่วง-ทาง | มา-กลาง-ดง]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (น้อง -> คอง/กัน): ✅ Pass
#   - Wak 2->3 (สา -> ยา): ✅ Pass
#   - Wak 3->4 (ยา -> รา/ดม): ✅ Pass
#
# ==================================================
# STANZA 8
# ==================================================
# Wak 1: เห็นมะม่วง | พวงผล | พึ่งสุกห่าม
#        [เห็น-มะ-ม่วง | พวง-ผล | พึ่ง-สุก-ห่าม]
# ------------------------------
# Wak 2: ทำไม้ง่าม | น้อยน้อย | สอยเสวย
#        [ทำ-ไม้-ง่าม | น้อย-น้อย | สอย-สะ-เหวย]
# ------------------------------
# Wak 3: อร่อยหวาน | ปานเปรียบ | รสนมเนย
#        [อะ-หร็่อย-หวาน | ปาน-เปรียบ | รส-นม-เนย]
# ------------------------------
# Wak 4: อิ่มแล้วเลย | ล่วงทาง | มากลางดง
#        [อิ่ม-แล้ว-เลย | ล่วง-ทาง | มา-กลาง-ดง]
# ------------------------------
# Wak 5: ครั้นสิ้นแสง | สุริยา | ทิพากร
#        [ครั้น-สิ้น-แสง | สุ-ริ-ยา | ทิ-พา-กอน]
# ------------------------------
# Wak 6: สำนักนอน | เนินผา | ป่าระหง
#        [สำ-นัก-นอน | เนิน-ผา | ป่า-ระ-หง]
# ------------------------------
# Wak 7: ทั้งสองแสน | เหนื่อยยาก | ลำบากองค์
#        [ทั้ง-สอง-แสน | เหนื่อย-ยาก | ลำ-บาก-อง]
# ------------------------------
# Wak 8: บาทบงสุ์ | บวมบอบ | ระบมตรม
#        [บาด-ทะ-บุ | บวม-บอบ | ระ-บม-ตร-ม]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (ห่าม -> ง่าม/น้อย): ✅ Pass
#   - Wak 2->3 (เหวย -> เนย): ✅ Pass
#   - Wak 3->4 (เนย -> เลย/ทาง): ✅ Pass
#
# ==================================================
# STANZA 9
# ==================================================
# Wak 1: ครั้นสิ้นแสง | สุริยา | ทิพากร
#        [ครั้น-สิ้น-แสง | สุ-ริ-ยา | ทิ-พา-กอน]
# ------------------------------
# Wak 2: สำนักนอน | เนินผา | ป่าระหง
#        [สำ-นัก-นอน | เนิน-ผา | ป่า-ระ-หง]
# ------------------------------
# Wak 3: ทั้งสองแสน | เหนื่อยยาก | ลำบากองค์
#        [ทั้ง-สอง-แสน | เหนื่อย-ยาก | ลำ-บาก-อง]
# ------------------------------
# Wak 4: บาทบงสุ์ | บวมบอบ | ระบมตรม
#        [บาด-ทะ-บุ | บวม-บอบ | ระ-บม-ตร-ม]
# ------------------------------
# Wak 5: พระเชษฐา | อาลัยถึง | ไอศวรรย์
#        [พระ-เชด-ถา | อา-ไล-ถึง | ไอ-สะ-หวัน]
# ------------------------------
# Wak 6: กับกำนัล | น้อยน้อย | นางสนม
#        [กับ-กำ-นัน | น้อย-น้อย | นาง-สะ-หนม]
# ------------------------------
# Wak 7: น้องคะนึง | ถึงพี่เลี้ยง | แลนางนม
#        [น้อง-คะ-นึง | ถึง-พี่-เลี้ยง | แล-นาง-นม]
# ------------------------------
# Wak 8: กับบรม | บิตุเรศ | พระมารดา
#        [กับ-บอ-รม | บิ-ตุ-เรด | พระ-มาน-ดา]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (กอน -> นอน/ผา): ✅ Pass
#   - Wak 2->3 (หง -> อง): ✅ Pass
#   - Wak 3->4 (อง -> บุ/บอบ): ❌ Fail
#
# ==================================================
# STANZA 10
# ==================================================
# Wak 1: สิบห้าวัน | ดั้นเดิน | ในไพรสณฑ์
#        [สิบ-ห้า-วัน | ดั้น-เดิน | ใน-ไพร-สน]
# ------------------------------
# Wak 2: ถึงตำบล | บ้านหนึ่ง | ใหญ่หนักหนา
#        [ถึง-ตำ-บน | บ้าน-หนึ่ง | ใหย่-หนัก-หนา]
# ------------------------------
# Wak 3: เรียกว่าบ้าน | จันตคาม | พราหมณ์พฤฒา
#        [เรียก-ว่า-บ้าน | จัน-ต-คาม | พราม-พรึด-ทา]
# ------------------------------
# Wak 4: มีทิศา | ปาโมกข์ | อยู่สองคน
#        [มี-ทิ-สา | ปา-โมก | อยู่-สอง-คน]
# ------------------------------
# Wak 5: อาจารย์หนึ่ง | ชำนาญ | ในการยุทธ์
#        [อา-จาน-หนึ่ง | ชำ-นาน | ใน-กาน-ยุด]
# ------------------------------
# Wak 6: ถึงอาวุธ | ซัดมา | ดั่งห่าฝน
#        [ถึง-อา-วุด | ซัด-มา | ดั่ง-ห่า-ฝน]
# ------------------------------
# Wak 7: รำกระบอง | ป้องกัน | กายสกนธ์
#        [รำ-กระ-บอง | ป้อง-กัน | กาย-สะ-กน]
# ------------------------------
# Wak 8: รักษาตน | มิให้ต้อง | คมศัสตรา
#        [รัก-ษา-ตน | มิ-ไห้-ต้อง | คม-สัด-ตรา]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (สน -> บน/หนึ่ง): ✅ Pass
#   - Wak 2->3 (หนา -> ทา): ✅ Pass
#   - Wak 3->4 (ทา -> สา/โมก): ✅ Pass
#
# ==================================================
# STANZA 11
# ==================================================
# Wak 1: อาจารย์หนึ่ง | ชำนาญ | ในการยุทธ์
#        [อา-จาน-หนึ่ง | ชำ-นาน | ใน-กาน-ยุด]
# ------------------------------
# Wak 2: ถึงอาวุธ | ซัดมา | ดั่งห่าฝน
#        [ถึง-อา-วุด | ซัด-มา | ดั่ง-ห่า-ฝน]
# ------------------------------
# Wak 3: รำกระบอง | ป้องกัน | กายสกนธ์
#        [รำ-กระ-บอง | ป้อง-กัน | กาย-สะ-กน]
# ------------------------------
# Wak 4: รักษาตน | มิให้ต้อง | คมศัสตรา
#        [รัก-ษา-ตน | มิ-ไห้-ต้อง | คม-สัด-ตรา]
# ------------------------------
# Wak 5: อาจารย์หนึ่ง | ชำนาญ | ในการปี่
#        [อา-จาน-หนึ่ง | ชำ-นาน | ใน-กาน-ปี่]
# ------------------------------
# Wak 6: ทั้งดีดสี | แสนเสนาะ | เพราะหนักหนา
#        [ทั้ง-ดีด-สี | แสน-เสนาะ | เพราะ-หนัก-หนา]
# ------------------------------
# Wak 7: ผู้ใดฟัง | วังเวงใน | วิญญาณ์
#        [ผู้-ใด-ฟัง | วัง-เวง-ใน | วิ-ยะ-ยา]
# ------------------------------
# Wak 8: เคลิ้มนิทรา | ลืมกาย | ดังวายปราณ
#        [เคลิ้ม-นิด-ซา | ลืม-กาย | ดัง-วาย-ปราน]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (ยุด -> วุด/มา): ✅ Pass
#   - Wak 2->3 (ฝน -> กน): ✅ Pass
#   - Wak 3->4 (กน -> ตน/ไห้): ✅ Pass
#
# ==================================================
# STANZA 12
# ==================================================
# Wak 1: เห็นแผ่นผา | จารึก | ลายลิขิต
#        [เห็น-แผ่น-ผา | จา-รึก | ลาย-ลิ-ขิด]
# ------------------------------
# Wak 2: เข้ายืนชิด | อ่านดู | รู้ประจักษ์
#        [เข้า-ยืน-ชิด | อ่าน-ดู | รู้-ประ-จัก]
# ------------------------------
# Wak 3: ท่านอาจารย์ | การกระบอง | ก็คล่องนัก
#        [ทั่น-อา-จาน | กาน-กระ-บอง | ก็-คล่อง-นัก]
# ------------------------------
# Wak 4: ได้ทองหนัก | แสนตำลึง | จึงได้เรียน
#        [ได้-ทอง-หนัก | แสน-ตำ-ลึง | จึง-ได้-เรียน]
# ------------------------------
# Wak 5: จึงบัญชา | ว่ากับ | พระน้องแก้ว
#        [จึง-บัน-ชา | ว่า-กับ | พระ-น้อง-แก้ว]
# ------------------------------
# Wak 6: พ่อเห็นแล้ว | หรือที่ลาย | ลิขิตเขียน
#        [พ่อ-เห็น-แล้ว | หรือ-ที่-ลาย | ลิ-ขิด-เขียน]
# ------------------------------
# Wak 7: สองอาจารย์ | ปานดวง | แก้ววิเชียร
#        [สอง-อา-จาน | ปาน-ดวง | แก้ว-วิ-เชียน]
# ------------------------------
# Wak 8: เจ้ารักเรียน | ที่ท่าน | อาจารย์ใด
#        [เจ้า-รัก-เรียน | ที่-ทั่น | อา-จาน-ใด]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (ขิด -> ชิด/ดู): ✅ Pass
#   - Wak 2->3 (จัก -> นัก): ✅ Pass
#   - Wak 3->4 (นัก -> หนัก/ตำ): ✅ Pass
#
# ==================================================
# STANZA 13
# ==================================================
# Wak 1: พระเชษฐา | ว่าจริง | แล้วเจ้าพี่
#        [พระ-เชด-ถา | ว่า-จิง | แล้ว-เจ้า-พี่]
# ------------------------------
# Wak 2: วิชามี | แล้วใคร | ไม่ข่มเหง
#        [วิ-ชา-มี | แล้ว-ไคร | ไม่-ข่ม-เหง]
# ------------------------------
# Wak 3: แต่ใจพี่ | นี้รัก | ทางนักเลง
#        [แต่-ใจ-พี่ | นี้-รัก | ทาง-นัก-เลง]
# ------------------------------
# Wak 4: หมายว่าเพลง | ดนตรี | นี้ดีจริง
#        [หมาย-ว่า-เพลง | ดน-ตรี | นี้-ดี-จิง]
# ------------------------------
# Wak 5: ถึงการเล่น | เป็นที่ | ประโลมโลก
#        [ถึง-กาน-เล่น | เป็น-ที่ | ประ-โลม-มะ-โกล]
# ------------------------------
# Wak 6: ได้ดับโศก | สูญหาย | ทั้งชายหญิง
#        [ได้-ดับ-โสก | สูน-หาย | ทั้ง-ชาย-หยิง]
# ------------------------------
# Wak 7: แต่ขัดสน | จนจิต | คิดประวิง
#        [แต่-ขัด-สน | จน-จิด | คิด-ประ-วิง]
# ------------------------------
# Wak 8: ด้วยทรัพย์สิ่ง | หนึ่งนี้ | ไม่มีมา
#        [ด้วย-ทรับ-สิ่ง | หนึ่ง-นี้ | ไม่-มี-มา]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (พี่ -> มี/ไคร): ✅ Pass
#   - Wak 2->3 (เหง -> เลง): ✅ Pass
#   - Wak 3->4 (เลง -> เพลง/ตรี): ✅ Pass
#
# ==================================================
# STANZA 14
# ==================================================
# Wak 1: พระอภัย | ได้คิด | ถึงคำน้อง
#        [พระ-อะ-ไพ | ได้-คิด | ถึง-คำ-น้อง]
# ------------------------------
# Wak 2: ต่างยิ้มย่อง | ปรีดิ์เปรม | เกษมศานต์
#        [ต่าง-ยิ้ม-ย่อง | ปรี-เปรม | กะ-เสม-สาน]
# ------------------------------
# Wak 3: เข้าหยุดยั้ง | สั่งเสีย | กันเสร็จการ
#        [เข้า-หยุด-ยั้ง | สั่ง-เสีย | กัน-เส็ด-กาน]
# ------------------------------
# Wak 4: กลับไป | หาอาจารย์ | ดังใจนึก
#        [กะ-หลับ-ไป | หา-อา-จาน | ดัง-ไจ-นึก]
# ------------------------------
# Wak 5: ศรีสุวรรณ | กุมาร | ชาญฉลาด
#        [สี-สุ-วัน | กุ-มาน | ชาน-ฉะ-หลาด]
# ------------------------------
# Wak 6: ยุรยาตร | เยื้องย่าง | มาข้างตึก
#        [ยุ-ระ-ยา-ด | เยื้อ-ย่าง | มา-ข้าง-ตึก]
# ------------------------------
# Wak 7: เห็นภูมิฐาน | เคหา | โอฬารึก
#        [เห็น-พูม-ถาน | เค-หา | โอ-รา-ลึก]
# ------------------------------
# Wak 8: ทั้งที่ฝึก | สอนสา | นุศิษย์มี
#        [ทั้ง-ที่-ฝึก | สอน-สา | นุ-สิด-มี]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (น้อง -> ย่อง/เปรม): ✅ Pass
#   - Wak 2->3 (สาน -> กาน): ✅ Pass
#   - Wak 3->4 (กาน -> ไป/อา): ❌ Fail
#
# ==================================================
# STANZA 15
# ==================================================
# Wak 1: ศรีสุวรรณ | กุมาร | ชาญฉลาด
#        [สี-สุ-วัน | กุ-มาน | ชาน-ฉะ-หลาด]
# ------------------------------
# Wak 2: ยุรยาตร | เยื้องย่าง | มาข้างตึก
#        [ยุ-ระ-ยา-ด | เยื้อ-ย่าง | มา-ข้าง-ตึก]
# ------------------------------
# Wak 3: เห็นภูมิฐาน | เคหา | โอฬารึก
#        [เห็น-พูม-ถาน | เค-หา | โอ-รา-ลึก]
# ------------------------------
# Wak 4: ทั้งที่ฝึก | สอนสา | นุศิษย์มี
#        [ทั้ง-ที่-ฝึก | สอน-สา | นุ-สิด-มี]
# ------------------------------
# Wak 5: มองเขม้น | เห็นพราหมณ์ | พฤฒาเฒ่า
#        [มอง-ขะ-เม่น | เห็น-พราม | พรึด-ทา-เท่า]
# ------------------------------
# Wak 6: กระหมวดเกล้า | เอนหลัง | นั่งเก้าอี้
#        [กระ-หมวด-เกล้า | เอ-หนอง | นั่ง-เก้า-อี้]
# ------------------------------
# Wak 7: ดูรูปร่าง | อย่างเยี่ยง | พระโยคี
#        [ดู-รูบ-ร่าง | อย่าง-เยี่ยง | พระ-โย-คี]
# ------------------------------
# Wak 8: กระบองสี่ | ศอกวาง | ไว้ข้างกาย
#        [กระ-บอง-สี่ | ศอ-กวาง | ไว้-ข้าง-กาย]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (หลาด -> ยา/เยื้อ): ❌ Fail
#   - Wak 2->3 (ตึก -> ลึก): ✅ Pass
#   - Wak 3->4 (ลึก -> ฝึก/สา): ✅ Pass
#
# ==================================================
# STANZA 16
# ==================================================
# Wak 1: มองเขม้น | เห็นพราหมณ์ | พฤฒาเฒ่า
#        [มอง-ขะ-เม่น | เห็น-พราม | พรึด-ทา-เท่า]
# ------------------------------
# Wak 2: กระหมวดเกล้า | เอนหลัง | นั่งเก้าอี้
#        [กระ-หมวด-เกล้า | เอ-หนอง | นั่ง-เก้า-อี้]
# ------------------------------
# Wak 3: ดูรูปร่าง | อย่างเยี่ยง | พระโยคี
#        [ดู-รูบ-ร่าง | อย่าง-เยี่ยง | พระ-โย-คี]
# ------------------------------
# Wak 4: กระบองสี่ | ศอกวาง | ไว้ข้างกาย
#        [กระ-บอง-สี่ | ศอ-กวาง | ไว้-ข้าง-กาย]
# ------------------------------
# Wak 5: ก็แจ้งว่า | อาจารย์ | เจ้าของตึก
#        [ก็-แจ้ง-ว่า | อา-จาน | เจ้า-ของ-ตึก]
# ------------------------------
# Wak 6: เห็นสมนึก | เหมือนจิต | ที่คิดหมาย
#        [เห็น-สม-นึก | เหมือน-จิด | ที่-คิด-หมาย]
# ------------------------------
# Wak 7: กระทั่งไอ | ให้เสียง | เป็นแยบคาย
#        [กระ-ทั่ง-ไอ | ไส้-เสียง | เป็น-แยก-คาย]
# ------------------------------
# Wak 8: แล้วก้มกาย | เข้าไปหา | ท่านอาจารย์
#        [แล้ว-ก้ม-กาย | เข้า-ไป-หา | ทั่น-อา-จาน]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (เท่า -> เกล้า/หนอง): ✅ Pass
#   - Wak 2->3 (อี้ -> คี): ✅ Pass
#   - Wak 3->4 (คี -> สี่/กวาง): ✅ Pass
#
# ==================================================
# STANZA 17
# ==================================================
# Wak 1: หน่อกษัตริย์ | ขัตติย์วงศ์ | ทรงสดับ
#        [หน่อ-กะ-สัด | ขัด-ติ-วง | ทรง-สะ-ดับ]
# ------------------------------
# Wak 2: น้อมคำนับ | เล่าแจ้ง | แถลงไข
#        [น้อม-คำ-นับ | เล่า-แจ้ง | แถน-ลง-ไข]
# ------------------------------
# Wak 3: พระบิดา | ข้าบำรุง | ซึ่งกรุงไกร
#        [พระ-บิ-ดา | ข้า-บำ-รุง | ซึ่ง-กรุง-ไกร]
# ------------------------------
# Wak 4: บัญชาให้ | เที่ยวหา | วิชาการ
#        [บัน-ชา-ไห้ | เที่ยว-หา | วิ-ชา-กาน]
# ------------------------------
# Wak 5: จึงดั้นเดิน | เนินป่า | มาถึงนี่
#        [จึง-ดั้น-เดิน | เนิน-ป่า | มา-ถึง-นี่]
# ------------------------------
# Wak 6: พอเห็นมี | อักขรา | อยู่หน้าบ้าน
#        [พอ-เห็น-มี | อัก-ข-รา | อยู่-น่า-บ้าน]
# ------------------------------
# Wak 7: รู้ว่าท่าน | พฤฒา | เป็นอาจารย์
#        [รู้-ว่า-ทั่น | พรึด-ทา | เป็น-อา-จาน]
# ------------------------------
# Wak 8: ขอประทาน | พากเพียร | เรียนวิชา
#        [ขอ-ประ-ทาน | พาก-เพียน | เรียน-วิ-ชา]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (ดับ -> นับ/แจ้ง): ✅ Pass
#   - Wak 2->3 (ไข -> ไกร): ✅ Pass
#   - Wak 3->4 (ไกร -> ไห้/หา): ✅ Pass
#
# ==================================================
# STANZA 18
# ==================================================
# Wak 1: จึงดั้นเดิน | เนินป่า | มาถึงนี่
#        [จึง-ดั้น-เดิน | เนิน-ป่า | มา-ถึง-นี่]
# ------------------------------
# Wak 2: พอเห็นมี | อักขรา | อยู่หน้าบ้าน
#        [พอ-เห็น-มี | อัก-ข-รา | อยู่-น่า-บ้าน]
# ------------------------------
# Wak 3: รู้ว่าท่าน | พฤฒา | เป็นอาจารย์
#        [รู้-ว่า-ทั่น | พรึด-ทา | เป็น-อา-จาน]
# ------------------------------
# Wak 4: ขอประทาน | พากเพียร | เรียนวิชา
#        [ขอ-ประ-ทาน | พาก-เพียน | เรียน-วิ-ชา]
# ------------------------------
# Wak 5: แต่โปรดเกล้า | คราวมา | ข้ายากแค้น
#        [แต่-โปรด-เก-ล้า | คราว-มา | ข้า-ยาก-แค้น]
# ------------------------------
# Wak 6: อันทองแสน | ตำลึงนั้น | ไม่ทันหา
#        [อัน-ทอง-แสน | ตำ-ลึง-นั้น | ไม่-ทัน-หา]
# ------------------------------
# Wak 7: ธำมรงค์ | เรือนมณี | ฉันมีมา
#        [ทำ-มะ-รง | เรือน-มะ-นี | ฉัน-มี-มา]
# ------------------------------
# Wak 8: ตีราคา | ควรแสน | ตำลึงทอง
#        [ตี-รา-คา | ควน-แสน | ตำ-ลึง-ทอง]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (นี่ -> มี/ข): ✅ Pass
#   - Wak 2->3 (บ้าน -> จาน): ✅ Pass
#   - Wak 3->4 (จาน -> ทาน/เพียน): ✅ Pass
#
# ==================================================
# STANZA 19
# ==================================================
# Wak 1: แต่โปรดเกล้า | คราวมา | ข้ายากแค้น
#        [แต่-โปรด-เก-ล้า | คราว-มา | ข้า-ยาก-แค้น]
# ------------------------------
# Wak 2: อันทองแสน | ตำลึงนั้น | ไม่ทันหา
#        [อัน-ทอง-แสน | ตำ-ลึง-นั้น | ไม่-ทัน-หา]
# ------------------------------
# Wak 3: ธำมรงค์ | เรือนมณี | ฉันมีมา
#        [ทำ-มะ-รง | เรือน-มะ-นี | ฉัน-มี-มา]
# ------------------------------
# Wak 4: ตีราคา | ควรแสน | ตำลึงทอง
#        [ตี-รา-คา | ควน-แสน | ตำ-ลึง-ทอง]
# ------------------------------
# Wak 5: แล้วถอดแหวน | วงน้อย | ที่ก้อยขวา
#        [แล้ว-ถอด-แหวน | วง-น้อย | ที่-ก้อย-ขวา]
# ------------------------------
# Wak 6: ให้พฤฒา | ทดแทน | คุณสนอง
#        [ไห้-พรึด-ทา | ทด-แทน | คุน-สะ-หนอง]
# ------------------------------
# Wak 7: ตาพราหมณ์เฒ่า | เอาสำลี | ประชีรอง
#        [ตา-พราม-เท่า | เอา-สำ-ลี | ประ-ชี-รอง]
# ------------------------------
# Wak 8: ขอดประคอง | ไว้ในผม | ให้สมควร
#        [ขอด-ประ-คอง | ไว้-ใน-ผม | ไห้-สม-ควน]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (แค้น -> แสน/ลึง): ✅ Pass
#   - Wak 2->3 (หา -> มา): ✅ Pass
#   - Wak 3->4 (มา -> คา/แสน): ✅ Pass
#
# ==================================================
# STANZA 20
# ==================================================
# Wak 1: แล้วถอดแหวน | วงน้อย | ที่ก้อยขวา
#        [แล้ว-ถอด-แหวน | วง-น้อย | ที่-ก้อย-ขวา]
# ------------------------------
# Wak 2: ให้พฤฒา | ทดแทน | คุณสนอง
#        [ไห้-พรึด-ทา | ทด-แทน | คุน-สะ-หนอง]
# ------------------------------
# Wak 3: ตาพราหมณ์เฒ่า | เอาสำลี | ประชีรอง
#        [ตา-พราม-เท่า | เอา-สำ-ลี | ประ-ชี-รอง]
# ------------------------------
# Wak 4: ขอดประคอง | ไว้ในผม | ให้สมควร
#        [ขอด-ประ-คอง | ไว้-ใน-ผม | ไห้-สม-ควน]
# ------------------------------
# Wak 5: แล้วไต่ถาม | นามวงศ์ | ถึงพงศา
#        [แล้ว-ต่าย-ถาม | นาม-วง | ถึง-พง-สา]
# ------------------------------
# Wak 6: สนทนา | ปรีดิ์เปรม | เกษมสรวล
#        [สน-ทะ-นา | ปรี-เปรม | กะ-เสม-สวน]
# ------------------------------
# Wak 7: อยู่เคหา | ตาพราหมณ์ | ไม่ลามลวน
#        [อยู่-เค-หา | ตา-พราม | ไม่-ลาม-ลวน]
# ------------------------------
# Wak 8: ครั้นค่ำชวน | หน่อไท | เข้าไสยา
#        [ครั้น-ค่ำ-ชวน | หน่อ-ไท | เข้า-ไส-ยา]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (ขวา -> ทา/แทน): ✅ Pass
#   - Wak 2->3 (หนอง -> รอง): ✅ Pass
#   - Wak 3->4 (รอง -> คอง/ใน): ✅ Pass
#
# ==================================================
# STANZA 21
# ==================================================
# Wak 1: แล้วไต่ถาม | นามวงศ์ | ถึงพงศา
#        [แล้ว-ต่าย-ถาม | นาม-วง | ถึง-พง-สา]
# ------------------------------
# Wak 2: สนทนา | ปรีดิ์เปรม | เกษมสรวล
#        [สน-ทะ-นา | ปรี-เปรม | กะ-เสม-สวน]
# ------------------------------
# Wak 3: อยู่เคหา | ตาพราหมณ์ | ไม่ลามลวน
#        [อยู่-เค-หา | ตา-พราม | ไม่-ลาม-ลวน]
# ------------------------------
# Wak 4: ครั้นค่ำชวน | หน่อไท | เข้าไสยา
#        [ครั้น-ค่ำ-ชวน | หน่อ-ไท | เข้า-ไส-ยา]
# ------------------------------
# Wak 5: ถึงยามดึก | ฝึกสอน | ในการยุทธ์
#        [ถึง-ยาม-ดึก | ฝึก-สอน | ใน-กาน-ยุด]
# ------------------------------
# Wak 6: เพลงอาวุธ | ดาบดั้ง | ให้ตั้งท่า
#        [เพลง-อา-วุด | ดาบ-ดั้ง | ไห้-ตั้ง-ท่า]
# ------------------------------
# Wak 7: กระบองกระ | บี่ถี่ถ้วน | ทุกวิชา
#        [กระ-บอง-กระ | บี่-ถี่-ถ้วน | ทุก-วิ-ชา]
# ------------------------------
# Wak 8: ค่อยศึกษา | ตั้งใจ | จะให้ดี
#        [ค่อย-สึก-สา | ตั้ง-ไจ | จะ-ไห้-ดี]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (สา -> นา/เปรม): ✅ Pass
#   - Wak 2->3 (สวน -> ลวน): ✅ Pass
#   - Wak 3->4 (ลวน -> ชวน/ไท): ✅ Pass
#
# ==================================================
# STANZA 22
# ==================================================
# Wak 1: ฝ่ายครูเฒ่า | พินท | พราหมณ์รามราช
#        [ฝ่าย-ครู-เท่า | พิน-ทะ | พราม-ราม-ราด]
# ------------------------------
# Wak 2: แสนสวาท | รักใคร่ | มิได้หมอง
#        [แสน-สะ-หวาด | รัก-ไค-ร่ | มิ-ได้-หมอง]
# ------------------------------
# Wak 3: ให้ข้าไท | ใช้สอย | คอยประคอง
#        [ไห้-ข้า-ไท | ไช้-สอย | คอย-ประ-คอง]
# ------------------------------
# Wak 4: เข้าในห้อง | หัดเพลง | บรรเลงพิณ
#        [เข้า-ใน-ห้อง | หัด-เพลง | บัน-เลง-พิน]
# ------------------------------
# Wak 5: แล้วพาไป | ยอดเขา | ให้เป่าปี่
#        [แล้ว-พา-ไป | ยอด-เขา | ไห้-เป่า-ปี่]
# ------------------------------
# Wak 6: ที่อย่างดี | สิ่งใด | ก็ได้สิ้น
#        [ที่-อย่าง-ดี | สิ่ง-ได | ก็-ได้-สิ้น]
# ------------------------------
# Wak 7: แต่เสือช้าง | กลางไพร | ถ้าได้ยิน
#        [แต่-เสือ-ช้าง | กลาง-ไพร | ถ้า-ได้-ยิน]
# ------------------------------
# Wak 8: ก็ลืมกิน | น้ำหญ้า | เข้ามาฟัง
#        [ก็-ลืม-กิน | น้ำ-ย่า | เข้า-มา-ฟัง]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (ราด -> หวาด/ไค): ✅ Pass
#   - Wak 2->3 (หมอง -> คอง): ✅ Pass
#   - Wak 3->4 (คอง -> ห้อง/เพลง): ✅ Pass
#
# ==================================================
# STANZA 23
# ==================================================
# Wak 1: แล้วพาไป | ยอดเขา | ให้เป่าปี่
#        [แล้ว-พา-ไป | ยอด-เขา | ไห้-เป่า-ปี่]
# ------------------------------
# Wak 2: ที่อย่างดี | สิ่งใด | ก็ได้สิ้น
#        [ที่-อย่าง-ดี | สิ่ง-ได | ก็-ได้-สิ้น]
# ------------------------------
# Wak 3: แต่เสือช้าง | กลางไพร | ถ้าได้ยิน
#        [แต่-เสือ-ช้าง | กลาง-ไพร | ถ้า-ได้-ยิน]
# ------------------------------
# Wak 4: ก็ลืมกิน | น้ำหญ้า | เข้ามาฟัง
#        [ก็-ลืม-กิน | น้ำ-ย่า | เข้า-มา-ฟัง]
# ------------------------------
# Wak 5: ประมาณเสร็จ | เจ็ดเดือน | โดยวิตถาร
#        [ประ-มาน-เส็ด | เจ็ด-เดือน | โดย-วิด-ถาน]
# ------------------------------
# Wak 6: พระกุมาร | ได้สม | อารมณ์หวัง
#        [พระ-กุ-มาน | ได้-สม | อา-รม-หวัง]
# ------------------------------
# Wak 7: สิ้นความรู้ | ครูประสิทธิ์ | ไม่ปิดบัง
#        [สิ้น-ความ-รู้ | ครู-ประ-สิด | ไม่-ปิด-บัง]
# ------------------------------
# Wak 8: จึงสอนสั่ง | อุปเท่ห์ | เป็นเล่ห์กล
#        [จึง-สอน-สั่ง | อุบ-เป๊ | เป็น-เล่-กน]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (ปี่ -> ดี/ได): ✅ Pass
#   - Wak 2->3 (สิ้น -> ยิน): ✅ Pass
#   - Wak 3->4 (ยิน -> กิน/ย่า): ✅ Pass
#
# ==================================================
# STANZA 24
# ==================================================
# Wak 1: ประมาณเสร็จ | เจ็ดเดือน | โดยวิตถาร
#        [ประ-มาน-เส็ด | เจ็ด-เดือน | โดย-วิด-ถาน]
# ------------------------------
# Wak 2: พระกุมาร | ได้สม | อารมณ์หวัง
#        [พระ-กุ-มาน | ได้-สม | อา-รม-หวัง]
# ------------------------------
# Wak 3: สิ้นความรู้ | ครูประสิทธิ์ | ไม่ปิดบัง
#        [สิ้น-ความ-รู้ | ครู-ประ-สิด | ไม่-ปิด-บัง]
# ------------------------------
# Wak 4: จึงสอนสั่ง | อุปเท่ห์ | เป็นเล่ห์กล
#        [จึง-สอน-สั่ง | อุบ-เป๊ | เป็น-เล่-กน]
# ------------------------------
# Wak 5: ถ้าแม้นว่า | ข้าศึก | มันโจมจับ
#        [ถ้า-แม้-น่า | ข้า-สึก | มัน-โจม-จับ]
# ------------------------------
# Wak 6: จะรบรับ | สารพัด | ให้ขัดสน
#        [จะ-รบ-รับ | สา-ระ-พัด | ไห้-ขัด-สน]
# ------------------------------
# Wak 7: เอาปี่เป่า | เล้าโลม | น้ำใจคน
#        [เอา-ปี่-เป่า | เล้า-โลม | น้ำ-ใจ-คน]
# ------------------------------
# Wak 8: ด้วยเล่ห์กล | โลกา | ห้าประการ
#        [ด้วย-เล่-กน | โล-กา | ห้า-ประ-กาน]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (ถาน -> มาน/สม): ✅ Pass
#   - Wak 2->3 (หวัง -> บัง): ✅ Pass
#   - Wak 3->4 (บัง -> สั่ง/เป๊): ✅ Pass
#
# ==================================================
# STANZA 25
# ==================================================
# Wak 1: แล้วให้ปี่ | ที่เพราะ | เสนาะเสียง
#        [แล้ว-ไห้-ปี่ | ที่-เพราะ | สะ-เหนาะ-เสียง]
# ------------------------------
# Wak 2: ยินสำเนียง | ถึงไหน | ก็ใหลหลง
#        [ยิน-สำ-เนียง | ถึง-ใหน | ก็-ไหล-ลง]
# ------------------------------
# Wak 3: อวยพรพลาง | ทางหยิบ | ธำมรงค์
#        [อวย-พอน-พลาง | ทาง-หิ-บะ | ทำ-มะ-รง]
# ------------------------------
# Wak 4: คืนให้องค์ | กุมารา | แล้วว่าพลัน
#        [คืน-ไห้-อง | กุ-มา-รา | แล้ว-ว่า-พลัน]
# ------------------------------
# Wak 5: ซึ่งดนตรี | ตีค่า | ไว้ถึงแสน
#        [ซึ่ง-ดน-ตรี | ตี-ค่า | ไว้-ถึง-แสน]
# ------------------------------
# Wak 6: เพราะหวงแหน | กำชับ | ไว้ขับขัน
#        [เพราะ-หวง-แหน | กำ-ชับ | ไว้-ขับ-ขัน]
# ------------------------------
# Wak 7: ใช่ประสงค์ | ตรงทรัพย์ | สิ่งสุวรรณ
#        [ไช่-ประ-สง | ตรง-ทรับ | สิ่ง-สุ-วัน]
# ------------------------------
# Wak 8: จะป้องกัน | มิให้ไพร่ | ได้วิชา
#        [จะ-ป้อง-กัน | มิ-ไห้-ไพร่ | ได้-วิ-ชา]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (เสียง -> เนียง/ใหน): ✅ Pass
#   - Wak 2->3 (ลง -> รง): ✅ Pass
#   - Wak 3->4 (รง -> อง/มา): ✅ Pass
#
# ==================================================
# STANZA 26
# ==================================================
# Wak 1: หน่อกษัตริย์ | สุริย์วงศ์ | ทรงสดับ
#        [หน่อ-กะ-สัด | สุ-ริ-วง | ทรง-สะ-ดับ]
# ------------------------------
# Wak 2: น้อมคำนับ | ปรีดิ์เปรม | เกษมศรี
#        [น้อม-คำ-นับ | ปรี-เปรม | กะ-เสม-สี]
# ------------------------------
# Wak 3: ครรไลลา | อาจารย์ | จรลี
#        [คัน-ไล-ลา | อา-จาน | จะ-ระ-ลี]
# ------------------------------
# Wak 4: ตามวิถี | แถวทาง | ถนนมา
#        [ตาม-ว-ถี | แถว-ทาง | ถะ-หนน-มา]
# ------------------------------
# Wak 5: พอมาพบ | พี่ชาย | ที่ท้ายบ้าน
#        [พอ-มา-พบ | พี่-ชาย | ที่-ท้าย-บ้าน]
# ------------------------------
# Wak 6: สองสำราญ | สรวลสันต์ | แล้วหรรษา
#        [สอง-สำ-ราน | สวน-สัน | แล้ว-หัน-สา]
# ------------------------------
# Wak 7: ต่างเล่าความ | ตามที่เรียน | รู้วิชา
#        [ต่าง-เล่า-ความ | ตาม-ที่-เรียน | รู้-วิ-ชา]
# ------------------------------
# Wak 8: แล้วพี่พา | น้องเดิน | ดำเนินไป
#        [แล้ว-พี่-พา | น้อง-เดิน | ดำ-เนิน-ไป]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (ดับ -> นับ/เปรม): ✅ Pass
#   - Wak 2->3 (สี -> ลี): ✅ Pass
#   - Wak 3->4 (ลี -> ถี/ทาง): ✅ Pass
#
# ==================================================
# STANZA 27
# ==================================================
# Wak 1: พอมาพบ | พี่ชาย | ที่ท้ายบ้าน
#        [พอ-มา-พบ | พี่-ชาย | ที่-ท้าย-บ้าน]
# ------------------------------
# Wak 2: สองสำราญ | สรวลสันต์ | แล้วหรรษา
#        [สอง-สำ-ราน | สวน-สัน | แล้ว-หัน-สา]
# ------------------------------
# Wak 3: ต่างเล่าความ | ตามที่เรียน | รู้วิชา
#        [ต่าง-เล่า-ความ | ตาม-ที่-เรียน | รู้-วิ-ชา]
# ------------------------------
# Wak 4: แล้วพี่พา | น้องเดิน | ดำเนินไป
#        [แล้ว-พี่-พา | น้อง-เดิน | ดำ-เนิน-ไป]
# ------------------------------
# Wak 5: ออกจากบ้าน | จันตคาม | ข้ามทิวทุ่ง
#        [ออก-จาก-บ้าน | จัน-ต-คาม | ข้าม-ทิว-ทุ่ง]
# ------------------------------
# Wak 6: หมายตรงกรุง | รัตนา | เข้าป่าใหญ่
#        [หมาย-ตรง-กรุง | รัด-ตะ-นา | เข้า-ป่า-ไหย่]
# ------------------------------
# Wak 7: สิบห้าวัน | บรรลุ | ถึงเวียงชัย
#        [สิบ-ห้า-วัน | บัน-ลุ | ถึง-เวียง-ไช]
# ------------------------------
# Wak 8: พอท้าวไท | สุทัศน์ | กษัตรา
#        [พอ-ท้าว-ไท | สุ-ทัด | กะ-สัด-ตรา]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (บ้าน -> ราน/สัน): ✅ Pass
#   - Wak 2->3 (สา -> ชา): ✅ Pass
#   - Wak 3->4 (ชา -> พา/เดิน): ✅ Pass
#
# ==================================================
# STANZA 28
# ==================================================
# Wak 1: ออกจากบ้าน | จันตคาม | ข้ามทิวทุ่ง
#        [ออก-จาก-บ้าน | จัน-ต-คาม | ข้าม-ทิว-ทุ่ง]
# ------------------------------
# Wak 2: หมายตรงกรุง | รัตนา | เข้าป่าใหญ่
#        [หมาย-ตรง-กรุง | รัด-ตะ-นา | เข้า-ป่า-ไหย่]
# ------------------------------
# Wak 3: สิบห้าวัน | บรรลุ | ถึงเวียงชัย
#        [สิบ-ห้า-วัน | บัน-ลุ | ถึง-เวียง-ไช]
# ------------------------------
# Wak 4: พอท้าวไท | สุทัศน์ | กษัตรา
#        [พอ-ท้าว-ไท | สุ-ทัด | กะ-สัด-ตรา]
# ------------------------------
# Wak 5: ออกแท่นทอง | ท้องพระโรง | จำรูญศรี
#        [ออก-แท่น-ทอง | ท้อง-พระ-โรง | จำ-รูน-สี]
# ------------------------------
# Wak 6: แสนเสนี | เฝ้าแหน | อยู่แน่นหนา
#        [แสน-เส-นี | เฝ้า-แหน | อยู่-แน่น-หนา]
# ------------------------------
# Wak 7: พระพี่น้อง | สององค์ | ก็ตรงมา
#        [พระ-พี่-น้อง | สอง-อง | ก็-ตรง-มา]
# ------------------------------
# Wak 8: เฝ้าบิดา | ที่ท้อง | พระโรงชัย
#        [เฝ้า-บิ-ดา | ที่-ท้อง | พระ-โรง-ไช]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (ทุ่ง -> กรุง/ตะ): ✅ Pass
#   - Wak 2->3 (ไหย่ -> ไช): ✅ Pass
#   - Wak 3->4 (ไช -> ไท/ทัด): ✅ Pass
#
# ==================================================
# STANZA 29
# ==================================================
# Wak 1: กรุงกษัตริย์ | สุริย์วงศ์ | พระทรงยศ
#        [กรุง-กะ-สัด | สุ-ริ-วง | พระ-ทรง-ยศ]
# ------------------------------
# Wak 2: เห็นโอรส | ยินดี | จะมีไหน
#        [เห็น-โอ-รด | ยิน-ดี | จะ-มี-ใหน]
# ------------------------------
# Wak 3: เรียกมานั่ง | ข้างแท่น | ทองประไพ
#        [เรียก-มา-นั่ง | ข้าง-แท่น | ทอง-ประ-ไพ]
# ------------------------------
# Wak 4: แล้วถามไถ่ | ทุกข์ยาก | เมื่อจากวัง
#        [แล้ว-ถาม-ถ่าย | ทุก-ยาก | เมื่อ-จาก-วัง]
# ------------------------------
# Wak 5: หนึ่งพี่น้อง | สองเสาะ | แสวงหา
#        [หนึ่ง-พี่-น้อง | สอง-เสาะ | สะ-แหวง-หา]
# ------------------------------
# Wak 6: ได้วิชา | เสร็จสม | อารมณ์หวัง
#        [ได้-วิ-ชา | เส็ด-สม | อา-รม-หวัง]
# ------------------------------
# Wak 7: หรือปลอดเปล่า | เล่าให้ | บิดาฟัง
#        [หรือ-ปลอด-เปล่า | เล่า-ไห้ | บิ-ดา-ฟัง]
# ------------------------------
# Wak 8: พ่อนี้นั่ง | คอยท่า | ทุกราตรี
#        [พ่อ-นี้-นั่ง | คอย-ท่า | ทุก-รา-ตรี]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (ยศ -> รด/ดี): ✅ Pass
#   - Wak 2->3 (ใหน -> ไพ): ✅ Pass
#   - Wak 3->4 (ไพ -> ถ่าย/ยาก): ❌ Fail
#
# ==================================================
# STANZA 30
# ==================================================
# Wak 1: พระพี่น้อง | สององค์ | ทรงสวัสดิ์
#        [พระ-พี่-น้อง | สอง-อง | ทรง-สะ-หวัด]
# ------------------------------
# Wak 2: ประสานหัตถ์ | น้อมประณต | บทศรี
#        [ประ-สาน-หัด | น้อม-ประ-นด | บด-สะ-รี]
# ------------------------------
# Wak 3: พระเชษฐา | ทูลแถลง | แจ้งคดี
#        [พระ-เชด-ถา | ทูน-แถน-ลง | แจ้ง-คะ-ดี]
# ------------------------------
# Wak 4: ลูกเรียนกล | ดนตรี | ชำนาญชาญ
#        [ลูก-เรียน-กล | ดน-ตรี | ชำ-นาน-ชาน]
# ------------------------------
# Wak 5: ศรีสุวรรณ | นั้นเรียน | ในการยุทธ์
#        [สี-สุ-วัน | นั้น-เรียน | ใน-กาน-ยุด]
# ------------------------------
# Wak 6: เพลงอาวุธ | เข้มแข็ง | กำแหงหาญ
#        [เพลง-อา-วุด | เข้ม-แข็ง | กำ-แหง-หาน]
# ------------------------------
# Wak 7: ทั้งสองสิ่ง | ยิ่งยวด | วิชาการ
#        [ทั้ง-สอง-สิ่ง | ยิ่ง-ยวด | วิ-ชา-กาน]
# ------------------------------
# Wak 8: ใครจะปาน | เปรียบได้ | นั้นไม่มี
#        [ไคร-จะ-ปาน | เปรียบ-ได้ | นั้น-ไม่-มี]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (หวัด -> หัด/ประ): ✅ Pass
#   - Wak 2->3 (รี -> ดี): ✅ Pass
#   - Wak 3->4 (ดี -> กล/ตรี): ✅ Pass
#
# ==================================================
# STANZA 31
# ==================================================
# Wak 1: ท้าวสุทัศน์ | ฟังอรรถ | โอรสราช
#        [ท้าว-สุ-ทัด | ฟัง-อัด | โอ-รด-ราด]
# ------------------------------
# Wak 2: บรมนาถ | ขัดข้อง | ให้หมองศรี
#        [บอ-รม-นาด | ขัด-ข้อง | ไห้-หมอง-สี]
# ------------------------------
# Wak 3: โกรธกระทืบ | บาทา | แล้วพาที
#        [โกรด-กระ-ทืบ | บา-ทา | แล้ว-พา-ที]
# ------------------------------
# Wak 4: อย่าอวดดี | เลยกูไม่ | พอใจฟัง
#        [อย่า-อวด-ดี | เลย-กู-ไม่ | พอ-ใจ-ฟัง]
# ------------------------------
# Wak 5: อันดนตรี | ปี่พาทย์ | ตะโพนเพลง
#        [อัน-ดน-ตรี | ปี่-พาด | ตะ-โพน-เพลง]
# ------------------------------
# Wak 6: เป็นนักเลง | เหล่าโลน | เล่นโขนหนัง
#        [เป็น-นัก-เลง | เหล่า-โลน | เล่น-โขน-หนัง]
# ------------------------------
# Wak 7: แต่พวกกู | ผู้หญิง | ที่ในวัง
#        [แต่-พวก-กู | ผู้-หยิง | ที่-ใน-วัง]
# ------------------------------
# Wak 8: มันก็ยัง | เรียนร่ำ | ได้ชำนาญ
#        [มัน-ก็-ยัง | เรียน-ร่ำ | ได้-ชำ-นาน]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (ราด -> นาด/ข้อง): ✅ Pass
#   - Wak 2->3 (สี -> ที): ✅ Pass
#   - Wak 3->4 (ที -> ดี/กู): ✅ Pass
#
# ==================================================
# STANZA 32
# ==================================================
# Wak 1: อันดนตรี | ปี่พาทย์ | ตะโพนเพลง
#        [อัน-ดน-ตรี | ปี่-พาด | ตะ-โพน-เพลง]
# ------------------------------
# Wak 2: เป็นนักเลง | เหล่าโลน | เล่นโขนหนัง
#        [เป็น-นัก-เลง | เหล่า-โลน | เล่น-โขน-หนัง]
# ------------------------------
# Wak 3: แต่พวกกู | ผู้หญิง | ที่ในวัง
#        [แต่-พวก-กู | ผู้-หยิง | ที่-ใน-วัง]
# ------------------------------
# Wak 4: มันก็ยัง | เรียนร่ำ | ได้ชำนาญ
#        [มัน-ก็-ยัง | เรียน-ร่ำ | ได้-ชำ-นาน]
# ------------------------------
# Wak 5: อันวิชา | อาวุธ | แลโล่เขน
#        [อัน-วิ-ชา | อา-วุด | แล-โล่-เขน]
# ------------------------------
# Wak 6: ชอบแต่เกณฑ์ | ศึกเสือ | เชื้อทหาร
#        [ชอบ-แต่-เกน | สึก-เสือ | เชื้อ-ทะ-หาน]
# ------------------------------
# Wak 7: เป็นกษัตริย์ | จักรพรรดิ | พิสดาร
#        [เป็น-กะ-สัด | จัก-กระ-พัด | พิด-สะ-ดาน]
# ------------------------------
# Wak 8: มาเรียนการ | เช่นนั้น | ด้วยอันใด
#        [มา-เรียน-กาน | เช่น-นั้น | ด้วย-อัน-ใด]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (เพลง -> เลง/โลน): ✅ Pass
#   - Wak 2->3 (หนัง -> วัง): ✅ Pass
#   - Wak 3->4 (วัง -> ยัง/ร่ำ): ✅ Pass
#
# ==================================================
# STANZA 33
# ==================================================
# Wak 1: อันวิชา | อาวุธ | แลโล่เขน
#        [อัน-วิ-ชา | อา-วุด | แล-โล่-เขน]
# ------------------------------
# Wak 2: ชอบแต่เกณฑ์ | ศึกเสือ | เชื้อทหาร
#        [ชอบ-แต่-เกน | สึก-เสือ | เชื้อ-ทะ-หาน]
# ------------------------------
# Wak 3: เป็นกษัตริย์ | จักรพรรดิ | พิสดาร
#        [เป็น-กะ-สัด | จัก-กระ-พัด | พิด-สะ-ดาน]
# ------------------------------
# Wak 4: มาเรียนการ | เช่นนั้น | ด้วยอันใด
#        [มา-เรียน-กาน | เช่น-นั้น | ด้วย-อัน-ใด]
# ------------------------------
# Wak 5: ลูกกาลี | มีแต่ | จะขายหน้า
#        [ลูก-กา-ลี | มี-แต่ | จะ-ขาย-น่า]
# ------------------------------
# Wak 6: ช่างชั่วช้า | ทุจริต | ผิดวิสัย
#        [ช่าง-ชั่ว-ช้า | ทุด-จะ-หริด | ผิด-วิ-ไส]
# ------------------------------
# Wak 7: จะให้อยู่ | เวียงวัง | ก็จังไร
#        [จะ-ไห้-อยู่ | เวียง-วัง | ก็-จัง-ไร]
# ------------------------------
# Wak 8: ชอบมาไส | คอส่ง | เสียจากเมือง
#        [ชอบ-มา-ไส | คอ-ส่ง | เสีย-จาก-เมือง]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (เขน -> เกน/เสือ): ✅ Pass
#   - Wak 2->3 (หาน -> ดาน): ✅ Pass
#   - Wak 3->4 (ดาน -> กาน/นั้น): ✅ Pass
#
# ==================================================
# STANZA 34
# ==================================================
# Wak 1: ลูกกาลี | มีแต่ | จะขายหน้า
#        [ลูก-กา-ลี | มี-แต่ | จะ-ขาย-น่า]
# ------------------------------
# Wak 2: ช่างชั่วช้า | ทุจริต | ผิดวิสัย
#        [ช่าง-ชั่ว-ช้า | ทุด-จะ-หริด | ผิด-วิ-ไส]
# ------------------------------
# Wak 3: จะให้อยู่ | เวียงวัง | ก็จังไร
#        [จะ-ไห้-อยู่ | เวียง-วัง | ก็-จัง-ไร]
# ------------------------------
# Wak 4: ชอบมาไส | คอส่ง | เสียจากเมือง
#        [ชอบ-มา-ไส | คอ-ส่ง | เสีย-จาก-เมือง]
# ------------------------------
# Wak 5: ไปเที่ยวเล่น | เป็นปี | แล้วมิสา
#        [ไป-เที่ยว-เล่น | เป็น-ปี | แล้ว-มิ-สา]
# ------------------------------
# Wak 6: มาพูดจา | ให้กู | คันหูเหือง
#        [มา-พูด-จา | ไห้-กู | คัน-หู-เหือง]
# ------------------------------
# Wak 7: พระพิโรธ | โกรธตรัส | ด้วยขัดเคือง
#        [พระ-พิ-โรด | โกรด-ตรัด | ด้วย-ขัด-เคือง]
# ------------------------------
# Wak 8: แล้วย่างเยื้อง | จากบัลลังก์ | เข้าวังใน
#        [แล้ว-ย่าง-เยื้อง | จาก-บัน-ลัง | เข้า-วัง-ใน]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (น่า -> ช้า/จะ): ✅ Pass
#   - Wak 2->3 (ไส -> ไร): ✅ Pass
#   - Wak 3->4 (ไร -> ไส/ส่ง): ✅ Pass
#
# ==================================================
# STANZA 35
# ==================================================
# Wak 1: พระเชษฐา | ว่าโอ้ | พ่อเพื่อนยาก
#        [พระ-เชด-ถา | ว่า-โอ้ | พ่อ-เพื่อน-ยาก]
# ------------------------------
# Wak 2: สู้ลำบาก | บุกป่า | พนาสัณฑ์
#        [สู้-ลำ-บาก | บุก-ป่า | พะ-นา-สัน]
# ------------------------------
# Wak 3: มาถึงวัง | ยังไม่ถึง | สักครึ่งวัน
#        [มา-ถึง-วัง | ยัง-ไม่-ถึง | สัก-ครึ่ง-วัน]
# ------------------------------
# Wak 4: ยังไม่ทัน | ทดลอง | ทั้งสองคน
#        [ยัง-ไม่-ทัน | ทด-ลอง | ทั้ง-สอง-คน]
# ------------------------------
# Wak 5: พระกริ้วกราด | คาดโทษ | ว่าโฉดเขลา
#        [พระ-กริ้ว-กราด | คาด-โทด | ว่า-โฉด-เขลา]
# ------------------------------
# Wak 6: พี่กับเจ้า | นี้ก็เห็น | ไม่เป็นผล
#        [พี่-กับ-เจ้า | นี้-ก็-เห็น | ไม่-เป็น-ผน]
# ------------------------------
# Wak 7: อยู่ก็อาย | ไพร่ฟ้า | ประชาชน
#        [อยู่-ก็-อาย | ไพร่-ฟ้า | ประ-ชา-ชน]
# ------------------------------
# Wak 8: ผิดก็ด้น | ดั้นไป | ในไพรวัน
#        [ผิด-ก็-ด้น | ดั้น-ไป | ใน-ไพร-วัน]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (ยาก -> บาก/ป่า): ✅ Pass
#   - Wak 2->3 (สัน -> วัน): ✅ Pass
#   - Wak 3->4 (วัน -> ทัน/ลอง): ✅ Pass
#
# ==================================================
# STANZA 36
# ==================================================
# Wak 1: พระกริ้วกราด | คาดโทษ | ว่าโฉดเขลา
#        [พระ-กริ้ว-กราด | คาด-โทด | ว่า-โฉด-เขลา]
# ------------------------------
# Wak 2: พี่กับเจ้า | นี้ก็เห็น | ไม่เป็นผล
#        [พี่-กับ-เจ้า | นี้-ก็-เห็น | ไม่-เป็น-ผน]
# ------------------------------
# Wak 3: อยู่ก็อาย | ไพร่ฟ้า | ประชาชน
#        [อยู่-ก็-อาย | ไพร่-ฟ้า | ประ-ชา-ชน]
# ------------------------------
# Wak 4: ผิดก็ด้น | ดั้นไป | ในไพรวัน
#        [ผิด-ก็-ด้น | ดั้น-ไป | ใน-ไพร-วัน]
# ------------------------------
# Wak 5: แล้วสวมสอด | กอดน้อง | ประคองหัตถ์
#        [แล้ว-สวม-สอด | กอด-น้อง | ประ-คอง-หัด]
# ------------------------------
# Wak 6: สองกษัตริย์ | โศกทรง | กันแสงศัลย์
#        [สอง-กะ-สัด | โสก-ทรง | กัน-แสง-สัน]
# ------------------------------
# Wak 7: พระอภัย | มณี | ศรีสุวรรณ
#        [พระ-อะ-ไพ | มะ-นี | สี-สุ-วัน]
# ------------------------------
# Wak 8: ก็พากัน | ซวนซบ | สลบไป
#        [ก็-พา-กัน | ซวน-ซบ | สะ-หลบ-ไป]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (เขลา -> เจ้า/ก็): ✅ Pass
#   - Wak 2->3 (ผน -> ชน): ✅ Pass
#   - Wak 3->4 (ชน -> ด้น/ไป): ✅ Pass
#
# ==================================================
# STANZA 37
# ==================================================
# Wak 1: แล้วสวมสอด | กอดน้อง | ประคองหัตถ์
#        [แล้ว-สวม-สอด | กอด-น้อง | ประ-คอง-หัด]
# ------------------------------
# Wak 2: สองกษัตริย์ | โศกทรง | กันแสงศัลย์
#        [สอง-กะ-สัด | โสก-ทรง | กัน-แสง-สัน]
# ------------------------------
# Wak 3: พระอภัย | มณี | ศรีสุวรรณ
#        [พระ-อะ-ไพ | มะ-นี | สี-สุ-วัน]
# ------------------------------
# Wak 4: ก็พากัน | ซวนซบ | สลบไป
#        [ก็-พา-กัน | ซวน-ซบ | สะ-หลบ-ไป]
# ------------------------------
# Wak 5: ฝ่ายมหา | เสนา | พฤฒามาตย์
#        [ฝ่าย-มะ-หา | เสนา | พรึด-ทา-มาด]
# ------------------------------
# Wak 6: เห็นหน่อนาถ | นิ่งแน่ | เข้าแก้ไข
#        [เห็น-หน่อ-นาด | นิ่ง-แน่ | เข้า-แก้-ไข]
# ------------------------------
# Wak 7: ทั้งสองตื่น | ฟื้นกาย | ระกำใจ
#        [ทั้ง-สอง-ตื่น | ฟื้น-กาย | ระ-กำ-ใจ]
# ------------------------------
# Wak 8: ชลนัยน์ | แนวนอง | ทั้งสององค์
#        [ชน-ละ-ไน | แนว-นอง | ทั้ง-สอง-อง]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (หัด -> สัด/ทรง): ✅ Pass
#   - Wak 2->3 (สัน -> วัน): ✅ Pass
#   - Wak 3->4 (วัน -> กัน/ซบ): ✅ Pass
#
# ==================================================
# STANZA 38
# ==================================================
# Wak 1: พระเชษฐา | ว่าจริง | แล้วน้องรัก
#        [พระ-เชด-ถา | ว่า-จิง | แล้ว-น้อง-รัก]
# ------------------------------
# Wak 2: เจ้าแหลมหลัก | ตักเตือน | สติพี่
#        [เจ้า-แหลม-หลัก | ตัก-เตือน | สะ-ติ-พี่]
# ------------------------------
# Wak 3: กระนั้น | แต่งองค์ไป | ทำไมมี
#        [กอ-ระ-นั้น | แต่ง-อง-ไป | ทำ-ไม-มี]
# ------------------------------
# Wak 4: ให้เป็นที่ | กังขา | ประชาชน
#        [ไห้-เป็น-ที่ | กัง-ขา | ประ-ชา-ชน]
# ------------------------------
# Wak 5: เราปลอมแปลง | แต่งกาย | เป็นชายไพร่
#        [เรา-ปลอม-แปลง | แต่ง-กาย | เป็น-ชาย-ไพร่]
# ------------------------------
# Wak 6: เหมือนยาก | ไร้แรมทาง | มากลางหน
#        [เหมือน-ยาก | ไร้-แรม-ทาง | มา-กลาง-หน]
# ------------------------------
# Wak 7: สองกษัตริย์ | ตรัสคิด | เห็นชอบกล
#        [สอง-กะ-สัด | ตรัด-คิด | เห็น-ชอบ-กน]
# ------------------------------
# Wak 8: จึงปลดเปลื้อง | เครื่องต้น | ออกจากกาย
#        [จึง-ปลด-เปลื้อง | เครื่อง-ต้น | ออก-จาก-กาย]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (รัก -> หลัก/เตือน): ✅ Pass
#   - Wak 2->3 (พี่ -> มี): ✅ Pass
#   - Wak 3->4 (มี -> ที่/ขา): ✅ Pass
#
# ==================================================
# STANZA 39
# ==================================================
# Wak 1: เราปลอมแปลง | แต่งกาย | เป็นชายไพร่
#        [เรา-ปลอม-แปลง | แต่ง-กาย | เป็น-ชาย-ไพร่]
# ------------------------------
# Wak 2: เหมือนยาก | ไร้แรมทาง | มากลางหน
#        [เหมือน-ยาก | ไร้-แรม-ทาง | มา-กลาง-หน]
# ------------------------------
# Wak 3: สองกษัตริย์ | ตรัสคิด | เห็นชอบกล
#        [สอง-กะ-สัด | ตรัด-คิด | เห็น-ชอบ-กน]
# ------------------------------
# Wak 4: จึงปลดเปลื้อง | เครื่องต้น | ออกจากกาย
#        [จึง-ปลด-เปลื้อง | เครื่อง-ต้น | ออก-จาก-กาย]
# ------------------------------
# Wak 5: เอาภูษา | ผ้าห่มห่อ | กระหวัด
#        [เอา-พู-สา | พ่า-ห่ม-ห่อ | กระ-หะ-วัด]
# ------------------------------
# Wak 6: แล้วคาดรัด | เอวไว้ | มิให้หาย
#        [แล้ว-คาด-รัด | เอว-ไว้ | มิ-ไห้-หาย]
# ------------------------------
# Wak 7: ศรีสุวรรณ | นั้นคุม | กระบองกราย
#        [สี-สุ-วัน | นั้น-คุม | กระ-บอง-กราย]
# ------------------------------
# Wak 8: พระพี่ชาย | ถือปี่ | แล้วลีลา
#        [พระ-พี่-ชาย | ถือ-ปี่ | แล้ว-ลี-ลา]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (ไพร่ -> ไร้/ทาง): ✅ Pass
#   - Wak 2->3 (หน -> กน): ✅ Pass
#   - Wak 3->4 (กน -> เปลื้อง/ต้น): ✅ Pass
#
# ==================================================
# STANZA 40
# ==================================================
# Wak 1: จะจับบท | บุตรพราหมณ์ | สามมาณพ
#        [จะ-จับ-บท | บุด-พราม | สาม-มา-นบ]
# ------------------------------
# Wak 2: ได้มาพบ | คบกันเล่น | เป็นสหาย
#        [ได้-มา-พบ | คบ-กัน-เล่น | เป็น-สะ-หาย]
# ------------------------------
# Wak 3: คนหนึ่งชื่อ | โมรา | ปรีชาชาย
#        [คน-หนึ่ง-ชื่อ | โม-รา | ปรี-ชา-ชาย]
# ------------------------------
# Wak 4: มีแยบคาย | ชำนาญ | ในการกล
#        [มี-แยก-คาย | ชำ-นาน | ใน-กาน-กล]
# ------------------------------
# Wak 5: เอาฟางหญ้า | มาผูก | สำเภาได้
#        [เอา-ฟาง-ย่า | มา-ผูก | สำ-เพา-ได้]
# ------------------------------
# Wak 6: แล้วแล่นไป | ในจังหวัด | ไม่ขัดสน
#        [แล้ว-แล่น-ไป | ใน-จัง-หวัด | ไม่-ขัด-สน]
# ------------------------------
# Wak 7: คนหนึ่งมี | วิชา | ชื่อสานน
#        [คน-หนึ่ง-มี | วิ-ชา | ชื่อ-สาน-น]
# ------------------------------
# Wak 8: ร้องเรียกฝน | ลมได้ | ดังใจจง
#        [ร้อง-เรียก-ฝน | ลม-ได้ | ดัง-ไจ-จง]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (นบ -> พบ/กัน): ✅ Pass
#   - Wak 2->3 (หาย -> ชาย): ✅ Pass
#   - Wak 3->4 (ชาย -> คาย/นาน): ✅ Pass
#
# ==================================================
# STANZA 41
# ==================================================
# Wak 1: เอาฟางหญ้า | มาผูก | สำเภาได้
#        [เอา-ฟาง-ย่า | มา-ผูก | สำ-เพา-ได้]
# ------------------------------
# ...
# ------------------------------
# Wak 6: เที่ยวลอยลำ | เล่นมหา | ชลาสินธุ์
#        [เที่ยว-ลอย-ลำ | เล่น-มะ-หา | ชะ-ลา-สิน]
# ------------------------------
# Wak 7: มาใกล้ไทร | สาขา | ริมวาริน
#        [มา-ไกล้-ไทร | สา-ขา | ริม-วา-ริน]
# ------------------------------
# Wak 8: ก็ได้ยิน | สุรเสียง | สำเนียงคน
#        [ก็-ได้-ยิน | สุ-ระ-เสียง | สำ-เนียง-คน]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (เขา -> เพา/ใหย่): ✅ Pass
#   - Wak 2->3 (หมาย -> พาย): ✅ Pass
#   - Wak 3->4 (พาย -> บาย/ป่า): ✅ Pass
#
# ==================================================
# STANZA 45
# ==================================================
# Wak 1: ถึงทะเล | แล่นตรง | ลงในน้ำ
#        [ถึง-ทะ-เล | แล่น-ตรง | ลง-ใน-น้ำ]
# ------------------------------
# Wak 2: เที่ยวลอยลำ | เล่นมหา | ชลาสินธุ์
#        [เที่ยว-ลอย-ลำ | เล่น-มะ-หา | ชะ-ลา-สิน]
# ------------------------------
# Wak 3: มาใกล้ไทร | สาขา | ริมวาริน
#        [มา-ไกล้-ไทร | สา-ขา | ริม-วา-ริน]
# ------------------------------
# Wak 4: ก็ได้ยิน | สุรเสียง | สำเนียงคน
#        [ก็-ได้-ยิน | สุ-ระ-เสียง | สำ-เนียง-คน]
# ------------------------------
# Wak 5: เห็นพี่น้อง | สององค์ | ล้วนทรงโฉม
#        [เห็น-พี่-น้อง | สอง-อง | ล้วน-ทรง-โฉม]
# ------------------------------
# Wak 6: งามประโลม | หลากจิต | คิดฉงน
#        [งาม-ประ-โลม | หลาก-จิด | คิด-ฉะ-หงน]
# ------------------------------
# Wak 7: ทอดสมอ | รอรา | เภตรายนต์
#        [ทอด-สะ-หมอ | รอ-รา | เพตรา-ยน]
# ------------------------------
# Wak 8: ทั้งสามคน | ขึ้นเดิน | บนเนินทราย
#        [ทั้ง-สาม-คน | ขึ้น-เดิน | บน-เนิน-ทราย]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (น้ำ -> ลำ/มะ): ✅ Pass
#   - Wak 2->3 (สิน -> ริน): ✅ Pass
#   - Wak 3->4 (ริน -> ยิน/ระ): ✅ Pass
#
# ==================================================
# STANZA 46
# ==================================================
# Wak 1: เห็นพี่น้อง | สององค์ | ล้วนทรงโฉม
#        [เห็น-พี่-น้อง | สอง-อง | ล้วน-ทรง-โฉม]
# ------------------------------
# Wak 2: งามประโลม | หลากจิต | คิดฉงน
#        [งาม-ประ-โลม | หลาก-จิด | คิด-ฉะ-หงน]
# ------------------------------
# Wak 3: ทอดสมอ | รอรา | เภตรายนต์
#        [ทอด-สะ-หมอ | รอ-รา | เพตรา-ยน]
# ------------------------------
# Wak 4: ทั้งสามคน | ขึ้นเดิน | บนเนินทราย
#        [ทั้ง-สาม-คน | ขึ้น-เดิน | บน-เนิน-ทราย]
# ------------------------------
# Wak 5: เข้ามาใกล้ | ไทรทอง | สองกษัตริย์
#        [เข้า-มา-ไกล้ | ไทร-ทอง | สอง-กะ-สัด]
# ------------------------------
# Wak 6: โสมนัส | ถามไถ่ | ดังใจหมาย
#        [โสม-มะ-นัด | ถาม-ถ่าย | ดัง-ไจ-หมาย]
# ------------------------------
# Wak 7: ว่าดูรา | มาณพ | ทั้งสองนาย
#        [ว่า-ดู-รา | มา-นบ | ทั้ง-สอง-นาย]
# ------------------------------
# Wak 8: เจ้าเพื่อนชาย | ชื่อไร | ไปไหนมา
#        [เจ้า-เพื่อน-ชาย | ชื่อ-ไร | ไป-ใหน-มา]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (โฉม -> โลม/จิด): ✅ Pass
#   - Wak 2->3 (หงน -> ยน): ✅ Pass
#   - Wak 3->4 (ยน -> คน/เดิน): ✅ Pass
#
# ==================================================
# STANZA 47
# ==================================================
# Wak 1: เข้ามาใกล้ | ไทรทอง | สองกษัตริย์
#        [เข้า-มา-ไกล้ | ไทร-ทอง | สอง-กะ-สัด]
# ------------------------------
# Wak 2: โสมนัส | ถามไถ่ | ดังใจหมาย
#        [โสม-มะ-นัด | ถาม-ถ่าย | ดัง-ไจ-หมาย]
# ------------------------------
# Wak 3: ว่าดูรา | มาณพ | ทั้งสองนาย
#        [ว่า-ดู-รา | มา-นบ | ทั้ง-สอง-นาย]
# ------------------------------
# Wak 4: เจ้าเพื่อนชาย | ชื่อไร | ไปไหนมา
#        [เจ้า-เพื่อน-ชาย | ชื่อ-ไร | ไป-ใหน-มา]
# ------------------------------
# Wak 5: หรือเดินดง | หลงทาง | มาต่างบ้าน
#        [หรือ-เดิน-ดง | หลง-ทาง | มา-ต่าง-บ้าน]
# ------------------------------
# Wak 6: จงแจ้งการณ์ | ให้เราฟัง | ที่กังขา
#        [จง-แจ้ง-กาน | ไห้-เรา-ฟัง | ที่-กัง-ขา]
# ------------------------------
# Wak 7: แม้นไม่มี่ | พี่น้อง | ญาติกา
#        [แม้น-ไม่-มี่ | พี่-น้อง | ยาด-ติ-กา]
# ------------------------------
# Wak 8: เราจะพา | ไปไว้เรือน | เป็นเพื่อนกัน
#        [เรา-จะ-พา | ไป-ไว้-เรือน | เป็น-เพื่อน-กัน]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (สัด -> นัด/ถ่าย): ✅ Pass
#   - Wak 2->3 (หมาย -> นาย): ✅ Pass
#   - Wak 3->4 (นาย -> ชาย/ไร): ✅ Pass
#
# ==================================================
# STANZA 48
# ==================================================
# Wak 1: ไปร่ำเรียน | วิชา | ที่อาจารย์
#        [ไป-ร่ำ-เรียน | วิ-ชา | ที่-อา-จาน]
# ------------------------------
# Wak 2: ตำบลบ้าน | จันตคาม | พนาศรี
#        [ตำ-บน-บ้าน | จัน-ต-คาม | พะ-นา-สี]
# ------------------------------
# Wak 3: อันตัวเรา | นี้ชำนาญ | การดนตรี
#        [อัน-ตัว-เรา | นี้-ชำ-นาน | กาน-ดน-ตรี]
# ------------------------------
# Wak 4: น้องเรานี้ | ก็ชำนาญ | การศัสตรา
#        [น้อง-เรา-นี้ | ก็-ชำ-นาน | กาน-สัด-ตรา]
# ------------------------------
# Wak 5: พระบิตุ | เรศขับไล่ | มิให้อยู่
#        [พระ-บิ-ตุ | เร-ศ-ขับ-ไล่ | มิ-ไห้-อยู่]
# ------------------------------
# Wak 6: ว่าเรียนรู้ | ต่ำชาติ | วาสนา
#        [ว่า-เรียน-รู้ | ต่ำ-ชาด | วาด-สะ-หนา]
# ------------------------------
# Wak 7: เราพี่น้อง | สองคน | จึงซนมา
#        [เรา-พี่-น้อง | สอง-คน | จึง-ซน-มา]
# ------------------------------
# Wak 8: หวังจะหา | แห่งครู | ผู้ชำนาญ
#        [หวัง-จะ-หา | แห่ง-ครู | ผู้-ชำ-นาน]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (จาน -> บ้าน/ต): ✅ Pass
#   - Wak 2->3 (สี -> ตรี): ✅ Pass
#   - Wak 3->4 (ตรี -> นี้/ชำ): ✅ Pass
#
# ==================================================
# STANZA 49
# ==================================================
# Wak 1: พระบิตุ | เรศขับไล่ | มิให้อยู่
#        [พระ-บิ-ตุ | เร-ศ-ขับ-ไล่ | มิ-ไห้-อยู่]
# ------------------------------
# Wak 2: ว่าเรียนรู้ | ต่ำชาติ | วาสนา
#        [ว่า-เรียน-รู้ | ต่ำ-ชาด | วาด-สะ-หนา]
# ------------------------------
# Wak 3: เราพี่น้อง | สองคน | จึงซนมา
#        [เรา-พี่-น้อง | สอง-คน | จึง-ซน-มา]
# ------------------------------
# Wak 4: หวังจะหา | แห่งครู | ผู้ชำนาญ
#        [หวัง-จะ-หา | แห่ง-ครู | ผู้-ชำ-นาน]
# ------------------------------
# Wak 5: ด้วยจะใคร่ | ไต่ถาม | ตามสงสัย
#        [ด้วย-จะ-ไค-ร่ | ต่าย-ถาม | ตาม-สง-ไส]
# ------------------------------
# Wak 6: วิชาใด | จึงจะดี | ให้วิตถาร
#        [วิ-ชา-ใด | จึง-จะ-ดี | ไห้-วิด-ถาน]
# ------------------------------
# Wak 7: ที่สมศักดิ์ | จักรพรรดิ | พิสดาร
#        [ที่-สม-สัก | จัก-กระ-พัด | พิด-สะ-ดาน]
# ------------------------------
# Wak 8: จะคิดอ่าน | เรียนร่ำ | เอาตำรา
#        [จะ-คิด-อ่าน | เรียน-ร่ำ | เอา-ตำ-รา]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (อยู่ -> รู้/ชาด): ✅ Pass
#   - Wak 2->3 (หนา -> มา): ✅ Pass
#   - Wak 3->4 (มา -> หา/ครู): ✅ Pass
#
# ==================================================
# STANZA 50
# ==================================================
# Wak 1: ด้วยจะใคร่ | ไต่ถาม | ตามสงสัย
#        [ด้วย-จะ-ไค-ร่ | ต่าย-ถาม | ตาม-สง-ไส]
# ------------------------------
# Wak 2: วิชาใด | จึงจะดี | ให้วิตถาร
#        [วิ-ชา-ใด | จึง-จะ-ดี | ไห้-วิด-ถาน]
# ------------------------------
# Wak 3: ที่สมศักดิ์ | จักรพรรดิ | พิสดาร
#        [ที่-สม-สัก | จัก-กระ-พัด | พิด-สะ-ดาน]
# ------------------------------
# Wak 4: จะคิดอ่าน | เรียนร่ำ | เอาตำรา
#        [จะ-คิด-อ่าน | เรียน-ร่ำ | เอา-ตำ-รา]
# ------------------------------
# Wak 5: อันตัวเจ้า | เผ่าพราหมณ์ | สามมาณพ
#        [อัน-ตัว-เจ้า | เผ่า-พราม | สาม-มา-นบ]
# ------------------------------
# Wak 6: ได้มาพบ | กันวันนี้ | ดีหนักหนา
#        [ได้-มา-พบ | กัน-วัน-นี้ | ดี-หนัก-หนา]
# ------------------------------
# Wak 7: ท่านทั้งสาม | นามใด | ไปไหนมา
#        [ทั่น-ทั้ง-สาม | นาม-ใด | ไป-ใหน-มา]
# ------------------------------
# Wak 8: จงเมตตา | บอกเล่า | ให้เข้าใจ
#        [จง-เมด-ตา | บอก-เล่า | ไห้-เข้า-ใจ]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (ไส -> ใด/จะ): ✅ Pass
#   - Wak 2->3 (ถาน -> ดาน): ✅ Pass
#   - Wak 3->4 (ดาน -> อ่าน/ร่ำ): ✅ Pass
#
# ==================================================
# STANZA 51
# ==================================================
# Wak 1: ดรุณพราหมณ์ | สามคน | ได้แจ้งอรรถ
#        [ดะ-รุน-พราม | สาม-คน | ได้-แจ้ง-อัด]
# ------------------------------
# Wak 2: ว่ากษัตริย์ | สุริย์วงศ์ | ไม่สงสัย
#        [ว่า-กะ-สัด | สุ-ริ-วง | ไม่-สง-ไส]
# ------------------------------
# Wak 3: ประณตนั่ง | บังคม | ขออภัย
#        [ประ-นด-นั่ง | บัง-คม | ขอ-อะ-ไพ]
# ------------------------------
# Wak 4: พระอย่าได้ | ถือความ | ข้าสามคน
#        [พระ-อย่า-ได้ | ถือ-ความ | ข้า-สาม-คน]
# ------------------------------
# Wak 5: ซึ่งพระองค์ | สงสัย | จึงไต่ถาม
#        [ซึ่ง-พระ-อง | สง-ไส | จึง-ต่าย-ถาม]
# ------------------------------
# Wak 6: จะทูลความ | ให้แจ้ง | แห่งนุสนธิ์
#        [จะ-ทูน-ความ | ไห้-แจ้ง | แห่ง-นุ-สน]
# ------------------------------
# Wak 7: ข้าชื่อวิ | เชียรโมรา | เจ้าสานน
#        [ข้า-ชื่อ-วิ | เชียน-โม-รา | เจ้า-สาน-น]
# ------------------------------
# Wak 8: ทั้งสามคน | คู่ชีวิต | เป็นมิตรกัน
#        [ทั้ง-สาม-คน | คู่-ชี-วิด | เป็น-มิด-กัน]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (อัด -> สัด/ริ): ✅ Pass
#   - Wak 2->3 (ไส -> ไพ): ✅ Pass
#   - Wak 3->4 (ไพ -> ได้/ความ): ✅ Pass
#
# ==================================================
# STANZA 52
# ==================================================
# Wak 1: ซึ่งพระองค์ | สงสัย | จึงไต่ถาม
#        [ซึ่ง-พระ-อง | สง-ไส | จึง-ต่าย-ถาม]
# ------------------------------
# Wak 2: จะทูลความ | ให้แจ้ง | แห่งนุสนธิ์
#        [จะ-ทูน-ความ | ไห้-แจ้ง | แห่ง-นุ-สน]
# ------------------------------
# Wak 3: ข้าชื่อวิ | เชียรโมรา | เจ้าสานน
#        [ข้า-ชื่อ-วิ | เชียน-โม-รา | เจ้า-สาน-น]
# ------------------------------
# Wak 4: ทั้งสามคน | คู่ชีวิต | เป็นมิตรกัน
#        [ทั้ง-สาม-คน | คู่-ชี-วิด | เป็น-มิด-กัน]
# ------------------------------
# Wak 5: แสวงหา | ตั้งเพียร | เพื่อเรียนรู้
#        [สะ-แหวง-หา | ตั้ง-เพียน | เพื่อ-เรียน-รู้]
# ------------------------------
# Wak 6: ได้เป็นคู่ | ศึกษาวิ | ชาขยัน
#        [ได้-เป็น-คู่ | สึก-สา-วิ | ชา-ขะ-หยัน]
# ------------------------------
# Wak 7: ได้รู้เรียก | ลมฝน | คือคนนั้น
#        [ได้-รู้-เรียก | ลม-ฝน | คือ-คน-นั้น]
# ------------------------------
# Wak 8: ข้าแข็งขัน | ยิงธนู | สู้ไพริน
#        [ข้า-แข็ง-ขัน | ยิง-ทะ-นู | สู้-ไพ-ริน]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (ถาม -> ความ/แจ้ง): ✅ Pass
#   - Wak 2->3 (สน -> น): ❌ Fail
#   - Wak 3->4 (น -> คน/ชี): ❌ Fail
#
# ==================================================
# STANZA 53
# ==================================================
# Wak 1: แสวงหา | ตั้งเพียร | เพื่อเรียนรู้
#        [สะ-แหวง-หา | ตั้ง-เพียน | เพื่อ-เรียน-รู้]
# ------------------------------
# Wak 2: ได้เป็นคู่ | ศึกษาวิ | ชาขยัน
#        [ได้-เป็น-คู่ | สึก-สา-วิ | ชา-ขะ-หยัน]
# ------------------------------
# Wak 3: ได้รู้เรียก | ลมฝน | คือคนนั้น
#        [ได้-รู้-เรียก | ลม-ฝน | คือ-คน-นั้น]
# ------------------------------
# Wak 4: ข้าแข็งขัน | ยิงธนู | สู้ไพริน
#        [ข้า-แข็ง-ขัน | ยิง-ทะ-นู | สู้-ไพ-ริน]
# ------------------------------
# Wak 5: ยิงออกไป | ได้ที | ละเจ็ดลูก
#        [ยิง-ออก-ไป | ได้-ที | ละ-เจ็ด-ลูก]
# ------------------------------
# Wak 6: จะให้ถูก | ตรงไหน | ก็ได้สิ้น
#        [จะ-ไห้-ถูก | ตรง-ไหน | ก็-ได้-สิ้น]
# ------------------------------
# Wak 7: คนนั้นผูก | เรือยนต์ | แล่นบนดิน
#        [คน-นั้น-ผูก | เรือ-ยน | แล่น-บน-ดิน]
# ------------------------------
# Wak 8: อยู่บ้านอิน | ทคาม | ทั้งสามคน
#        [อยู่-บ้าน-อิน | ท-คาม | ทั้ง-สาม-คน]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (รู้ -> คู่/สา): ✅ Pass
#   - Wak 2->3 (หยัน -> นั้น): ✅ Pass
#   - Wak 3->4 (นั้น -> ขัน/ทะ): ✅ Pass
#
# ==================================================
# STANZA 54
# ==================================================
# Wak 1: ยิงออกไป | ได้ที | ละเจ็ดลูก
#        [ยิง-ออก-ไป | ได้-ที | ละ-เจ็ด-ลูก]
# ------------------------------
# Wak 2: จะให้ถูก | ตรงไหน | ก็ได้สิ้น
#        [จะ-ไห้-ถูก | ตรง-ไหน | ก็-ได้-สิ้น]
# ------------------------------
# Wak 3: คนนั้นผูก | เรือยนต์ | แล่นบนดิน
#        [คน-นั้น-ผูก | เรือ-ยน | แล่น-บน-ดิน]
# ------------------------------
# Wak 4: อยู่บ้านอิน | ทคาม | ทั้งสามคน
#        [อยู่-บ้าน-อิน | ท-คาม | ทั้ง-สาม-คน]
# ------------------------------
# Wak 5: ซึ่งองค์พระ | อนุชา | เรียนอาวุธ
#        [ซึ่ง-อง-พระ | อะ-นุ-ชา | เรียน-อา-วุด]
# ------------------------------
# Wak 6: เข้ายงยุทธ์ | ข้าก็เห็น | จะเป็นผล
#        [เข้า-ยง-ยุด | ข้า-ก็-เห็น | จะ-เป็น-ผน]
# ------------------------------
# Wak 7: แต่ดนตรี | นี้ดู | ไม่ชอบกล
#        [แต่-ดน-ตรี | นี้-ดู | ไม่-ชอบ-กน]
# ------------------------------
# Wak 8: ข้าแสนสน | เท่ห์ใน | น้ำใจจริง
#        [ข้า-แสน-สน | เท่-ใน | น้ำ-ไจ-จิง]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (ลูก -> ถูก/ไหน): ✅ Pass
#   - Wak 2->3 (สิ้น -> ดิน): ✅ Pass
#   - Wak 3->4 (ดิน -> อิน/คาม): ✅ Pass
#
# ==================================================
# STANZA 55
# ==================================================
# Wak 1: พระฟังความ | พราหมณ์น้อย | สนองถาม
#        [พระ-ฟัง-ความ | พราม-น้อย | สะ-หนอง-ถาม]
# ------------------------------
# Wak 2: จึงเล่าความ | จะแจ้ง | แถลงไข
#        [จึง-เล่า-ความ | จะ-แจ้ง | แถน-ลง-ไข]
# ------------------------------
# Wak 3: อันดนตรี | มีคุณ | ทุกอย่างไป
#        [อัน-ดน-ตรี | มี-คุน | ทุก-อย่าง-ไป]
# ------------------------------
# Wak 4: ย้อมใช้ได้ | ดังจินดา | ค่าบุรินทร์
#        [ย้อม-ไช้-ได้ | ดัง-จิน-ดา | ค่า-บุ-ริน]
# ------------------------------
# Wak 5: ถึงมนุษย์ | ครุฑา | เทวราช
#        [ถึง-มะ-นุด | ครุ-ฑา | เท-วะ-ดา]
# ------------------------------
# Wak 6: จตุบาท | กลางป่า | พนาสินฑ์
#        [จะ-ตุ-บาด | กลาง-ป่า | พะ-นา-สิน]
# ------------------------------
# Wak 7: แม้นปี่เรา | เป่าไป | ให้ได้ยิน
#        [แม้น-ปี่-เรา | เป่า-ไป | ไห้-ได้-ยิน]
# ------------------------------
# Wak 8: ก็สุดสิ้น | โทโส | ที่โกรธา
#        [ก็-สุด-สิ้น | โท-โท | ที่-โกร-ทา]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (ถาม -> ความ/แจ้ง): ✅ Pass
#   - Wak 2->3 (ไข -> ไป): ✅ Pass
#   - Wak 3->4 (ไป -> ได้/จิน): ✅ Pass
#
# ==================================================
# STANZA 56
# ==================================================
# Wak 1: ถึงมนุษย์ | ครุฑา | เทวราช
#        [ถึง-มะ-นุด | ครุ-ฑา | เท-วะ-ดา]
# ------------------------------
# Wak 2: จตุบาท | กลางป่า | พนาสินฑ์
#        [จะ-ตุ-บาด | กลาง-ป่า | พะ-นา-สิน]
# ------------------------------
# Wak 3: แม้นปี่เรา | เป่าไป | ให้ได้ยิน
#        [แม้น-ปี่-เรา | เป่า-ไป | ไห้-ได้-ยิน]
# ------------------------------
# Wak 4: ก็สุดสิ้น | โทโส | ที่โกรธา
#        [ก็-สุด-สิ้น | โท-โท | ที่-โกร-ทา]
# ------------------------------
# Wak 5: ให้ใจอ่อน | นอนหลับ | ลืมสติ
#        [ไห้-ไจ-อ่อน | นอน-หลับ | ลืม-สะ-ติ]
# ------------------------------
# Wak 6: อันลัทธิ | ดนตรี | ดีหนักหนา
#        [อัน-ลัด-ทิ | ดน-ตรี | ดี-หนัก-หนา]
# ------------------------------
# Wak 7: ซึ่งสงสัย | ไม่สิ้นใน | วิญญาณ์
#        [ซึ่ง-สง-ไส | ไม่-สิ้น-ใน | วิ-ยะ-ยา]
# ------------------------------
# Wak 8: จงนิทรา | เถิดจะเป่า | ให้เจ้าฟัง
#        [จง-นิด-ซา | เถิด-จะ-เป่า | ไห้-เจ้า-ฟัง]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (ดา -> บาด/ป่า): ✅ Pass
#   - Wak 2->3 (สิน -> ยิน): ✅ Pass
#   - Wak 3->4 (ยิน -> สิ้น/โท): ✅ Pass
#
# ==================================================
# STANZA 57
# ==================================================
# Wak 1: เจ้าพราหมณ์ฟัง | วังเวง | วะแว่วเสียง
#        [เจ้า-พราม-ฟัง | วัง-เวง | วะ-แว่ว-เสียง]
# ------------------------------
# Wak 2: สำเนียงเพียง | การเวก | กังวานหวาน
#        [สำ-เนียง-เพียง | กาน-เกด | กัง-วาน-หวาน]
# ------------------------------
# Wak 3: หวาดประหวัด | สตรี | ฤดีดาล
#        [หวาด-ประ-หวัด | สัด-ตรี | รึ-ดี-ดาน]
# ------------------------------
# Wak 4: ให้ซาบซ่าน | เสียวสดับ | จนหลับไป
#        [ไห้-ซาบ-ซ่าน | เสียว-สะ-ดับ | จน-หลับ-ไป]
# ------------------------------
# Wak 5: ศรีสุวรรณ | นั้นนั่ง | อยู่ข้างพี่
#        [สี-สุ-วัน | นั้น-นั่ง | อยู่-ข้าง-พี่]
# ------------------------------
# Wak 6: ฟังเสียงปี่ | วาบวับ | ก็หลับใหล
#        [ฟัง-เสียง-ปี่ | วาบ-วับ | ก็-หลับ-ไหล]
# ------------------------------
# Wak 7: พระแกล้งเป่า | แปลงเพลง | วังเวงใจ
#        [พระ-แกล้ง-เป่า | แปลง-เพลง | วัง-เวง-ใจ]
# ------------------------------
# Wak 8: เป็นความบวง | สรวงพระไทร | ที่เนินทราย
#        [เป็น-ความ-บวง | สวง-พระ-ไทร | ที่-เนิน-ทราย]
# ------------------------------
#
#   [Rhyme Verification - Stanza 1 (Waks 1-4)]
#   - Wak 1->2 (เสียง -> เพียง/เกด): ✅ Pass
#   - Wak 2->3 (หวาน -> ดาน): ✅ Pass
#   - Wak 3->4 (ดาน -> ซ่าน/สะ): ✅ Pass

# %%
print(kv.check_klon(
                "ฉันชื่อหมูกรอบ ฉันชอบกินไก่ แล้วก็วิ่งไล่ หมาชื่อนํ้าทอง \
                    ลคคนเก่ง เอ๋งเอ๋งเสียงหมา มีคนจับจอง เขาชื่อน้องเธียร",
                k_type=4,
            ))
poem1 = (
        "แม่รักลูกลูกก็รู้อยู่ว่ารัก คนอื่นสักหมื่นแสนไม่แม้นเหมือน "
        "จะกินนอนวอนว่าเมตตาเตือด จะจากเรือนร้างแม่ไปแต่ตัว "
        "แม่วันทองของลูกจงกลับบ้าน เขาจะพาลว้าวุ่นแม่ทูนหัว "
        "จะก้มหน้าลาไปมิได้กลัว แม่อย่ามัวหมองนักจงหักใจ"
        )
print(kv.check_klon(poem1, k_type=8))
# Out:
# ["Rhyme error in Stanza (บทที่) 1: 'ไล่' (วรรครอง (Wak 3)) does not rhyme with ['หมา', 'ชื่อน'] (วรรคส่ง (Wak 4))", "Rhyme error in Stanza (บทที่) 2: 'หมา' (วรรครับ (Wak 2)) does not rhyme with 'จอง' (วรรครอง (Wak 3))", "Rhyme error in Stanza (บทที่) 2: 'จอง' (วรรครอง (Wak 3)) does not rhyme with ['เขา', 'ชื่อ'] (วรรคส่ง (Wak 4))", "Inter-stanza rhyme error (ผิดสัมผัสระหว่างบท) between Stanza 1 and 2: 'ทอง' (วรรคส่ง (Wak 4)) does not rhyme with 'หมา' (วรรครับ (Wak 2))"]
# ["Rhyme error in Stanza (บทที่) 1: 'เหมือน' (วรรครับ (Wak 2)) does not rhyme with 'เตือด' (วรรครอง (Wak 3))", "Rhyme error in Stanza (บทที่) 1: 'เตือด' (วรรครอง (Wak 3)) does not rhyme with ['จะ', 'จาก', 'เรือน', 'ร้าง', 'แม่'] (วรรคส่ง (Wak 4))"]

# %%
print(kv.check_klon(
    "แม่รักลูกลูกก็รู้อยู่ว่ารัก คนอื่นสักหมื่นแสนไม่แม้นเหมือน จะกินนอนวอนว่าเมตตาเตือน จะจากเรือนร้างแม่ไปแต่ตัว แม่วันทองของลูกจงกลับบ้าน เขาจะพาลว้าวุ่นแม่ทูนหัว จะก้มหน้าลาไปมิได้กลัว แม่อย่ามัวหมองนักจงหักใจ",
    k_type=8
))
print(kv.check_klon(
    "นางกอดจูบลูบหลังแล้วสั่งสอน อำนวยพรพลายน้อยละห้อยไห้ พ่อไปดีศรีสวัสดิ์กำจัดภัย จนเติบใหญ่ยิ่งยวดได้บวชเรียน ลูกผู้ชายลายมือนั้นคือยศ เเจ้าจงอตส่าห์ทำสม่ำเสมียน แล้วพาลูกออกมาข้างท่าเกวียน จะจากเจียนใจขาดอนาถใจ",
    k_type=8
))
# โอ้บาปกรรมน้ำนรกเจียวอกเรา -> เจียว-อก but got missed tokenize as เจีย-วอก
print(kv.check_klon(
    "ถึงโรงเหล้าเตากลั่นควันโขมง มีคันโพงผูกสายไว้ปลายเสา โอ้บาปกรรมน้ำนรกเจียวอกเรา ให้มัวเมาเหมือนหนึ่งบ้าเป็นน่าอาย ทำบุญบวชกรวดน้ำขอสำเร็จ สรรเพชญโพธิญาณประมาณหมาย ถึงสุราพารอดไม่วอดวาย ไม่ใกล้กรายแกล้งเมินก็เกินไป",
    k_type=8
))
print(kv.check_sara("เร็จ"))
print(kv.check_sara("เพช"))
print(kv.is_sumpus("เร็จ", "เพช"))
# in this case of สุนทรภู่ He use "สัมผัสลักลั่น" หรือการอนุโลมให้สระเสียงสั้นกับเสียงยาวที่มีมาตราตัวสะกดเดียวกันสัมผัสกันได้ which in this checker is not able to detect it. So it will return False
print(kv.check_klon(
    "ไม่เมาเหล้าแล้วแต่เรายังเมารัก สุดจะหักห้ามจิตคิดไฉน ถึงเมาเหล้าเช้าสายก็หายไป แต่เมาใจนี้ประจำทุกค่ำคืน",
    k_type=8
))
# Out:
# The poem is correct according to the principle.
# The poem is correct according to the principle.
# ["Rhyme error in Stanza (บทที่) 2: 'เร็จ' (วรรคสดับ (Wak 1)) does not rhyme with ['สรร', 'เพชญ', 'โพธิ', 'ญาณ', 'ประ'] (วรรครับ (Wak 2))"]
# เอะ
# เอ
# False
# The poem is correct according to the principle.

# %%
print(kv.check_klon(
    "แม่วันทองของลูกจงกลับบ้าน ขาจะพาลว้าวุ่นแม่ทูนหัว จะก้มหน้าลาไปมิได้กลัว แม่อย่ามัวหมองนักจงหักใจ",
    k_type=8
))
print(kv.check_klon(
    "แม่วันทองของลูกจงนานา อุปการคุณแม่ทูนหัว จะก้มหน้าลาไปมิได้กลัว แม่อย่ามัวหมองนักจงหักใจ",
    k_type=8
))
# Out:
# The poem is correct according to the principle.
# ["Rhyme error in Stanza (บทที่) 1: 'นา' (วรรคสดับ (Wak 1)) does not rhyme with ['อุป', 'การ', 'คุณ', 'แม่', 'ทูน'] (วรรครับ (Wak 2))"]

# %%
# Assuming you have instantiated kv = KhaveeVerifier()

problem_words = [
    # Reduced Forms (ลดรูป)
    "เลย", "พวก", "จวก", "คน", #"พร", "ณ", "เงือก", "เสือ", "มะเขือ", "โต๊ะ", "เรียน", "เกิด", "เหม่อ", "ผล็อย", "จันทร์", "นภสินธุ์", "ลักษมณ์", "ฟิล์ม",
    # Transformed Forms (เปลี่ยนรูป)
    "เจ็ด", "แข็ง", "เดิน", "ล็อก", #"ก็", "รัก", "เกีย", "เกียว", "เกลือ", "เกลี้ยง", "กลัว", "เอือ", "เรื่อง", "บ่", "บ", "อ", "ขอ"
]

print(f"{'Word':<10} | {'Vowel (Sara)':<10} | {'Marttra':<10}")
print("-" * 35)

for word in problem_words:
    sara = kv.check_sara(word)
    marttra = kv.check_marttra(word)
    print(f"{word:<10} | {sara:<10} | {marttra:<10}")
# Out:
# Word       | Vowel (Sara) | Marttra
# -----------------------------------
# เลย        | เออ        | เกย
# พวก        | อัว        | กก
# จวก        | อัว        | กก
# คน         | โอะ        | กน
# เจ็ด       | เอะ        | กด
# แข็ง       | แอะ        | กง
# เดิน       | เออ        | กน
# ล็อก       | เอาะ       | กก

# %%
problematic_words2 = ["เขว", "เหว่", "ไกล", "ใกล้",
                    #   "ใจ","จัย", "เสีย","สมัย","เลื่อย", 
                    #   "เปื่อย", "เฉื่อย", "เหนื่อย", "สวย", 
                    #   "เปล", "แปร", "โปล", "โปร", "ไฟล์", 
                      "มิตร", ]
for word in problematic_words2:
    print(f"Word: {word}, true final: {kv._has_true_final_yl(word)}, Sara: {kv.check_sara(word)}, Marttra: {kv.check_marttra(word)}")

print(kv.is_sumpus("ฤทธิ์", "กิด"))
# Out:
# Word: เขว, true final: False, Sara: เอ, Marttra: กา
# Word: เหว่, true final: False, Sara: เอ, Marttra: กา
# Word: ไกล, true final: False, Sara: ไอ, Marttra: กา
# Word: ใกล้, true final: False, Sara: ไอ, Marttra: กา
# Word: มิตร, true final: True, Sara: อิ, Marttra: กด
# True

# %%
# Test G2P model pronunciate
words_to_test = ["เลเวล", "โมเดล", "ชิล", "อิสราเอล", "แอปเปิล", "ฟุตบอล"]
for word in words_to_test:
    result = pronunciate(word, engine="word=to-phoneme")
    print(f"{word} -> {result}")
# Out:
# เลเวล -> เล-เวน
# โมเดล -> โม-เดน
# ชิล -> ชิน
# อิสราเอล -> อิด-สะ-รา-เอล
# แอปเปิล -> แอบ-เปิน
# ฟุตบอล -> ฟุด-บอน

# %%
words_to_test = ["เสีย","ไกล","ไทย","ใกล้","ไกว","ใคร","แปร"]
for word in words_to_test:
    print(f"Word: {word}, true final: {kv._has_true_final_yl(word)}, Sara: {kv.check_sara(word)}, Marttra: {kv.check_marttra(word)}")
# Out:
# Word: เสีย, true final: False, Sara: เอีย, Marttra: กา
# Word: ไกล, true final: False, Sara: ไอ, Marttra: กา
# Word: ไทย, true final: False, Sara: ไอ, Marttra: กา
# Word: ใกล้, true final: False, Sara: ไอ, Marttra: กา
# Word: ไกว, true final: False, Sara: ไอ, Marttra: กา
# Word: ใคร, true final: False, Sara: ไอ, Marttra: กา
# Word: แปร, true final: False, Sara: แอ, Marttra: กา

# %%
kv.check_sara("เลย")   # Previously returned "เอ", now yields "เออ" (สระลดรูป)
kv.check_sara("พวก")   # Previously failed, now yields "อัว" (สระลดรูป)
kv.check_sara("เจ็ด")  # Previously returned "เอ", now yields "เอะ" (สระเปลี่ยนรูป)
kv.check_sara("แข็ง")  # Previously returned "แอ", now yields "แอะ" (สระเปลี่ยนรูป)
kv.check_sara("ก็")    # Previously failed, now yields "เอาะ" (สระเปลี่ยนรูป)
words_to_test = ["ฤทธิ์", "กิด", "ฤกษ์", "ก็", "แก้ว", "วัติ", "วัต", "วัด", "ตัว", "กลัว", "ชั่ว", "ชัวร์", "อื", "กื"]
for word in words_to_test:
    print(f"Word: {word}, Sara: {kv.check_sara(word)}, Marttra: {kv.check_marttra(word)}")
# Out:
# Word: ฤทธิ์, Sara: อิ, Marttra: กด
# Word: กิด, Sara: อิ, Marttra: กด
# Word: ฤกษ์, Sara: เออ, Marttra: กก
# Word: ก็, Sara: เอาะ, Marttra: กา
# Word: แก้ว, Sara: แอ, Marttra: เกอว
# Word: วัติ, Sara: อะ, Marttra: กด
# Word: วัต, Sara: อะ, Marttra: กด
# Word: วัด, Sara: อะ, Marttra: กด
# Word: ตัว, Sara: อัว, Marttra: กา
# Word: กลัว, Sara: อัว, Marttra: กา
# Word: ชั่ว, Sara: อัว, Marttra: กา
# Word: ชัวร์, Sara: อัว, Marttra: กา
# Word: อื, Sara: อือ, Marttra: กา
# Word: กื, Sara: อือ, Marttra: กา

# %%
print(kv.is_sumpus("ก็","ก้อ"))
# Out:
# False

# %%
# Syllable, Cluster, & Rhyme Validation
print(kv.check_marttra("พาล"))       # Output: "กน"
print(kv.check_marttra("ไกล"))       # Output: "กา"
print(kv.check_marttra("ไกว"))       # Output: "กา"
print(kv.check_marttra("โปร"))       # Output: "กา"

print(kv.is_sumpus("บ้าน", "พาล"))  # Output: True
print(kv.is_sumpus("ธรรม", "สัม"))  # Output: True
print(kv.is_sumpus("ธรรม", "จำ"))   # Output: True
print(kv.is_sumpus("กัย", "ไก"))    # Output: True
print(kv.is_sumpus("ฤทธิ์", "กิด"))    # Output: True

# Silent Suffix Truncation Evaluation
karun_examples = ["อินทรีย์", "กษัตริย์", "ไปรษณีย์", "ฤทธิ์", "จันทร์", "ภาพยนตร์", "กาสาวพัสตร์"]
for word in karun_examples:
    print(f"{word} -> {kv.handle_karun_sound_silence(word)}")
# Out:
# กน
# กา
# กา
# กา
# True
# True
# True
# True
# True
# อินทรีย์ -> อินทรี
# กษัตริย์ -> กษัต
# ไปรษณีย์ -> ไปรษณี
# ฤทธิ์ -> ฤท
# จันทร์ -> จัน
# ภาพยนตร์ -> ภาพยน
# กาสาวพัสตร์ -> กาสาวพัส

# %%
poem = (
        "แม่รักลูกลูกก็รู้อยู่ว่ารัก คนอื่นสักหมื่นแสนไม่แม้นเหมือน "
        "จะกินนอนวอนว่าเมตตาเตือน จะจากเรือนร้างแม่ไปแต่ตัว "
        "แม่วันทองของลูกจงกลับบ้าน เขาจะพาลว้าวุ่นแม่ทูนหัว "
        "จะก้มหน้าลาไปมิได้กลัว แม่อย่ามัวหมองนักจงหักใจ "
)
print(kv.check_klon(poem, k_type=8))

poem2 = (
"""
แม่รักลูกลูกก็รู้อยู่ว่ารัก คนอื่นสักหมื่นแสนไม่แม้นเหมือน
จะกินนอนวอนว่าเมตตาเตือน จะจากเรือนร้างแม่ไปแต่ตัว
แม่วันทองของลูกจงกลับบ้าน เขาจะพาลว้าวุ่นแม่ทูนหัว
จะก้มหน้าลาไปมิได้กลัว แม่อย่ามัวหมองนักจงหักใจ
"""
)
print(poem2)
print(kv.check_klon(poem2, k_type=8))
# Out:
# The poem is correct according to the principle.
#
# แม่รักลูกลูกก็รู้อยู่ว่ารัก คนอื่นสักหมื่นแสนไม่แม้นเหมือน
# จะกินนอนวอนว่าเมตตาเตือน จะจากเรือนร้างแม่ไปแต่ตัว
# แม่วันทองของลูกจงกลับบ้าน เขาจะพาลว้าวุ่นแม่ทูนหัว
# จะก้มหน้าลาไปมิได้กลัว แม่อย่ามัวหมองนักจงหักใจ
#
# The poem is correct according to the principle.

# %%
poem = (
        "เหวยเหวยอีจันทรา ขึ้นหน้าเถียงผัว "
        "อุบาทว์ชาติชั่ว ไสหัวมึงไป "
        "นางจันทาเถียงเล่า พระองค์เจ้าหลงไหล "
        "ไล่ตีเมียไย พระไม่ปรานี "
)
print(kv.check_klon(poem, k_type=4))
poem_segments = poem.split(" ")
for i in range(0, len(poem_segments) - 1, 4):
        stanza = [
        subword_tokenize(poem_segments[i], engine="han_solo"),
        subword_tokenize(poem_segments[i + 1], engine="han_solo"),
        subword_tokenize(poem_segments[i + 2], engine="han_solo"),
        subword_tokenize(poem_segments[i + 3], engine="han_solo"),
        ]
        print(f"{i} Stanza: {stanza}")
# Out:
# The poem is correct according to the principle.
# 0 Stanza: [['เหวย', 'เหวย', 'อี', 'จัน', 'ทรา'], ['ขึ้น', 'หน้า', 'เถียง', 'ผัว'], ['อุ', 'บาทว์', 'ชาติ', 'ชั่ว'], ['ไส', 'หัว', 'มึง', 'ไป']]
# 4 Stanza: [['นาง', 'จัน', 'ทา', 'เถียง', 'เล่า'], ['พระ', 'องค์', 'เจ้า', 'หลง', 'ไหล'], ['ไล่', 'ตี', 'เมีย', 'ไย'], ['พระ', 'ไม่', 'ปรา', 'นี']]

# %%
print(kv.is_sumpus("กอน", "กร"))
print(kv.is_sumpus("ฤทธิ์", "กิด"))
print(kv.check_marttra("ฤกษ์"))
print(kv.check_sara("ฤทธิ์"))
print(kv.check_marttra("ฤทธิ์"))
# Out:
# True
# True
# กก
# อิ
# กด

# %%
from pythainlp import thai_consonants
print(kv._is_true_final("ธรณี"))
word = "ธรณี"
consonants = [c for c in word if c in thai_consonants + "ฤฦ"]
cluster = consonants[0] + consonants[1]
print(cluster)
# Out:
# True
# ธร

# %%
poem = "ถึงบางพูดพูดดีเป็นศรีศักดิ์มีคนรักรสถ้อยอร่อยจิตแม้นพูดชั่วตัวตายทำลายมิตรจะชอบผิดในมนุษย์เพราะพูดจา"
poem2 = """โอ้สังเวชวาศนานิจาเอ๋ย
จะมีคู่มิได้อยู่ประคองเชย	ต้องละเลยดวงใจไว้ไกลตา
ถึงทุกข์ใครในโลกที่โศกเศร้า	ไม่เหมือนเราภุมรินถวิลหา
จะพลัดพรากจากกันไม่ทันลา	ใช้แต่ตาต่างถ้อยสุนทรวอน 
โอ้จำใจไกลนุชสุดสวาดิ	จึงนิราศเรื่องรักเปนอักษร
ให้เห็นอกตกยากเมื่อจากจร	ไปดงดอนแดนป่าพนาวัน
กับศิษย์น้องสองนายล้วนชายหนุ่ม	น้อยกับพุ่มเพื่อนไร้ในไพรสัณฑ์
กับนายแสงแจ้งทางกลางอารัญ	จะพากันแรมทางไปต่างเมือง
ถึงยามสองล่องลำนาวาเลื่อน	พอดวงเดือนดั้นเมฆขึ้นเหลืองเหลือง
ถึงวัดแจ้งแสงจันทร์จำรัสเรือง	แลชำเลืองเหลียวหลังหลั่งน้ำตา
เปนห่วงหนึ่งถึงชนกที่ปกเกล้า	จะแสนเศร้าครวญคอยละห้อยหา
ทั้งจากแดนแสนห่วงดวงกานดา	โอ้อุรารุ่มร้อนอ่อนกำลัง
ถึงสามปลื้มพี่นี้ร่ำปล้ำแต่ทุกข์	สุดจะปลุกใจปลื้มให้ลืมหลัง
ขออารักษ์หลักประเทศนิเวศวัง	เทพทั้งเมืองฟ้าสุราไลย
ขอฝากน้องสองรามารดาด้วย	เอ็นดูช่วยปกครองให้ผ่องใส"""
# print(subword_tokenize(poem2, engine="dict"))
# print(subword_tokenize(poem2, engine="han_solo"))
print(subword_tokenize(poem2, engine="ssg")) # best performance
poem_tok = subword_tokenize(poem2.replace("\n", " ").replace("\t", ""), engine="ssg", keep_whitespace=True)
print(f"Poem Tokenized: {poem_tok}")
# Out:
# ['โอ้', 'สัง', 'เวช', 'วา', 'ศนา', 'นิ', 'จา', 'เอ๋ย\n', 'จะ', 'มี', 'คู่', 'มิ', 'ได้', 'อยู่', 'ประ', 'คอง', 'เชย\t', 'ต้อง', 'ละ', 'เลย', 'ดวง', 'ใจ', 'ไว้', 'ไกล', 'ตา\n', 'ถึง', 'ทุกข์', 'ใคร', 'ใน', 'โลก', 'ที่', 'โศก', 'เศร้า\t', 'ไม่', 'เหมือน', 'เรา', 'ภุม', 'ริน', 'ถวิล', 'หา\n', 'จะ', 'พลัด', 'พราก', 'จาก', 'กัน', 'ไม่', 'ทัน', 'ลา\t', 'ใช้', 'แต่', 'ตา', 'ต่าง', 'ถ้อย', 'สุน', 'ทร', 'วอน', ' \n', 'โอ้', 'จำ', 'ใจ', 'ไกล', 'นุช', 'สุด', 'สวา', 'ดิ\t', 'จึง', 'นิ', 'ราศ', 'เรื่อง', 'รัก', 'เปน', 'อัก', 'ษร\n', 'ให้', 'เห็น', 'อก', 'ตก', 'ยาก', 'เมื่อ', 'จาก', 'จร\t', 'ไป', 'ดง', 'ดอน', 'แดน', 'ป่า', 'พนา', 'วัน', '\n', 'กับ', 'ศิษย์', 'น้อง', 'สอง', 'นาย', 'ล้วน', 'ชาย', 'หนุ่ม', '\tน้อย', 'กับ', 'พุ่ม', 'เพื่อน', 'ไร้', 'ใน', 'ไพร', 'สัณฑ์\n', 'กับ', 'นาย', 'แสง', 'แจ้ง', 'ทาง', 'กลาง', 'อา', 'รัญ\t', 'จะ', 'พา', 'กัน', 'แรม', 'ทาง', 'ไป', 'ต่าง', 'เมือง', '\nถึง', 'ยาม', 'สอง', 'ล่อง', 'ลำ', 'นา', 'วา', 'เลื่อน\t', 'พอ', 'ดวง', 'เดือน', 'ดั้น', 'เมฆ', 'ขึ้น', 'เหลือง', 'เหลือง', '\nถึง', 'วัด', 'แจ้ง', 'แสง', 'จันทร์', 'จำ', 'รัส', 'เรือง\t', 'แล', 'ชำ', 'เลือง', 'เหลียว', 'หลัง', 'หลั่ง', 'น้ำ', 'ตา\n', 'เปน', 'ห่วง', 'หนึ่ง', 'ถึง', 'ชนก', 'ที่', 'ปก', 'เกล้า\t', 'จะ', 'แสน', 'เศร้า', 'ครวญ', 'คอย', 'ละ', 'ห้อย', 'หา\n', 'ทั้ง', 'จาก', 'แดน', 'แสน', 'ห่วง', 'ดวง', 'กาน', 'ดา\t', 'โอ้', 'อุ', 'รา', 'รุ่ม', 'ร้อน', 'อ่อน', 'กำ', 'ลัง', '\nถึง', 'สาม', 'ปลื้ม', 'พี่', 'นี้', 'ร่ำ', 'ปล้ำ', 'แต่', 'ทุกข์\t', 'สุด', 'จะ', 'ปลุก', 'ใจ', 'ปลื้ม', 'ให้', 'ลืม', 'หลัง', '\nขอ', 'อา', 'รักษ์', 'หลัก', 'ประ', 'เทศ', 'นิ', 'เวศ', 'วัง', '\t', 'เทพ', 'ทั้ง', 'เมือง', 'ฟ้า', 'สุ', 'รา', 'ไล', 'ย\n', 'ขอ', 'ฝาก', 'น้อง', 'สอง', 'รา', 'มาร', 'ดา', 'ด้วย\t', 'เอ็น', 'ดู', 'ช่วย', 'ปก', 'ครอง', 'ให้', 'ผ่อง', 'ใส']
# Poem Tokenized: ['โอ้', 'สัง', 'เวช', 'วา', 'ศนา', 'นิ', 'จา', 'เอ๋ย ', 'จะ', 'มี', 'คู่', 'มิ', 'ได้', 'อยู่', 'ประ', 'คอง', 'เชย', 'ต้อง', 'ละ', 'เลย', 'ดวง', 'ใจ', 'ไว้', 'ไกล', 'ตา ', 'ถึง', 'ทุกข์', 'ใคร', 'ใน', 'โลก', 'ที่', 'โศก', 'เศร้า', 'ไม่', 'เหมือน', 'เรา', 'ภุม', 'ริน', 'ถวิล', 'หา ', 'จะ', 'พลัด', 'พราก', 'จาก', 'กัน', 'ไม่', 'ทัน', 'ลา', 'ใช้', 'แต่', 'ตา', 'ต่าง', 'ถ้อย', 'สุน', 'ทร', 'วอน', '  ', 'โอ้', 'จำ', 'ใจ', 'ไกล', 'นุช', 'สุด', 'สวา', 'ดิ', 'จึง', 'นิ', 'ราศ', 'เรื่อง', 'รัก', 'เปน', 'อัก', 'ษร ', 'ให้', 'เห็น', 'อก', 'ตก', 'ยาก', 'เมื่อ', 'จาก', 'จร', 'ไป', 'ดง', 'ดอน', 'แดน', 'ป่า', 'พนา', 'วัน', ' ', 'กับ', 'ศิษย์', 'น้อง', 'สอง', 'นาย', 'ล้วน', 'ชาย', 'หนุ่ม', 'น้อย', 'กับ', 'พุ่ม', 'เพื่อน', 'ไร้', 'ใน', 'ไพร', 'สัณฑ์ ', 'กับ', 'นาย', 'แสง', 'แจ้ง', 'ทาง', 'กลาง', 'อา', 'รัญ', 'จะ', 'พา', 'กัน', 'แรม', 'ทาง', 'ไป', 'ต่าง', 'เมือง', ' ถึง', 'ยาม', 'สอง', 'ล่อง', 'ลำ', 'นา', 'วา', 'เลื่อน', 'พอ', 'ดวง', 'เดือน', 'ดั้น', 'เมฆ', 'ขึ้น', 'เหลือง', 'เหลือง', ' ถึง', 'วัด', 'แจ้ง', 'แสง', 'จันทร์', 'จำ', 'รัส', 'เรือง', 'แล', 'ชำ', 'เลือง', 'เหลียว', 'หลัง', 'หลั่ง', 'น้ำ', 'ตา ', 'เปน', 'ห่วง', 'หนึ่ง', 'ถึง', 'ชนก', 'ที่', 'ปก', 'เกล้า', 'จะ', 'แสน', 'เศร้า', 'ครวญ', 'คอย', 'ละ', 'ห้อย', 'หา ', 'ทั้ง', 'จาก', 'แดน', 'แสน', 'ห่วง', 'ดวง', 'กาน', 'ดา', 'โอ้', 'อุ', 'รา', 'รุ่ม', 'ร้อน', 'อ่อน', 'กำ', 'ลัง', ' ถึง', 'สาม', 'ปลื้ม', 'พี่', 'นี้', 'ร่ำ', 'ปล้ำ', 'แต่', 'ทุกข์', 'สุด', 'จะ', 'ปลุก', 'ใจ', 'ปลื้ม', 'ให้', 'ลืม', 'หลัง', ' ขอ', 'อา', 'รักษ์', 'หลัก', 'ประ', 'เทศ', 'นิ', 'เวศ', 'วัง', 'เทพ', 'ทั้ง', 'เมือง', 'ฟ้า', 'สุ', 'รา', 'ไล', 'ย ', 'ขอ', 'ฝาก', 'น้อง', 'สอง', 'รา', 'มาร', 'ดา', 'ด้วย', 'เอ็น', 'ดู', 'ช่วย', 'ปก', 'ครอง', 'ให้', 'ผ่อง', 'ใส']

# %%
poem_klon4 = (
            "มวลไม้ดอกสวย ระรวยกลิ่นหอม หมู่ผึ้งดมดอม พรั่งพร้อมนานา "
            "ผีเสื้อปีกบาง บินกางปีกมา ช่างงามจับตา เริงร่าสุขใจ"
        )
poem = (
            "มวลไม้ดอกสวยระรวยกลิ่นหอม หมู่ผึ้งดมดอมพรั่งพร้อมนานา "
            "ผีเสื้อปีกบางบินกางปีกมา ช่างงามจับตาเริงร่าสุขใจ"
        )
poem = (
            "แม่รักลูกลูกก็รู้อยู่ว่ารัก คนอื่นสักหมื่นแสนไม่แม้นเหมือน "
            "จะกินนอนวอนว่าเมตตาเตือน จะจากเรือนร้างแม่ไปแต่ตัว "
            "แม่วันทองของลูกจงกลับบ้าน เขาจะพาลว้าวุ่นแม่ทูนหัว "
            "จะก้มหน้าลาไปมิได้กลัว แม่อย่ามัวหมองนักจงหักใจ"
        )
poem = (
            "นางกอดจูบลูบหลังแล้วสั่งสอน อำนวยพรพลายน้อยละห้อยไห้ "
            "พ่อไปดีศรีสวัสดิ์กำจัดภัย จนเติบใหญ่ยิ่งยวดได้บวชเรียน "
            "ลูกผู้ชายลายมือนั้นคือยศ เเจ้าจงอตส่าห์ทำสม่ำเสมียน "
            "แล้วพาลูกออกมาข้างท่าเกวียน จะจากเจียนใจขาดอนาถใจ"
        )
poem = (
            "แม่รักลูกลูกก็รู้อยู่ว่ารักมากมาก คนอื่นสักหมื่นแสนไม่แม้นเหมือน "
            "จะกินนอนวอนว่าเมตตาเตือน จะจากเรือนร้างแม่ไปแต่ตัว "
            "แม่วันทองของลูกจงกลับบ้าน เขาจะพาลว้าวุ่นแม่ทูนหัว "
            "จะก้มหน้าลาไปมิได้กลัว แม่อย่ามัวหมองนักจงหักใจ"
        )
poem = (
            "แม่รักลูกลูกก็รู้อยู่ว่ารัก คนอื่นสักหมื่นแสนไม่แม้นเหมือน "
            "จะกินนอนวอนว่าเมตตาเตือน จะจากเรือนร้างแม่ไปแต่ตัง "
            "แม่วันทองของลูกจงกลับบ้าน เขาจะพาลว้าวุ่นแม่ทูนหัว "
            "จะก้มหน้าลาไปมิได้กลัว แม่อย่ามัวหมองนักจงหักใจ"
        )
poem = (
            "ฉันชื่อหมูกรอบ ฉันชอบกินไก่ แล้ววิ่งตามไป ไล่หมาน้ำทอง "
            "ฉันมันคนเก่ง เอ๋งเอ๋งคะนอง มีคนจับจอง เป็นของน้องเธียร"
        )
# poem = (
#             "ฉันชื่อหมูกรอบ ฉันชอบกินไก่ แล้ววิ่งตามไล่ น้องหมาน้ำทอง "
#             "ฉันมันคนโหด เอ๋งเอ๋งคะนอง มีคนจับจอง เป็นของน้องเธียร"
#         )
print(kv.check_klon(poem, k_type=4))
# Out:
# The poem is correct according to the principle.

# %%
import ssg
subword_tok1 = ssg.syllable_tokenize(poem2.replace("\n", " ").replace("\t", ""))
subword_tok = subword_tokenize(poem2.replace("\n", " ").replace("\t", ""), engine="ssg")
print(f"Poem Tokenized  : {subword_tok}")
print(f"Poem Tokenized 1: {subword_tok1}")
# Out:
# Poem Tokenized  : ['โอ้', 'สัง', 'เวช', 'วา', 'ศนา', 'นิ', 'จา', 'เอ๋ย ', 'จะ', 'มี', 'คู่', 'มิ', 'ได้', 'อยู่', 'ประ', 'คอง', 'เชย', 'ต้อง', 'ละ', 'เลย', 'ดวง', 'ใจ', 'ไว้', 'ไกล', 'ตา ', 'ถึง', 'ทุกข์', 'ใคร', 'ใน', 'โลก', 'ที่', 'โศก', 'เศร้า', 'ไม่', 'เหมือน', 'เรา', 'ภุม', 'ริน', 'ถวิล', 'หา ', 'จะ', 'พลัด', 'พราก', 'จาก', 'กัน', 'ไม่', 'ทัน', 'ลา', 'ใช้', 'แต่', 'ตา', 'ต่าง', 'ถ้อย', 'สุน', 'ทร', 'วอน', '  ', 'โอ้', 'จำ', 'ใจ', 'ไกล', 'นุช', 'สุด', 'สวา', 'ดิ', 'จึง', 'นิ', 'ราศ', 'เรื่อง', 'รัก', 'เปน', 'อัก', 'ษร ', 'ให้', 'เห็น', 'อก', 'ตก', 'ยาก', 'เมื่อ', 'จาก', 'จร', 'ไป', 'ดง', 'ดอน', 'แดน', 'ป่า', 'พนา', 'วัน', ' ', 'กับ', 'ศิษย์', 'น้อง', 'สอง', 'นาย', 'ล้วน', 'ชาย', 'หนุ่ม', 'น้อย', 'กับ', 'พุ่ม', 'เพื่อน', 'ไร้', 'ใน', 'ไพร', 'สัณฑ์ ', 'กับ', 'นาย', 'แสง', 'แจ้ง', 'ทาง', 'กลาง', 'อา', 'รัญ', 'จะ', 'พา', 'กัน', 'แรม', 'ทาง', 'ไป', 'ต่าง', 'เมือง', ' ถึง', 'ยาม', 'สอง', 'ล่อง', 'ลำ', 'นา', 'วา', 'เลื่อน', 'พอ', 'ดวง', 'เดือน', 'ดั้น', 'เมฆ', 'ขึ้น', 'เหลือง', 'เหลือง', ' ถึง', 'วัด', 'แจ้ง', 'แสง', 'จันทร์', 'จำ', 'รัส', 'เรือง', 'แล', 'ชำ', 'เลือง', 'เหลียว', 'หลัง', 'หลั่ง', 'น้ำ', 'ตา ', 'เปน', 'ห่วง', 'หนึ่ง', 'ถึง', 'ชนก', 'ที่', 'ปก', 'เกล้า', 'จะ', 'แสน', 'เศร้า', 'ครวญ', 'คอย', 'ละ', 'ห้อย', 'หา ', 'ทั้ง', 'จาก', 'แดน', 'แสน', 'ห่วง', 'ดวง', 'กาน', 'ดา', 'โอ้', 'อุ', 'รา', 'รุ่ม', 'ร้อน', 'อ่อน', 'กำ', 'ลัง', ' ถึง', 'สาม', 'ปลื้ม', 'พี่', 'นี้', 'ร่ำ', 'ปล้ำ', 'แต่', 'ทุกข์', 'สุด', 'จะ', 'ปลุก', 'ใจ', 'ปลื้ม', 'ให้', 'ลืม', 'หลัง', ' ขอ', 'อา', 'รักษ์', 'หลัก', 'ประ', 'เทศ', 'นิ', 'เวศ', 'วัง', 'เทพ', 'ทั้ง', 'เมือง', 'ฟ้า', 'สุ', 'รา', 'ไล', 'ย ', 'ขอ', 'ฝาก', 'น้อง', 'สอง', 'รา', 'มาร', 'ดา', 'ด้วย', 'เอ็น', 'ดู', 'ช่วย', 'ปก', 'ครอง', 'ให้', 'ผ่อง', 'ใส']
# Poem Tokenized 1: ['โอ้', 'สัง', 'เวช', 'วา', 'ศนา', 'นิ', 'จา', 'เอ๋ย ', 'จะ', 'มี', 'คู่', 'มิ', 'ได้', 'อยู่', 'ประ', 'คอง', 'เชย', 'ต้อง', 'ละ', 'เลย', 'ดวง', 'ใจ', 'ไว้', 'ไกล', 'ตา ', 'ถึง', 'ทุกข์', 'ใคร', 'ใน', 'โลก', 'ที่', 'โศก', 'เศร้า', 'ไม่', 'เหมือน', 'เรา', 'ภุม', 'ริน', 'ถวิล', 'หา ', 'จะ', 'พลัด', 'พราก', 'จาก', 'กัน', 'ไม่', 'ทัน', 'ลา', 'ใช้', 'แต่', 'ตา', 'ต่าง', 'ถ้อย', 'สุน', 'ทร', 'วอน', '  ', 'โอ้', 'จำ', 'ใจ', 'ไกล', 'นุช', 'สุด', 'สวา', 'ดิ', 'จึง', 'นิ', 'ราศ', 'เรื่อง', 'รัก', 'เปน', 'อัก', 'ษร ', 'ให้', 'เห็น', 'อก', 'ตก', 'ยาก', 'เมื่อ', 'จาก', 'จร', 'ไป', 'ดง', 'ดอน', 'แดน', 'ป่า', 'พนา', 'วัน', ' ', 'กับ', 'ศิษย์', 'น้อง', 'สอง', 'นาย', 'ล้วน', 'ชาย', 'หนุ่ม', 'น้อย', 'กับ', 'พุ่ม', 'เพื่อน', 'ไร้', 'ใน', 'ไพร', 'สัณฑ์ ', 'กับ', 'นาย', 'แสง', 'แจ้ง', 'ทาง', 'กลาง', 'อา', 'รัญ', 'จะ', 'พา', 'กัน', 'แรม', 'ทาง', 'ไป', 'ต่าง', 'เมือง', ' ถึง', 'ยาม', 'สอง', 'ล่อง', 'ลำ', 'นา', 'วา', 'เลื่อน', 'พอ', 'ดวง', 'เดือน', 'ดั้น', 'เมฆ', 'ขึ้น', 'เหลือง', 'เหลือง', ' ถึง', 'วัด', 'แจ้ง', 'แสง', 'จันทร์', 'จำ', 'รัส', 'เรือง', 'แล', 'ชำ', 'เลือง', 'เหลียว', 'หลัง', 'หลั่ง', 'น้ำ', 'ตา ', 'เปน', 'ห่วง', 'หนึ่ง', 'ถึง', 'ชนก', 'ที่', 'ปก', 'เกล้า', 'จะ', 'แสน', 'เศร้า', 'ครวญ', 'คอย', 'ละ', 'ห้อย', 'หา ', 'ทั้ง', 'จาก', 'แดน', 'แสน', 'ห่วง', 'ดวง', 'กาน', 'ดา', 'โอ้', 'อุ', 'รา', 'รุ่ม', 'ร้อน', 'อ่อน', 'กำ', 'ลัง', ' ถึง', 'สาม', 'ปลื้ม', 'พี่', 'นี้', 'ร่ำ', 'ปล้ำ', 'แต่', 'ทุกข์', 'สุด', 'จะ', 'ปลุก', 'ใจ', 'ปลื้ม', 'ให้', 'ลืม', 'หลัง', ' ขอ', 'อา', 'รักษ์', 'หลัก', 'ประ', 'เทศ', 'นิ', 'เวศ', 'วัง', 'เทพ', 'ทั้ง', 'เมือง', 'ฟ้า', 'สุ', 'รา', 'ไล', 'ย ', 'ขอ', 'ฝาก', 'น้อง', 'สอง', 'รา', 'มาร', 'ดา', 'ด้วย', 'เอ็น', 'ดู', 'ช่วย', 'ปก', 'ครอง', 'ให้', 'ผ่อง', 'ใส']

# %%
from pythainlp.util import num_to_thaiword
print(num_to_thaiword(112))
print(num_to_thaiword(1234567890))
print(num_to_thaiword(11000000))
print(num_to_thaiword(11000001))
print(num_to_thaiword(11000011))
print(num_to_thaiword(111000000))
print(num_to_thaiword(101000000))
print(num_to_thaiword(501741221))
print(num_to_thaiword(6001461300))
print(num_to_thaiword(20006001461300))
# Out:
# หนึ่งร้อยสิบสอง
# หนึ่งพันสองร้อยสามสิบสี่ล้านห้าแสนหกหมื่นเจ็ดพันแปดร้อยเก้าสิบ
# สิบเอ็ดล้าน
# สิบเอ็ดล้านเอ็ด
# สิบเอ็ดล้านสิบเอ็ด
# หนึ่งร้อยสิบเอ็ดล้าน
# หนึ่งร้อยหนึ่งล้าน
# ห้าร้อยหนึ่งล้านเจ็ดแสนสี่หมื่นหนึ่งพันสองร้อยยี่สิบเอ็ด
# หกพันหนึ่งล้านสี่แสนหกหมื่นหนึ่งพันสามร้อย
# ยี่สิบล้านหกพันหนึ่งล้านสี่แสนหกหมื่นหนึ่งพันสามร้อย

# %%
number = 12345678901234567890
number_str = str(number)
groups: list[str] = []
while number_str:
    group = number_str[-6:]
    number_str = number_str[:-6]
    groups.append(group)
for group in groups:
    print(f"Group: {group}")
    
output = ""
for i in range(len(groups) - 1, -1, -1):
    group_num = int(groups[i])
    if group_num > 0:
        output += num_to_thaiword(group_num)
    if i > 0:
        output += "ล้าน"

print(f"Final Output: {output}")
# Out:
# Group: 567890
# Group: 901234
# Group: 345678
# Group: 12
# Final Output: สิบสองล้านสามแสนสี่หมื่นห้าพันหกร้อยเจ็ดสิบแปดล้านเก้าแสนหนึ่งพันสองร้อยสามสิบสี่ล้านห้าแสนหกหมื่นเจ็ดพันแปดร้อยเก้าสิบ
